# %%
import random

# Number of Players and Rounds
num_players = 10
num_rounds = 5
num_simulations = 1000

# Sample Players with Elo ratings (example data)
players = [{'name': f'Player {i}', 'elo': random.randint(1400, 2600), 'points': 0} for i in range(num_players)]



def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2 """
    return 1 / (1 + 10 ** ((player2['elo'] - player1['elo']) / 400))

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
    elif result < win_prob + (1 - win_prob) / 2:
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
    else:
        player2['points'] += 1  # Player 2 wins

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            # Avoid pairing the same players again (simple check)
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

# %%
def simulate_tournament():
    """ Simulate a single Swiss-system tournament """
    # Reset points and opponents for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []

    # Simulate rounds
    for _ in range(num_rounds):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)

    # Determine winner (basic - most points)
    winner = max(players, key=lambda x: x['points'])
    return winner['name']

# Run multiple simulations and tally wins
tournament_wins = {player['name']: 0 for player in players}
for _ in range(num_simulations):
    winner = simulate_tournament()
    tournament_wins[winner] += 1

# Print probabilities of winning the tournament
for player in players:
    probability = tournament_wins[player['name']] / num_simulations
    print(f"{player['name']} winning probability: {probability:.2f}")
# Out:
# Player 0 winning probability: 0.52
# Player 1 winning probability: 0.00
# Player 2 winning probability: 0.09
# Player 3 winning probability: 0.00
# Player 4 winning probability: 0.04
# Player 5 winning probability: 0.00
# Player 6 winning probability: 0.02
# Player 7 winning probability: 0.00
# Player 8 winning probability: 0.03
# Player 9 winning probability: 0.30

# %%
import random

# Number of Players, Rounds, and Simulations
num_players = 10
num_rounds = 5
num_simulations = 1000
k_factor = 20  # K-factor for Elo rating updates

# Initialize Players with Elo ratings
players = [{'name': f'Player {i}', 'elo': random.randint(1400, 2600), 'points': 0} for i in range(num_players)]

def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2 """
    return 1 / (1 + 10 ** ((player2['elo'] - player1['elo']) / 400))

def update_elo_ratings(winner, loser, draw=False):
    """ Update Elo ratings after a game """
    expected_win_winner = calculate_win_probability(winner, loser)
    expected_win_loser = calculate_win_probability(loser, winner)

    score_winner = 0.5 if draw else 1
    score_loser = 0.5 if draw else 0

    winner['elo'] += k_factor * (score_winner - expected_win_winner)
    loser['elo'] += k_factor * (score_loser - expected_win_loser)

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
        update_elo_ratings(player1, player2)
    elif result < win_prob + (1 - win_prob) / 2:
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
        update_elo_ratings(player1, player2, draw=True)
    else:
        player2['points'] += 1  # Player 2 wins
        update_elo_ratings(player2, player1)

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

def print_round_statistics(players, round_number):
    """ Print statistics after each round """
    print(f"\nAfter Round {round_number}:")
    for player in players:
        print(f"{player['name']} - Points: {player['points']}, Elo: {player['elo']:.2f}")

def simulate_tournament():
    """ Simulate a single Swiss-system tournament """
    # Reset points and opponents for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []
        player['elo'] = random.randint(1400, 2600)  # Reset Elo for each simulation

    # Simulate rounds
    for round_number in range(1, num_rounds + 1):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)
        print_round_statistics(players, round_number)

    # Determine winner (most points)
    winner = max(players, key=lambda x: x['points'])
    return winner['name']

# Simulate and Print Results
for _ in range(num_simulations):
    simulate_tournament()
# Out:
# After Round 1:
# Player 0 - Points: 1, Elo: 2369.40
# Player 1 - Points: 0, Elo: 2185.60
# Player 2 - Points: 0.5, Elo: 1593.21
# Player 3 - Points: 0.5, Elo: 2129.79
# Player 4 - Points: 1, Elo: 1914.44
# Player 5 - Points: 0, Elo: 1634.56
# Player 6 - Points: 0, Elo: 1914.54
# Player 7 - Points: 1, Elo: 2140.46
# Player 8 - Points: 0.5, Elo: 2302.78
# Player 9 - Points: 0.5, Elo: 2520.22
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2370.75
# Player 1 - Points: 0, Elo: 2183.06
# Player 2 - Points: 0.5, Elo: 1592.39
# Player 3 - Points: 1.0, Elo: 2134.39
# Player 4 - Points: 1, Elo: 1913.08
# Player 5 - Points: 0.5, Elo: 1641.23
# Player 6 - Points: 0.5, Elo: 1907.87
# Player 7 - Points: 2, Elo: 2141.28
# Player 8 - Points: 1.0, Elo: 2298.17
# Player 9 - Points: 1.5, Elo: 2522.77
#
# After Round 3:
# Player 0 - Points: 3, Elo: 2374.97
# Player 1 - Points: 0.5, Elo: 2176.47
# Player 2 - Points: 1.5, Elo: 1603.79
# Player 3 - Points: 1.0, Elo: 2132.46
# Player 4 - Points: 1.5, Elo: 1921.12
# Player 5 - Points: 0.5, Elo: 1629.84
# Player 6 - Points: 1.0, Elo: 1914.47
# Player 7 - Points: 2, Elo: 2137.07
# Player 8 - Points: 1.5, Elo: 2290.14
# Player 9 - Points: 2.5, Elo: 2524.70
#
# After Round 4:
# Player 0 - Points: 3.5, Elo: 2379.03
# Player 1 - Points: 1.5, Elo: 2177.29
# Player 2 - Points: 2.0, Elo: 1613.41
# Player 3 - Points: 2.0, Elo: 2136.90
# Player 4 - Points: 1.5, Elo: 1916.64
# Player 5 - Points: 0.5, Elo: 1629.01
# Player 6 - Points: 1.0, Elo: 1910.03
# Player 7 - Points: 3, Elo: 2141.54
# Player 8 - Points: 2.0, Elo: 2280.52
# Player 9 - Points: 3.0, Elo: 2520.64
#
# After Round 5:
# Player 0 - Points: 4.5, Elo: 2379.27
# Player 1 - Points: 2.0, Elo: 2176.13
# Player 2 - Points: 2.0, Elo: 1613.17
# Player 3 - Points: 2.5, Elo: 2138.05
# Player 4 - Points: 1.5, Elo: 1916.64
# Player 5 - Points: 0.5, Elo: 1629.01
# Player 6 - Points: 1.5, Elo: 1917.91
# Player 7 - Points: 3, Elo: 2139.52
# Player 8 - Points: 2.5, Elo: 2272.63
# Player 9 - Points: 4.0, Elo: 2522.66
#
# After Round 1:
# Player 0 - Points: 0, Elo: 1517.68
# Player 1 - Points: 1, Elo: 1980.32
# Player 2 - Points: 0, Elo: 1785.51
# Player 3 - Points: 1, Elo: 1756.49
# Player 4 - Points: 0.5, Elo: 2270.78
# Player 5 - Points: 0.5, Elo: 2488.22
# Player 6 - Points: 0.5, Elo: 2375.58
# Player 7 - Points: 0.5, Elo: 2498.42
# Player 8 - Points: 1, Elo: 2283.14
# Player 9 - Points: 0, Elo: 1426.86
#
# After Round 2:
# Player 0 - Points: 0, Elo: 1517.61
# Player 1 - Points: 2, Elo: 1984.64
# Player 2 - Points: 1, Elo: 1787.77
# Player 3 - Points: 1, Elo: 1752.16
# Player 4 - Points: 1.0, Elo: 2271.13
# Player 5 - Points: 1.5, Elo: 2495.09
# Player 6 - Points: 0.5, Elo: 2368.71
# Player 7 - Points: 1.5, Elo: 2498.49
# Player 8 - Points: 1.5, Elo: 2282.79
# Player 9 - Points: 0, Elo: 1424.60
#
# After Round 3:
# Player 0 - Points: 1, Elo: 1524.99
# Player 1 - Points: 2.5, Elo: 1993.64
# Player 2 - Points: 1.5, Elo: 1796.60
# Player 3 - Points: 1.5, Elo: 1761.60
# Player 4 - Points: 1.5, Elo: 2262.30
# Player 5 - Points: 2.0, Elo: 2486.09
# Player 6 - Points: 1.0, Elo: 2359.27
# Player 7 - Points: 2.5, Elo: 2502.98
# Player 8 - Points: 1.5, Elo: 2278.31
# Player 9 - Points: 0, Elo: 1417.22
#
# After Round 4:
# Player 0 - Points: 1, Elo: 1524.73
# Player 1 - Points: 3.5, Elo: 2012.63
# Player 2 - Points: 1.5, Elo: 1796.23
# Player 3 - Points: 1.5, Elo: 1760.54
# Player 4 - Points: 2.5, Elo: 2263.36
# Player 5 - Points: 3.0, Elo: 2486.47
# Player 6 - Points: 2.0, Elo: 2359.36
# Player 7 - Points: 2.5, Elo: 2483.99
# Player 8 - Points: 2.5, Elo: 2278.56
# Player 9 - Points: 0, Elo: 1417.13
#
# After Round 5:
# Player 0 - Points: 1.5, Elo: 1531.27
# Player 1 - Points: 4.5, Elo: 2028.81
# Player 2 - Points: 2.0, Elo: 1789.69
# Player 3 - Points: 1.5, Elo: 1742.98
# Player 4 - Points: 2.5, Elo: 2247.18
# Player 5 - Points: 3.5, Elo: 2486.39
# Player 6 - Points: 3.0, Elo: 2367.07
# Player 7 - Points: 3.0, Elo: 2484.06
# Player 8 - Points: 2.5, Elo: 2270.85
# Player 9 - Points: 1, Elo: 1434.70
#
# After Round 1:
# Player 0 - Points: 0, Elo: 1697.63
# Player 1 - Points: 1, Elo: 1882.37
# Player 2 - Points: 1, Elo: 2205.57
# Player 3 - Points: 0, Elo: 1591.43
# Player 4 - Points: 0.5, Elo: 1811.29
# Player 5 - Points: 0.5, Elo: 2206.71
# Player 6 - Points: 0.5, Elo: 2157.17
# Player 7 - Points: 0.5, Elo: 2455.83
# Player 8 - Points: 0, Elo: 1985.21
# Player 9 - Points: 1, Elo: 2152.79
#
# After Round 2:
# Player 0 - Points: 0, Elo: 1697.38
# Player 1 - Points: 1, Elo: 1879.68
# Player 2 - Points: 2, Elo: 2208.26
# Player 3 - Points: 0, Elo: 1589.55
# Player 4 - Points: 0.5, Elo: 1808.84
# Player 5 - Points: 1.0, Elo: 2205.29
# Player 6 - Points: 1.0, Elo: 2158.58
# Player 7 - Points: 1.5, Elo: 2456.08
# Player 8 - Points: 1, Elo: 1987.09
# Player 9 - Points: 2, Elo: 2155.25
#
# After Round 3:
# Player 0 - Points: 1, Elo: 1704.37
# Player 1 - Points: 1, Elo: 1878.98
# Player 2 - Points: 2.5, Elo: 2206.75
# Player 3 - Points: 0, Elo: 1582.56
# Player 4 - Points: 0.5, Elo: 1806.48
# Player 5 - Points: 2.0, Elo: 2209.72
# Player 6 - Points: 2.0, Elo: 2160.94
# Player 7 - Points: 2.5, Elo: 2456.78
# Player 8 - Points: 1, Elo: 1982.66
# Player 9 - Points: 2.5, Elo: 2156.76
#
# After Round 4:
# Player 0 - Points: 1, Elo: 1703.02
# Player 1 - Points: 1.5, Elo: 1881.88
# Player 2 - Points: 2.5, Elo: 2202.92
# Player 3 - Points: 0, Elo: 1578.24
# Player 4 - Points: 1.5, Elo: 1810.80
# Player 5 - Points: 2.0, Elo: 2198.21
# Player 6 - Points: 3.0, Elo: 2162.29
# Player 7 - Points: 3.5, Elo: 2460.62
# Player 8 - Points: 1.5, Elo: 1979.76
# Player 9 - Points: 3.5, Elo: 2168.27
#
# After Round 5:
# Player 0 - Points: 1, Elo: 1703.02
# Player 1 - Points: 1.5, Elo: 1879.09
# Player 2 - Points: 3.5, Elo: 2211.75
# Player 3 - Points: 0, Elo: 1578.24
# Player 4 - Points: 1.5, Elo: 1805.31
# Player 5 - Points: 3.0, Elo: 2201.00
# Player 6 - Points: 3.0, Elo: 2153.45
# Player 7 - Points: 4.5, Elo: 2463.75
# Player 8 - Points: 2.5, Elo: 1985.24
# Player 9 - Points: 3.5, Elo: 2165.14
#
# After Round 1:
# Player 0 - Points: 0, Elo: 2195.83
# Player 1 - Points: 1, Elo: 2311.17
# Player 2 - Points: 1, Elo: 2103.58
# Player 3 - Points: 0, Elo: 1491.42
# Player 4 - Points: 1, Elo: 2469.14
# Player 5 - Points: 0, Elo: 1607.86
# Player 6 - Points: 0, Elo: 2049.82
# Player 7 - Points: 1, Elo: 2130.18
# Player 8 - Points: 0.5, Elo: 2177.60
# Player 9 - Points: 0.5, Elo: 2197.40
#
# After Round 2:
# Player 0 - Points: 1, Elo: 2205.30
# Player 1 - Points: 2, Elo: 2315.82
# Player 2 - Points: 1, Elo: 2098.93
# Player 3 - Points: 0, Elo: 1491.09
# Player 4 - Points: 1, Elo: 2451.63
# Player 5 - Points: 0.5, Elo: 1616.40
# Player 6 - Points: 0.5, Elo: 2041.28
# Player 7 - Points: 2, Elo: 2147.69
# Player 8 - Points: 0.5, Elo: 2168.13
# Player 9 - Points: 1.5, Elo: 2197.73
#
# After Round 3:
# Player 0 - Points: 2, Elo: 2215.09
# Player 1 - Points: 2.5, Elo: 2311.33
# Player 2 - Points: 2, Elo: 2116.61
# Player 3 - Points: 0.5, Elo: 1500.28
# Player 4 - Points: 1, Elo: 2433.95
# Player 5 - Points: 0.5, Elo: 1615.60
# Player 6 - Points: 1.0, Elo: 2032.09
# Player 7 - Points: 2.5, Elo: 2152.18
# Player 8 - Points: 1.5, Elo: 2168.93
# Player 9 - Points: 1.5, Elo: 2187.95
#
# After Round 4:
# Player 0 - Points: 3, Elo: 2223.29
# Player 1 - Points: 3.5, Elo: 2317.44
# Player 2 - Points: 2.5, Elo: 2118.63
# Player 3 - Points: 1.5, Elo: 1513.48
# Player 4 - Points: 2, Elo: 2435.75
# Player 5 - Points: 0.5, Elo: 1602.40
# Player 6 - Points: 1.0, Elo: 2030.29
# Player 7 - Points: 2.5, Elo: 2143.97
# Player 8 - Points: 1.5, Elo: 2162.81
# Player 9 - Points: 2.0, Elo: 2185.93
#
# After Round 5:
# Player 0 - Points: 3, Elo: 2210.37
# Player 1 - Points: 4.5, Elo: 2330.72
# Player 2 - Points: 3.5, Elo: 2131.56
# Player 3 - Points: 2.0, Elo: 1523.01
# Player 4 - Points: 2, Elo: 2422.47
# Player 5 - Points: 0.5, Elo: 1602.40
# Player 6 - Points: 1.0, Elo: 2030.29
# Player 7 - Points: 3.0, Elo: 2145.18
# Player 8 - Points: 2.0, Elo: 2153.28
# Player 9 - Points: 2.5, Elo: 2184.73
#
# After Round 1:
# Player 0 - Points: 0, Elo: 2142.37
# Player 1 - Points: 1, Elo: 2141.63
# Player 2 - Points: 1, Elo: 2026.94
# Player 3 - Points: 0, Elo: 1903.06
# Player 4 - Points: 0.5, Elo: 1842.92
# Player 5 - Points: 0.5, Elo: 2125.08
# Player 6 - Points: 1, Elo: 2509.87
# Player 7 - Points: 0, Elo: 2111.13
# Player 8 - Points: 1, Elo: 2559.70
# Player 9 - Points: 0, Elo: 1982.30
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 2135.40
# Player 1 - Points: 2, Elo: 2148.45
# Player 2 - Points: 1, Elo: 2020.12
# Player 3 - Points: 1, Elo: 1918.71
# Player 4 - Points: 1.0, Elo: 1849.89
# Player 5 - Points: 0.5, Elo: 2109.44
# Player 6 - Points: 1.5, Elo: 2511.29
# Player 7 - Points: 1, Elo: 2117.59
# Player 8 - Points: 1.5, Elo: 2558.28
# Player 9 - Points: 0, Elo: 1975.85
#
# After Round 3:
# Player 0 - Points: 0.5, Elo: 2124.88
# Player 1 - Points: 2.5, Elo: 2156.24
# Player 2 - Points: 1, Elo: 2019.26
# Player 3 - Points: 1.5, Elo: 1916.75
# Player 4 - Points: 1.5, Elo: 1851.85
# Player 5 - Points: 0.5, Elo: 2095.77
# Player 6 - Points: 2.0, Elo: 2503.49
# Player 7 - Points: 2, Elo: 2128.10
# Player 8 - Points: 2.5, Elo: 2559.14
# Player 9 - Points: 1, Elo: 1989.51
#
# After Round 4:
# Player 0 - Points: 0.5, Elo: 2114.05
# Player 1 - Points: 3.0, Elo: 2164.45
# Player 2 - Points: 1.5, Elo: 2018.40
# Player 3 - Points: 1.5, Elo: 1916.09
# Player 4 - Points: 1.5, Elo: 1848.46
# Player 5 - Points: 1.5, Elo: 2106.61
# Player 6 - Points: 3.0, Elo: 2504.15
# Player 7 - Points: 3, Elo: 2131.49
# Player 8 - Points: 3.0, Elo: 2550.93
# Player 9 - Points: 1.5, Elo: 1990.37
#
# After Round 5:
# Player 0 - Points: 0.5, Elo: 2114.05
# Player 1 - Points: 3.0, Elo: 2153.51
# Player 2 - Points: 1.5, Elo: 2017.25
# Player 3 - Points: 1.5, Elo: 1915.59
# Player 4 - Points: 2.5, Elo: 1862.33
# Player 5 - Points: 1.5, Elo: 2106.61
# Player 6 - Points: 4.0, Elo: 2505.31
# Player 7 - Points: 4, Elo: 2142.43
# Player 8 - Points: 4.0, Elo: 2551.44
# Player 9 - Points: 1.5, Elo: 1976.50
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2517.46
# Player 1 - Points: 0, Elo: 2072.54
# Player 2 - Points: 1, Elo: 2142.75
# Player 3 - Points: 0, Elo: 1577.25
# Player 4 - Points: 0.5, Elo: 1481.11
# Player 5 - Points: 0.5, Elo: 1775.89
# Player 6 - Points: 0.5, Elo: 1626.15
# Player 7 - Points: 0.5, Elo: 2149.85
# Player 8 - Points: 0, Elo: 1734.98
# Player 9 - Points: 1, Elo: 1935.02
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2519.53
# Player 1 - Points: 0.5, Elo: 2074.73
# Player 2 - Points: 1, Elo: 2140.68
# Player 3 - Points: 0, Elo: 1571.50
# Player 4 - Points: 0.5, Elo: 1479.74
# Player 5 - Points: 0.5, Elo: 1761.83
# Player 6 - Points: 1.5, Elo: 1640.22
# Player 7 - Points: 1.0, Elo: 2147.66
# Player 8 - Points: 1, Elo: 1740.73
# Player 9 - Points: 2, Elo: 1936.38
#
# After Round 3:
# Player 0 - Points: 3, Elo: 2520.20
# Player 1 - Points: 1.5, Elo: 2075.36
# Player 2 - Points: 2, Elo: 2141.74
# Player 3 - Points: 0, Elo: 1566.49
# Player 4 - Points: 0.5, Elo: 1479.11
# Player 5 - Points: 1.5, Elo: 1766.84
# Player 6 - Points: 1.5, Elo: 1639.15
# Player 7 - Points: 2.0, Elo: 2149.41
# Player 8 - Points: 1, Elo: 1738.98
# Player 9 - Points: 2, Elo: 1935.71
#
# After Round 4:
# Player 0 - Points: 4, Elo: 2522.32
# Player 1 - Points: 2.5, Elo: 2078.26
# Player 2 - Points: 2, Elo: 2126.42
# Player 3 - Points: 0, Elo: 1554.03
# Player 4 - Points: 1.5, Elo: 1491.58
# Player 5 - Points: 1.5, Elo: 1763.94
# Player 6 - Points: 1.5, Elo: 1631.95
# Player 7 - Points: 2.0, Elo: 2147.29
# Player 8 - Points: 2, Elo: 1746.18
# Player 9 - Points: 3, Elo: 1951.03
#
# After Round 5:
# Player 0 - Points: 5, Elo: 2522.55
# Player 1 - Points: 2.5, Elo: 2064.75
# Player 2 - Points: 3, Elo: 2137.02
# Player 3 - Points: 0, Elo: 1554.03
# Player 4 - Points: 2.0, Elo: 1495.41
# Player 5 - Points: 1.5, Elo: 1763.94
# Player 6 - Points: 2.0, Elo: 1628.12
# Player 7 - Points: 2.0, Elo: 2136.69
# Player 8 - Points: 2, Elo: 1745.95
# Player 9 - Points: 4, Elo: 1964.54
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1619.89
# Player 1 - Points: 0.5, Elo: 2500.11
# Player 2 - Points: 0.5, Elo: 1552.69
# Player 3 - Points: 0.5, Elo: 1820.31
# Player 4 - Points: 0, Elo: 1409.92
# Player 5 - Points: 1, Elo: 1910.08
# Player 6 - Points: 0, Elo: 2458.71
# Player 7 - Points: 1, Elo: 2535.29
# Player 8 - Points: 1, Elo: 2373.92
# Player 9 - Points: 0, Elo: 1845.08
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 1619.63
# Player 1 - Points: 1.5, Elo: 2500.20
# Player 2 - Points: 0.5, Elo: 1552.60
# Player 3 - Points: 1.5, Elo: 1822.03
# Player 4 - Points: 0, Elo: 1408.20
# Player 5 - Points: 1.5, Elo: 1919.54
# Player 6 - Points: 1, Elo: 2459.28
# Player 7 - Points: 1.5, Elo: 2525.82
# Player 8 - Points: 2, Elo: 2374.18
# Player 9 - Points: 0, Elo: 1844.51
#
# After Round 3:
# Player 0 - Points: 0.5, Elo: 1619.52
# Player 1 - Points: 2.5, Elo: 2506.72
# Player 2 - Points: 0.5, Elo: 1552.50
# Player 3 - Points: 2.0, Elo: 1824.77
# Player 4 - Points: 0, Elo: 1406.70
# Player 5 - Points: 2.0, Elo: 1916.81
# Player 6 - Points: 2, Elo: 2459.39
# Player 7 - Points: 2.5, Elo: 2525.93
# Player 8 - Points: 2, Elo: 2367.65
# Player 9 - Points: 1, Elo: 1846.01
#
# After Round 4:
# Player 0 - Points: 0.5, Elo: 1615.25
# Player 1 - Points: 2.5, Elo: 2497.27
# Player 2 - Points: 1.5, Elo: 1558.53
# Player 3 - Points: 2.5, Elo: 1834.26
# Player 4 - Points: 0, Elo: 1400.67
# Player 5 - Points: 2.5, Elo: 1925.42
# Player 6 - Points: 2.5, Elo: 2449.89
# Player 7 - Points: 3.5, Elo: 2535.38
# Player 8 - Points: 2.5, Elo: 2359.04
# Player 9 - Points: 2, Elo: 1850.28
#
# After Round 5:
# Player 0 - Points: 1.5, Elo: 1619.76
# Player 1 - Points: 3.5, Elo: 2497.99
# Player 2 - Points: 1.5, Elo: 1555.39
# Player 3 - Points: 2.5, Elo: 1833.92
# Player 4 - Points: 0, Elo: 1396.16
# Player 5 - Points: 2.5, Elo: 1924.70
# Player 6 - Points: 3.5, Elo: 2457.33
# Player 7 - Points: 4.5, Elo: 2535.73
# Player 8 - Points: 2.5, Elo: 2351.60
# Player 9 - Points: 3, Elo: 1853.43
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2597.73
# Player 1 - Points: 0, Elo: 2028.27
# Player 2 - Points: 1, Elo: 2483.88
# Player 3 - Points: 0, Elo: 2460.12
# Player 4 - Points: 0.5, Elo: 1447.99
# Player 5 - Points: 0.5, Elo: 1939.01
# Player 6 - Points: 0, Elo: 2550.93
# Player 7 - Points: 1, Elo: 2387.07
# Player 8 - Points: 1, Elo: 2064.96
# Player 9 - Points: 0, Elo: 1675.04
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2604.57
# Player 1 - Points: 0, Elo: 2008.95
# Player 2 - Points: 1, Elo: 2477.05
# Player 3 - Points: 0.5, Elo: 2451.06
# Player 4 - Points: 1.5, Elo: 1467.30
# Player 5 - Points: 1.0, Elo: 1948.06
# Player 6 - Points: 1, Elo: 2551.06
# Player 7 - Points: 2, Elo: 2389.78
# Player 8 - Points: 1, Elo: 2062.25
# Player 9 - Points: 0, Elo: 1674.92
#
# After Round 3:
# Player 0 - Points: 3, Elo: 2609.07
# Player 1 - Points: 1, Elo: 2011.50
# Player 2 - Points: 2, Elo: 2477.11
# Player 3 - Points: 1.0, Elo: 2442.99
# Player 4 - Points: 1.5, Elo: 1467.24
# Player 5 - Points: 1.0, Elo: 1947.46
# Player 6 - Points: 2, Elo: 2551.66
# Player 7 - Points: 2, Elo: 2385.27
# Player 8 - Points: 1.5, Elo: 2070.32
# Player 9 - Points: 0, Elo: 1672.36
#
# After Round 4:
# Player 0 - Points: 4, Elo: 2617.43
# Player 1 - Points: 1, Elo: 2009.96
# Player 2 - Points: 2, Elo: 2464.53
# Player 3 - Points: 2.0, Elo: 2444.53
# Player 4 - Points: 1.5, Elo: 1466.64
# Player 5 - Points: 1.0, Elo: 1930.87
# Player 6 - Points: 2, Elo: 2543.30
# Player 7 - Points: 3, Elo: 2397.86
# Player 8 - Points: 2.5, Elo: 2070.92
# Player 9 - Points: 1, Elo: 1688.96
#
# After Round 5:
# Player 0 - Points: 5, Elo: 2618.26
# Player 1 - Points: 1, Elo: 1997.72
# Player 2 - Points: 3, Elo: 2476.75
# Player 3 - Points: 3.0, Elo: 2453.20
# Player 4 - Points: 1.5, Elo: 1462.29
# Player 5 - Points: 2.0, Elo: 1943.11
# Player 6 - Points: 2, Elo: 2531.07
# Player 7 - Points: 3, Elo: 2389.19
# Player 8 - Points: 2.5, Elo: 2070.10
# Player 9 - Points: 2, Elo: 1693.31
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1418.54
# Player 1 - Points: 0.5, Elo: 2051.46
# Player 2 - Points: 0.5, Elo: 1718.71
# Player 3 - Points: 0.5, Elo: 2434.29
# Player 4 - Points: 1, Elo: 2419.88
# Player 5 - Points: 0, Elo: 2022.12
# Player 6 - Points: 1, Elo: 2438.71
# Player 7 - Points: 0, Elo: 2475.29
# Player 8 - Points: 1, Elo: 2168.67
# Player 9 - Points: 0, Elo: 1582.33
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 1418.28
# Player 1 - Points: 1.5, Elo: 2054.03
# Player 2 - Points: 0.5, Elo: 1716.15
# Player 3 - Points: 1.5, Elo: 2435.99
# Player 4 - Points: 2, Elo: 2430.42
# Player 5 - Points: 0, Elo: 2020.42
# Player 6 - Points: 1, Elo: 2428.17
# Player 7 - Points: 1, Elo: 2475.41
# Player 8 - Points: 2, Elo: 2168.93
# Player 9 - Points: 0, Elo: 1582.22
#
# After Round 3:
# Player 0 - Points: 0.5, Elo: 1418.22
# Player 1 - Points: 2.0, Elo: 2062.03
# Player 2 - Points: 0.5, Elo: 1715.90
# Player 3 - Points: 2.0, Elo: 2427.99
# Player 4 - Points: 2, Elo: 2414.05
# Player 5 - Points: 0.5, Elo: 2011.90
# Player 6 - Points: 2, Elo: 2428.23
# Player 7 - Points: 2, Elo: 2475.66
# Player 8 - Points: 3, Elo: 2185.30
# Player 9 - Points: 0.5, Elo: 1590.73
#
# After Round 4:
# Player 0 - Points: 0.5, Elo: 1418.17
# Player 1 - Points: 2.0, Elo: 2055.43
# Player 2 - Points: 0.5, Elo: 1715.57
# Player 3 - Points: 3.0, Elo: 2437.59
# Player 4 - Points: 2, Elo: 2404.45
# Player 5 - Points: 0.5, Elo: 2011.90
# Player 6 - Points: 3, Elo: 2428.55
# Player 7 - Points: 3, Elo: 2475.70
# Player 8 - Points: 4, Elo: 2191.89
# Player 9 - Points: 0.5, Elo: 1590.73
#
# After Round 5:
# Player 0 - Points: 0.5, Elo: 1415.12
# Player 1 - Points: 2.0, Elo: 2053.34
# Player 2 - Points: 1.5, Elo: 1718.63
# Player 3 - Points: 3.5, Elo: 2431.50
# Player 4 - Points: 3, Elo: 2416.47
# Player 5 - Points: 0.5, Elo: 2011.90
# Player 6 - Points: 4, Elo: 2430.64
# Player 7 - Points: 3, Elo: 2463.68
# Player 8 - Points: 4.5, Elo: 2197.98
# Player 9 - Points: 0.5, Elo: 1590.73
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2396.63
# Player 1 - Points: 0, Elo: 1800.37
# Player 2 - Points: 0.5, Elo: 1697.74
# Player 3 - Points: 0.5, Elo: 1913.26
# Player 4 - Points: 0.5, Elo: 2151.32
# Player 5 - Points: 0.5, Elo: 2397.68
# Player 6 - Points: 0.5, Elo: 1820.60
# Player 7 - Points: 0.5, Elo: 1621.40
# Player 8 - Points: 1, Elo: 2096.98
# Player 9 - Points: 0, Elo: 1580.02
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2399.66
# Player 1 - Points: 1, Elo: 1810.95
# Player 2 - Points: 1.0, Elo: 1706.37
# Player 3 - Points: 1.0, Elo: 1922.10
# Player 4 - Points: 1.0, Elo: 2142.69
# Player 5 - Points: 1.0, Elo: 2388.83
# Player 6 - Points: 0.5, Elo: 1810.02
# Player 7 - Points: 1.5, Elo: 1630.22
# Player 8 - Points: 1, Elo: 2093.96
# Player 9 - Points: 0, Elo: 1571.20
#
# After Round 3:
# Player 0 - Points: 3, Elo: 2399.89
# Player 1 - Points: 2, Elo: 1818.03
# Player 2 - Points: 1.0, Elo: 1699.29
# Player 3 - Points: 1.5, Elo: 1927.72
# Player 4 - Points: 1.5, Elo: 2137.08
# Player 5 - Points: 2.0, Elo: 2391.93
# Player 6 - Points: 1.5, Elo: 1814.05
# Player 7 - Points: 1.5, Elo: 1629.98
# Player 8 - Points: 1, Elo: 2090.86
# Player 9 - Points: 0, Elo: 1567.17
#
# After Round 4:
# Player 0 - Points: 3.5, Elo: 2399.66
# Player 1 - Points: 2, Elo: 1811.09
# Player 2 - Points: 1.5, Elo: 1697.32
# Player 3 - Points: 2.5, Elo: 1934.66
# Player 4 - Points: 2.5, Elo: 2139.77
# Player 5 - Points: 2.5, Elo: 2392.16
# Player 6 - Points: 1.5, Elo: 1811.36
# Player 7 - Points: 2.0, Elo: 1631.95
# Player 8 - Points: 1, Elo: 2090.86
# Player 9 - Points: 0, Elo: 1567.17
#
# After Round 5:
# Player 0 - Points: 4.5, Elo: 2400.95
# Player 1 - Points: 2, Elo: 1808.46
# Player 2 - Points: 1.5, Elo: 1690.49
# Player 3 - Points: 2.5, Elo: 1933.37
# Player 4 - Points: 3.5, Elo: 2142.39
# Player 5 - Points: 3.5, Elo: 2392.41
# Player 6 - Points: 2.5, Elo: 1818.19
# Player 7 - Points: 2.0, Elo: 1631.70
# Player 8 - Points: 1, Elo: 2090.86
# Player 9 - Points: 0, Elo: 1567.17
#
# After Round 1:
# Player 0 - Points: 1, Elo: 1941.59
# Player 1 - Points: 0, Elo: 1512.41
# Player 2 - Points: 1, Elo: 1809.17
# Player 3 - Points: 0, Elo: 1977.83
# Player 4 - Points: 1, Elo: 1730.04
# Player 5 - Points: 0, Elo: 1609.96
# Player 6 - Points: 1, Elo: 1919.31
# Player 7 - Points: 0, Elo: 1631.69
# Player 8 - Points: 0, Elo: 1457.97
# Player 9 - Points: 1, Elo: 2573.03
#
# After Round 2:
# Player 0 - Points: 2, Elo: 1947.95
# Player 1 - Points: 0, Elo: 1512.37
# Player 2 - Points: 1, Elo: 1802.81
# Player 3 - Points: 1, Elo: 1979.97
# Player 4 - Points: 1.5, Elo: 1735.01
# Player 5 - Points: 0, Elo: 1607.81
# Player 6 - Points: 1.5, Elo: 1914.34
# Player 7 - Points: 0, Elo: 1617.07
# Player 8 - Points: 1, Elo: 1472.59
# Player 9 - Points: 2, Elo: 2573.08
#
# After Round 3:
# Player 0 - Points: 2.5, Elo: 1957.42
# Player 1 - Points: 0, Elo: 1501.23
# Player 2 - Points: 2, Elo: 1810.88
# Player 3 - Points: 1, Elo: 1968.11
# Player 4 - Points: 1.5, Elo: 1726.93
# Player 5 - Points: 0, Elo: 1598.08
# Player 6 - Points: 2.5, Elo: 1926.21
# Player 7 - Points: 1, Elo: 1626.80
# Player 8 - Points: 2, Elo: 1483.73
# Player 9 - Points: 2.5, Elo: 2563.61
#
# After Round 4:
# Player 0 - Points: 3.5, Elo: 1966.52
# Player 1 - Points: 0.5, Elo: 1503.95
# Player 2 - Points: 2, Elo: 1810.62
# Player 3 - Points: 2, Elo: 1970.57
# Player 4 - Points: 2.5, Elo: 1730.89
# Player 5 - Points: 0.5, Elo: 1595.36
# Player 6 - Points: 2.5, Elo: 1917.11
# Player 7 - Points: 1, Elo: 1624.34
# Player 8 - Points: 2, Elo: 1479.77
# Player 9 - Points: 3.5, Elo: 2563.87
#
# After Round 5:
# Player 0 - Points: 4.5, Elo: 1970.62
# Player 1 - Points: 0.5, Elo: 1502.67
# Player 2 - Points: 3, Elo: 1813.22
# Player 3 - Points: 3, Elo: 1971.84
# Player 4 - Points: 2.5, Elo: 1726.79
# Player 5 - Points: 0.5, Elo: 1595.36
# Player 6 - Points: 2.5, Elo: 1916.64
# Player 7 - Points: 1, Elo: 1624.34
# Player 8 - Points: 2, Elo: 1477.18
# Player 9 - Points: 4.5, Elo: 2564.34
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2394.29
# Player 1 - Points: 0, Elo: 1661.71
# Player 2 - Points: 1, Elo: 2449.65
# Player 3 - Points: 0, Elo: 2484.35
# Player 4 - Points: 1, Elo: 2293.20
# Player 5 - Points: 0, Elo: 1495.80
# Player 6 - Points: 0, Elo: 1523.95
# Player 7 - Points: 1, Elo: 2552.05
# Player 8 - Points: 0.5, Elo: 2052.63
# Player 9 - Points: 0.5, Elo: 2217.37
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2405.87
# Player 1 - Points: 0, Elo: 1659.80
# Player 2 - Points: 1, Elo: 2438.07
# Player 3 - Points: 1, Elo: 2487.89
# Player 4 - Points: 1.5, Elo: 2299.52
# Player 5 - Points: 1, Elo: 1506.61
# Player 6 - Points: 0, Elo: 1513.14
# Player 7 - Points: 1.5, Elo: 2545.73
# Player 8 - Points: 1.5, Elo: 2054.53
# Player 9 - Points: 0.5, Elo: 2213.83
#
# After Round 3:
# Player 0 - Points: 3, Elo: 2412.90
# Player 1 - Points: 0, Elo: 1659.63
# Player 2 - Points: 2, Elo: 2438.17
# Player 3 - Points: 2, Elo: 2488.05
# Player 4 - Points: 1.5, Elo: 2292.49
# Player 5 - Points: 1, Elo: 1506.51
# Player 6 - Points: 0, Elo: 1512.79
# Player 7 - Points: 2.5, Elo: 2546.85
# Player 8 - Points: 1.5, Elo: 2053.42
# Player 9 - Points: 1.5, Elo: 2214.18
#
# After Round 4:
# Player 0 - Points: 3, Elo: 2406.58
# Player 1 - Points: 1, Elo: 1665.64
# Player 2 - Points: 3, Elo: 2444.20
# Player 3 - Points: 3, Elo: 2489.57
# Player 4 - Points: 1.5, Elo: 2286.46
# Player 5 - Points: 1, Elo: 1506.18
# Player 6 - Points: 0, Elo: 1506.78
# Player 7 - Points: 3.5, Elo: 2553.17
# Player 8 - Points: 1.5, Elo: 2051.90
# Player 9 - Points: 2.5, Elo: 2214.52
#
# After Round 5:
# Player 0 - Points: 4, Elo: 2418.92
# Player 1 - Points: 1, Elo: 1665.64
# Player 2 - Points: 3, Elo: 2437.24
# Player 3 - Points: 3, Elo: 2477.22
# Player 4 - Points: 1.5, Elo: 2274.41
# Player 5 - Points: 1, Elo: 1505.35
# Player 6 - Points: 0, Elo: 1506.78
# Player 7 - Points: 4.5, Elo: 2560.14
# Player 8 - Points: 2.5, Elo: 2052.73
# Player 9 - Points: 3.5, Elo: 2226.56
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1545.32
# Player 1 - Points: 0.5, Elo: 1791.68
# Player 2 - Points: 0, Elo: 2503.45
# Player 3 - Points: 1, Elo: 2401.55
# Player 4 - Points: 0.5, Elo: 1789.04
# Player 5 - Points: 0.5, Elo: 2078.96
# Player 6 - Points: 1, Elo: 2336.42
# Player 7 - Points: 0, Elo: 2108.58
# Player 8 - Points: 1, Elo: 2570.06
# Player 9 - Points: 0, Elo: 1548.94
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 1545.27
# Player 1 - Points: 0.5, Elo: 1781.60
# Player 2 - Points: 1, Elo: 2505.05
# Player 3 - Points: 2, Elo: 2409.70
# Player 4 - Points: 1.5, Elo: 1799.11
# Player 5 - Points: 0.5, Elo: 2077.36
# Player 6 - Points: 1, Elo: 2328.27
# Player 7 - Points: 1, Elo: 2109.35
# Player 8 - Points: 2, Elo: 2570.11
# Player 9 - Points: 0, Elo: 1548.18
#
# After Round 3:
# Player 0 - Points: 0.5, Elo: 1545.05
# Player 1 - Points: 0.5, Elo: 1778.97
# Player 2 - Points: 1.5, Elo: 2495.38
# Player 3 - Points: 2, Elo: 2404.01
# Player 4 - Points: 2.0, Elo: 1808.78
# Player 5 - Points: 1.5, Elo: 2078.27
# Player 6 - Points: 2, Elo: 2328.49
# Player 7 - Points: 2, Elo: 2111.98
# Player 8 - Points: 3, Elo: 2575.80
# Player 9 - Points: 0, Elo: 1547.27
#
# After Round 4:
# Player 0 - Points: 0.5, Elo: 1544.16
# Player 1 - Points: 1.5, Elo: 1783.14
# Player 2 - Points: 1.5, Elo: 2480.92
# Player 3 - Points: 2.5, Elo: 2397.15
# Player 4 - Points: 2.0, Elo: 1808.54
# Player 5 - Points: 2.5, Elo: 2079.16
# Player 6 - Points: 3, Elo: 2342.95
# Player 7 - Points: 2.5, Elo: 2118.84
# Player 8 - Points: 4, Elo: 2576.03
# Player 9 - Points: 0, Elo: 1543.10
#
# After Round 5:
# Player 0 - Points: 0.5, Elo: 1534.13
# Player 1 - Points: 1.5, Elo: 1782.78
# Player 2 - Points: 2.5, Elo: 2481.27
# Player 3 - Points: 3.5, Elo: 2399.92
# Player 4 - Points: 2.0, Elo: 1805.67
# Player 5 - Points: 2.5, Elo: 2076.39
# Player 6 - Points: 3, Elo: 2338.81
# Player 7 - Points: 3.5, Elo: 2121.71
# Player 8 - Points: 5, Elo: 2580.18
# Player 9 - Points: 1, Elo: 1553.13
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1624.89
# Player 1 - Points: 0.5, Elo: 1848.11
# Player 2 - Points: 1, Elo: 2109.51
# Player 3 - Points: 0, Elo: 1474.49
# Player 4 - Points: 0, Elo: 1494.67
# Player 5 - Points: 1, Elo: 2205.33
# Player 6 - Points: 1, Elo: 2408.20
# Player 7 - Points: 0, Elo: 1610.80
# Player 8 - Points: 1, Elo: 1909.59
# Player 9 - Points: 0, Elo: 1638.41
#
# After Round 2:
# Player 0 - Points: 1.5, Elo: 1630.81
# Player 1 - Points: 1.5, Elo: 1850.42
# Player 2 - Points: 2, Elo: 2122.20
# Player 3 - Points: 0, Elo: 1468.57
# Player 4 - Points: 0, Elo: 1492.36
# Player 5 - Points: 1, Elo: 2192.64
# Player 6 - Points: 2, Elo: 2409.27
# Player 7 - Points: 1, Elo: 1621.59
# Player 8 - Points: 1, Elo: 1908.52
# Player 9 - Points: 0, Elo: 1627.62
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 1630.06
# Player 1 - Points: 2.5, Elo: 1854.65
# Player 2 - Points: 2, Elo: 2118.98
# Player 3 - Points: 0, Elo: 1467.10
# Player 4 - Points: 0, Elo: 1486.06
# Player 5 - Points: 2, Elo: 2193.40
# Player 6 - Points: 3, Elo: 2412.49
# Player 7 - Points: 1, Elo: 1617.37
# Player 8 - Points: 2, Elo: 1909.99
# Player 9 - Points: 1, Elo: 1633.91
#
# After Round 4:
# Player 0 - Points: 1.5, Elo: 1620.17
# Player 1 - Points: 2.5, Elo: 1853.87
# Player 2 - Points: 2.5, Elo: 2113.60
# Player 3 - Points: 0.5, Elo: 1467.64
# Player 4 - Points: 0.5, Elo: 1485.52
# Player 5 - Points: 3, Elo: 2194.10
# Player 6 - Points: 4, Elo: 2413.26
# Player 7 - Points: 1, Elo: 1616.67
# Player 8 - Points: 2.5, Elo: 1915.37
# Player 9 - Points: 2, Elo: 1643.80
#
# After Round 5:
# Player 0 - Points: 1.5, Elo: 1617.08
# Player 1 - Points: 3.5, Elo: 1870.21
# Player 2 - Points: 2.5, Elo: 2097.26
# Player 3 - Points: 0.5, Elo: 1462.32
# Player 4 - Points: 0.5, Elo: 1479.12
# Player 5 - Points: 3, Elo: 2189.68
# Player 6 - Points: 5, Elo: 2417.68
# Player 7 - Points: 2, Elo: 1623.06
# Player 8 - Points: 3.5, Elo: 1918.46
# Player 9 - Points: 3, Elo: 1649.12
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2385.10
# Player 1 - Points: 0, Elo: 1888.90
# Player 2 - Points: 1, Elo: 1772.51
# Player 3 - Points: 0, Elo: 1703.49
# Player 4 - Points: 0.5, Elo: 2427.19
# Player 5 - Points: 0.5, Elo: 1965.81
# Player 6 - Points: 1, Elo: 1502.30
# Player 7 - Points: 0, Elo: 1676.70
# Player 8 - Points: 1, Elo: 1893.45
# Player 9 - Points: 0, Elo: 1546.55
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2385.67
# Player 1 - Points: 0, Elo: 1888.04
# Player 2 - Points: 1, Elo: 1771.94
# Player 3 - Points: 0, Elo: 1699.87
# Player 4 - Points: 1.5, Elo: 2428.06
# Player 5 - Points: 1.5, Elo: 1969.43
# Player 6 - Points: 1, Elo: 1500.40
# Player 7 - Points: 1, Elo: 1683.12
# Player 8 - Points: 2, Elo: 1895.35
# Player 9 - Points: 0, Elo: 1540.13
#
# After Round 3:
# Player 0 - Points: 3, Elo: 2386.79
# Player 1 - Points: 0.5, Elo: 1882.74
# Player 2 - Points: 1, Elo: 1771.50
# Player 3 - Points: 0.5, Elo: 1695.57
# Player 4 - Points: 2.5, Elo: 2428.50
# Player 5 - Points: 2.5, Elo: 1970.68
# Player 6 - Points: 1, Elo: 1499.14
# Player 7 - Points: 1.5, Elo: 1688.42
# Player 8 - Points: 2, Elo: 1894.23
# Player 9 - Points: 0.5, Elo: 1544.43
#
# After Round 4:
# Player 0 - Points: 4, Elo: 2397.99
# Player 1 - Points: 1.0, Elo: 1874.72
# Player 2 - Points: 1, Elo: 1759.15
# Player 3 - Points: 0.5, Elo: 1695.57
# Player 4 - Points: 2.5, Elo: 2417.31
# Player 5 - Points: 3.5, Elo: 1978.52
# Player 6 - Points: 1.5, Elo: 1507.16
# Player 7 - Points: 2.5, Elo: 1700.76
# Player 8 - Points: 2, Elo: 1886.40
# Player 9 - Points: 0.5, Elo: 1544.43
#
# After Round 5:
# Player 0 - Points: 5, Elo: 2399.63
# Player 1 - Points: 1.5, Elo: 1875.06
# Player 2 - Points: 2, Elo: 1762.95
# Player 3 - Points: 0.5, Elo: 1695.57
# Player 4 - Points: 3.5, Elo: 2417.63
# Player 5 - Points: 3.5, Elo: 1976.88
# Player 6 - Points: 1.5, Elo: 1503.36
# Player 7 - Points: 2.5, Elo: 1700.45
# Player 8 - Points: 2.5, Elo: 1886.06
# Player 9 - Points: 0.5, Elo: 1544.43
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2534.06
# Player 1 - Points: 0, Elo: 1520.94
# Player 2 - Points: 0, Elo: 1671.77
# Player 3 - Points: 1, Elo: 1964.23
# Player 4 - Points: 0, Elo: 1684.66
# Player 5 - Points: 1, Elo: 2145.34
# Player 6 - Points: 0.5, Elo: 1705.40
# Player 7 - Points: 0.5, Elo: 2290.60
# Player 8 - Points: 1, Elo: 1936.94
# Player 9 - Points: 0, Elo: 1882.06
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2534.78
# Player 1 - Points: 1, Elo: 1535.80
# Player 2 - Points: 0, Elo: 1671.22
# Player 3 - Points: 1, Elo: 1963.51
# Player 4 - Points: 0.5, Elo: 1689.80
# Player 5 - Points: 2, Elo: 2149.97
# Player 6 - Points: 0.5, Elo: 1690.54
# Player 7 - Points: 1.5, Elo: 2291.15
# Player 8 - Points: 1, Elo: 1932.31
# Player 9 - Points: 0.5, Elo: 1876.92
#
# After Round 3:
# Player 0 - Points: 3, Elo: 2536.75
# Player 1 - Points: 1, Elo: 1535.55
# Player 2 - Points: 0.5, Elo: 1676.53
# Player 3 - Points: 1.5, Elo: 1962.61
# Player 4 - Points: 1.5, Elo: 1699.82
# Player 5 - Points: 2, Elo: 2148.00
# Player 6 - Points: 0.5, Elo: 1680.52
# Player 7 - Points: 2.5, Elo: 2291.41
# Player 8 - Points: 1.5, Elo: 1933.20
# Player 9 - Points: 1.0, Elo: 1871.61
#
# After Round 4:
# Player 0 - Points: 4, Elo: 2540.67
# Player 1 - Points: 1, Elo: 1533.02
# Player 2 - Points: 1.0, Elo: 1676.64
# Player 3 - Points: 2.5, Elo: 1977.49
# Player 4 - Points: 1.5, Elo: 1695.69
# Player 5 - Points: 2, Elo: 2133.12
# Player 6 - Points: 1.0, Elo: 1680.40
# Player 7 - Points: 2.5, Elo: 2287.49
# Player 8 - Points: 2.5, Elo: 1937.34
# Player 9 - Points: 2.0, Elo: 1874.13
#
# After Round 5:
# Player 0 - Points: 5, Elo: 2541.27
# Player 1 - Points: 1, Elo: 1527.39
# Player 2 - Points: 1.0, Elo: 1676.64
# Player 3 - Points: 3.0, Elo: 1984.62
# Player 4 - Points: 2.5, Elo: 1701.32
# Player 5 - Points: 2, Elo: 2116.79
# Player 6 - Points: 1.0, Elo: 1680.40
# Player 7 - Points: 3.0, Elo: 2280.36
# Player 8 - Points: 2.5, Elo: 1936.74
# Player 9 - Points: 3.0, Elo: 1890.46
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2527.08
# Player 1 - Points: 0, Elo: 2224.92
# Player 2 - Points: 1, Elo: 1992.69
# Player 3 - Points: 0, Elo: 1727.31
# Player 4 - Points: 0.5, Elo: 1857.65
# Player 5 - Points: 0.5, Elo: 2539.35
# Player 6 - Points: 0, Elo: 1675.19
# Player 7 - Points: 1, Elo: 2225.81
# Player 8 - Points: 0, Elo: 1643.91
# Player 9 - Points: 1, Elo: 2580.09
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2527.96
# Player 1 - Points: 1, Elo: 2227.08
# Player 2 - Points: 1, Elo: 1991.81
# Player 3 - Points: 0, Elo: 1727.12
# Player 4 - Points: 0.5, Elo: 1855.50
# Player 5 - Points: 1.5, Elo: 2539.53
# Player 6 - Points: 1, Elo: 1684.29
# Player 7 - Points: 1, Elo: 2223.51
# Player 8 - Points: 0, Elo: 1634.81
# Player 9 - Points: 2, Elo: 2582.39
#
# After Round 3:
# Player 0 - Points: 3, Elo: 2539.52
# Player 1 - Points: 1, Elo: 2224.24
# Player 2 - Points: 2, Elo: 1994.72
# Player 3 - Points: 0, Elo: 1714.53
# Player 4 - Points: 0.5, Elo: 1853.35
# Player 5 - Points: 2.5, Elo: 2542.37
# Player 6 - Points: 1, Elo: 1681.38
# Player 7 - Points: 2, Elo: 2225.66
# Player 8 - Points: 1, Elo: 1647.40
# Player 9 - Points: 2, Elo: 2570.84
#
# After Round 4:
# Player 0 - Points: 4, Elo: 2549.60
# Player 1 - Points: 1, Elo: 2221.84
# Player 2 - Points: 2.5, Elo: 2000.54
# Player 3 - Points: 0, Elo: 1714.53
# Player 4 - Points: 1.5, Elo: 1858.77
# Player 5 - Points: 2.5, Elo: 2532.29
# Player 6 - Points: 1, Elo: 1675.96
# Player 7 - Points: 2.5, Elo: 2219.84
# Player 8 - Points: 1, Elo: 1647.40
# Player 9 - Points: 3, Elo: 2573.23
#
# After Round 5:
# Player 0 - Points: 5, Elo: 2552.20
# Player 1 - Points: 2, Elo: 2222.86
# Player 2 - Points: 2.5, Elo: 1999.82
# Player 3 - Points: 0, Elo: 1713.50
# Player 4 - Points: 2.5, Elo: 1863.34
# Player 5 - Points: 3.5, Elo: 2532.43
# Player 6 - Points: 1, Elo: 1675.82
# Player 7 - Points: 2.5, Elo: 2217.24
# Player 8 - Points: 1, Elo: 1642.83
# Player 9 - Points: 4, Elo: 2573.95
#
# After Round 1:
# Player 0 - Points: 1, Elo: 1824.00
# Player 1 - Points: 0, Elo: 1985.00
# Player 2 - Points: 1, Elo: 2265.67
# Player 3 - Points: 0, Elo: 2335.33
# Player 4 - Points: 0.5, Elo: 2381.83
# Player 5 - Points: 0.5, Elo: 2477.17
# Player 6 - Points: 0.5, Elo: 1671.31
# Player 7 - Points: 0.5, Elo: 1648.69
# Player 8 - Points: 1, Elo: 2163.31
# Player 9 - Points: 0, Elo: 1698.69
#
# After Round 2:
# Player 0 - Points: 1.5, Elo: 1832.54
# Player 1 - Points: 0.5, Elo: 1977.52
# Player 2 - Points: 1.5, Elo: 2257.13
# Player 3 - Points: 1, Elo: 2335.83
# Player 4 - Points: 1.5, Elo: 2386.25
# Player 5 - Points: 1.5, Elo: 2477.36
# Player 6 - Points: 0.5, Elo: 1671.12
# Player 7 - Points: 1.0, Elo: 1656.17
# Player 8 - Points: 1, Elo: 2158.88
# Player 9 - Points: 0, Elo: 1698.19
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 1831.75
# Player 1 - Points: 0.5, Elo: 1972.31
# Player 2 - Points: 1.5, Elo: 2252.73
# Player 3 - Points: 2, Elo: 2336.22
# Player 4 - Points: 2.5, Elo: 2387.05
# Player 5 - Points: 2.5, Elo: 2481.76
# Player 6 - Points: 1.0, Elo: 1671.90
# Player 7 - Points: 1.0, Elo: 1655.78
# Player 8 - Points: 2, Elo: 2164.09
# Player 9 - Points: 0.5, Elo: 1697.41
#
# After Round 4:
# Player 0 - Points: 2.5, Elo: 1837.45
# Player 1 - Points: 1.0, Elo: 1965.72
# Player 2 - Points: 2.5, Elo: 2253.36
# Player 3 - Points: 2, Elo: 2327.68
# Player 4 - Points: 3.5, Elo: 2395.59
# Player 5 - Points: 3.5, Elo: 2484.52
# Player 6 - Points: 1.0, Elo: 1666.20
# Player 7 - Points: 1.0, Elo: 1655.15
# Player 8 - Points: 2, Elo: 2161.32
# Player 9 - Points: 1.0, Elo: 1704.01
#
# After Round 5:
# Player 0 - Points: 2.5, Elo: 1836.98
# Player 1 - Points: 2.0, Elo: 1968.75
# Player 2 - Points: 3.0, Elo: 2257.24
# Player 3 - Points: 3, Elo: 2333.22
# Player 4 - Points: 4.0, Elo: 2391.72
# Player 5 - Points: 4.5, Elo: 2485.00
# Player 6 - Points: 1.0, Elo: 1663.17
# Player 7 - Points: 2.0, Elo: 1666.55
# Player 8 - Points: 2, Elo: 2155.77
# Player 9 - Points: 1.0, Elo: 1692.61
#
# After Round 1:
# Player 0 - Points: 0, Elo: 1967.70
# Player 1 - Points: 1, Elo: 1679.30
# Player 2 - Points: 0.5, Elo: 2114.80
# Player 3 - Points: 0.5, Elo: 2389.20
# Player 4 - Points: 0.5, Elo: 2086.74
# Player 5 - Points: 0.5, Elo: 2357.26
# Player 6 - Points: 0, Elo: 2029.38
# Player 7 - Points: 1, Elo: 2454.62
# Player 8 - Points: 0.5, Elo: 1410.81
# Player 9 - Points: 0.5, Elo: 2199.19
#
# After Round 2:
# Player 0 - Points: 1, Elo: 1968.47
# Player 1 - Points: 1.5, Elo: 1689.08
# Player 2 - Points: 1.0, Elo: 2113.99
# Player 3 - Points: 0.5, Elo: 2378.28
# Player 4 - Points: 1.0, Elo: 2087.54
# Player 5 - Points: 1.5, Elo: 2368.18
# Player 6 - Points: 0, Elo: 2023.91
# Player 7 - Points: 1.5, Elo: 2444.85
# Player 8 - Points: 0.5, Elo: 1410.03
# Player 9 - Points: 1.5, Elo: 2204.66
#
# After Round 3:
# Player 0 - Points: 1, Elo: 1962.43
# Player 1 - Points: 1.5, Elo: 1688.68
# Player 2 - Points: 2.0, Elo: 2120.03
# Player 3 - Points: 1.5, Elo: 2381.44
# Player 4 - Points: 1.0, Elo: 2084.38
# Player 5 - Points: 2.5, Elo: 2368.57
# Player 6 - Points: 0.5, Elo: 2014.48
# Player 7 - Points: 2.5, Elo: 2448.86
# Player 8 - Points: 1.0, Elo: 1419.46
# Player 9 - Points: 1.5, Elo: 2200.65
#
# After Round 4:
# Player 0 - Points: 1.5, Elo: 1965.81
# Player 1 - Points: 1.5, Elo: 1687.14
# Player 2 - Points: 3.0, Elo: 2121.57
# Player 3 - Points: 2.5, Elo: 2386.66
# Player 4 - Points: 1.5, Elo: 2081.01
# Player 5 - Points: 3.5, Elo: 2380.84
# Player 6 - Points: 0.5, Elo: 2014.48
# Player 7 - Points: 2.5, Elo: 2436.59
# Player 8 - Points: 1.0, Elo: 1419.46
# Player 9 - Points: 1.5, Elo: 2195.43
#
# After Round 5:
# Player 0 - Points: 1.5, Elo: 1961.60
# Player 1 - Points: 2.0, Elo: 1695.26
# Player 2 - Points: 3.5, Elo: 2127.90
# Player 3 - Points: 3.0, Elo: 2388.09
# Player 4 - Points: 2.0, Elo: 2072.89
# Player 5 - Points: 4.0, Elo: 2374.51
# Player 6 - Points: 0.5, Elo: 2014.48
# Player 7 - Points: 3.0, Elo: 2435.16
# Player 8 - Points: 1.0, Elo: 1419.46
# Player 9 - Points: 2.5, Elo: 2199.64
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1703.53
# Player 1 - Points: 0.5, Elo: 1961.47
# Player 2 - Points: 0.5, Elo: 2180.28
# Player 3 - Points: 0.5, Elo: 1910.72
# Player 4 - Points: 0.5, Elo: 1924.85
# Player 5 - Points: 0.5, Elo: 2058.15
# Player 6 - Points: 0, Elo: 1605.63
# Player 7 - Points: 1, Elo: 2295.37
# Player 8 - Points: 0.5, Elo: 1604.58
# Player 9 - Points: 0.5, Elo: 2251.42
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 1702.89
# Player 1 - Points: 1.0, Elo: 1967.05
# Player 2 - Points: 1.0, Elo: 2174.70
# Player 3 - Points: 0.5, Elo: 1901.13
# Player 4 - Points: 1.5, Elo: 1934.44
# Player 5 - Points: 1.5, Elo: 2059.52
# Player 6 - Points: 0, Elo: 1605.15
# Player 7 - Points: 2, Elo: 2296.01
# Player 8 - Points: 0.5, Elo: 1603.21
# Player 9 - Points: 1.5, Elo: 2251.90
#
# After Round 3:
# Player 0 - Points: 0.5, Elo: 1701.64
# Player 1 - Points: 1.0, Elo: 1955.18
# Player 2 - Points: 2.0, Elo: 2175.94
# Player 3 - Points: 1.5, Elo: 1913.00
# Player 4 - Points: 1.5, Elo: 1932.22
# Player 5 - Points: 1.5, Elo: 2054.55
# Player 6 - Points: 0, Elo: 1595.10
# Player 7 - Points: 3, Elo: 2298.23
# Player 8 - Points: 1.5, Elo: 1613.26
# Player 9 - Points: 2.5, Elo: 2256.86
#
# After Round 4:
# Player 0 - Points: 1.5, Elo: 1708.67
# Player 1 - Points: 2.0, Elo: 1957.63
# Player 2 - Points: 3.0, Elo: 2179.89
# Player 3 - Points: 1.5, Elo: 1906.87
# Player 4 - Points: 1.5, Elo: 1928.28
# Player 5 - Points: 2.5, Elo: 2060.69
# Player 6 - Points: 0, Elo: 1588.07
# Player 7 - Points: 3.5, Elo: 2297.05
# Player 8 - Points: 1.5, Elo: 1610.81
# Player 9 - Points: 3.0, Elo: 2258.05
#
# After Round 5:
# Player 0 - Points: 2.5, Elo: 1726.34
# Player 1 - Points: 2.0, Elo: 1954.62
# Player 2 - Points: 3.0, Elo: 2173.14
# Player 3 - Points: 2.5, Elo: 1909.94
# Player 4 - Points: 2.5, Elo: 1930.75
# Player 5 - Points: 2.5, Elo: 2043.02
# Player 6 - Points: 0, Elo: 1585.60
# Player 7 - Points: 4.5, Elo: 2303.80
# Player 8 - Points: 1.5, Elo: 1607.73
# Player 9 - Points: 4.0, Elo: 2261.06
#
# After Round 1:
# Player 0 - Points: 0, Elo: 1973.04
# Player 1 - Points: 1, Elo: 1892.96
# Player 2 - Points: 0.5, Elo: 1877.55
# Player 3 - Points: 0.5, Elo: 1895.45
# Player 4 - Points: 1, Elo: 2485.22
# Player 5 - Points: 0, Elo: 1704.78
# Player 6 - Points: 1, Elo: 2462.64
# Player 7 - Points: 0, Elo: 1868.36
# Player 8 - Points: 1, Elo: 2215.58
# Player 9 - Points: 0, Elo: 1605.42
#
# After Round 2:
# Player 0 - Points: 0, Elo: 1960.36
# Player 1 - Points: 1.5, Elo: 1902.32
# Player 2 - Points: 1.5, Elo: 1890.23
# Player 3 - Points: 1.5, Elo: 1900.46
# Player 4 - Points: 1.5, Elo: 2475.86
# Player 5 - Points: 0, Elo: 1699.77
# Player 6 - Points: 2, Elo: 2466.52
# Player 7 - Points: 1, Elo: 1871.97
# Player 8 - Points: 1, Elo: 2211.70
# Player 9 - Points: 0, Elo: 1601.81
#
# After Round 3:
# Player 0 - Points: 0, Elo: 1956.55
# Player 1 - Points: 1.5, Elo: 1901.57
# Player 2 - Points: 1.5, Elo: 1889.56
# Player 3 - Points: 2.5, Elo: 1909.64
# Player 4 - Points: 2.5, Elo: 2476.53
# Player 5 - Points: 1, Elo: 1707.03
# Player 6 - Points: 3, Elo: 2467.27
# Player 7 - Points: 1, Elo: 1862.79
# Player 8 - Points: 2, Elo: 2215.51
# Player 9 - Points: 0, Elo: 1594.56
#
# After Round 4:
# Player 0 - Points: 1, Elo: 1958.76
# Player 1 - Points: 2.0, Elo: 1901.23
# Player 2 - Points: 2.0, Elo: 1889.91
# Player 3 - Points: 2.5, Elo: 1908.86
# Player 4 - Points: 3.5, Elo: 2480.17
# Player 5 - Points: 1, Elo: 1701.23
# Player 6 - Points: 4, Elo: 2468.05
# Player 7 - Points: 2, Elo: 1868.58
# Player 8 - Points: 2, Elo: 2211.87
# Player 9 - Points: 0, Elo: 1592.34
#
# After Round 5:
# Player 0 - Points: 1, Elo: 1958.76
# Player 1 - Points: 2.0, Elo: 1891.45
# Player 2 - Points: 3.0, Elo: 1899.30
# Player 3 - Points: 3.5, Elo: 1918.64
# Player 4 - Points: 4.5, Elo: 2489.82
# Player 5 - Points: 1, Elo: 1700.23
# Player 6 - Points: 4, Elo: 2458.40
# Player 7 - Points: 2, Elo: 1859.20
# Player 8 - Points: 3, Elo: 2212.87
# Player 9 - Points: 0, Elo: 1592.34
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2291.12
# Player 1 - Points: 0, Elo: 1409.88
# Player 2 - Points: 0.5, Elo: 1444.65
# Player 3 - Points: 0.5, Elo: 1883.35
# Player 4 - Points: 0, Elo: 1674.77
# Player 5 - Points: 1, Elo: 2450.23
# Player 6 - Points: 0, Elo: 1787.89
# Player 7 - Points: 1, Elo: 1984.11
# Player 8 - Points: 1, Elo: 2017.90
# Player 9 - Points: 0, Elo: 1485.10
#
# After Round 2:
# Player 0 - Points: 1.5, Elo: 2295.41
# Player 1 - Points: 0, Elo: 1400.87
# Player 2 - Points: 1.5, Elo: 1453.65
# Player 3 - Points: 1.0, Elo: 1877.98
# Player 4 - Points: 0.5, Elo: 1680.14
# Player 5 - Points: 1.5, Elo: 2445.94
# Player 6 - Points: 1, Elo: 1790.87
# Player 7 - Points: 1, Elo: 1975.07
# Player 8 - Points: 2, Elo: 2026.93
# Player 9 - Points: 0, Elo: 1482.12
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 2278.92
# Player 1 - Points: 0.5, Elo: 1403.17
# Player 2 - Points: 2.0, Elo: 1463.59
# Player 3 - Points: 2.0, Elo: 1885.52
# Player 4 - Points: 0.5, Elo: 1677.05
# Player 5 - Points: 2.0, Elo: 2436.01
# Player 6 - Points: 1, Elo: 1783.33
# Player 7 - Points: 2, Elo: 1978.17
# Player 8 - Points: 3, Elo: 2043.41
# Player 9 - Points: 0.5, Elo: 1479.83
#
# After Round 4:
# Player 0 - Points: 2.0, Elo: 2271.93
# Player 1 - Points: 0.5, Elo: 1401.15
# Player 2 - Points: 2.0, Elo: 1462.90
# Player 3 - Points: 2.5, Elo: 1894.72
# Player 4 - Points: 1.5, Elo: 1681.91
# Player 5 - Points: 2.5, Elo: 2426.82
# Player 6 - Points: 2, Elo: 1785.35
# Player 7 - Points: 2.5, Elo: 1985.16
# Player 8 - Points: 4, Elo: 2044.10
# Player 9 - Points: 0.5, Elo: 1474.96
#
# After Round 5:
# Player 0 - Points: 3.0, Elo: 2272.12
# Player 1 - Points: 0.5, Elo: 1401.15
# Player 2 - Points: 2.0, Elo: 1462.71
# Player 3 - Points: 2.5, Elo: 1888.77
# Player 4 - Points: 1.5, Elo: 1674.81
# Player 5 - Points: 3.5, Elo: 2428.28
# Player 6 - Points: 3, Elo: 1792.45
# Player 7 - Points: 2.5, Elo: 1983.70
# Player 8 - Points: 5, Elo: 2050.05
# Player 9 - Points: 0.5, Elo: 1474.96
#
# After Round 1:
# Player 0 - Points: 1, Elo: 1793.51
# Player 1 - Points: 0, Elo: 1857.49
# Player 2 - Points: 1, Elo: 1953.45
# Player 3 - Points: 0, Elo: 1811.55
# Player 4 - Points: 0.5, Elo: 2476.63
# Player 5 - Points: 0.5, Elo: 2497.37
# Player 6 - Points: 0, Elo: 2138.60
# Player 7 - Points: 1, Elo: 2590.40
# Player 8 - Points: 1, Elo: 2455.27
# Player 9 - Points: 0, Elo: 1707.73
#
# After Round 2:
# Player 0 - Points: 1, Elo: 1787.81
# Player 1 - Points: 0, Elo: 1856.94
# Player 2 - Points: 2, Elo: 1959.15
# Player 3 - Points: 0, Elo: 1811.17
# Player 4 - Points: 1.5, Elo: 2477.18
# Player 5 - Points: 1.5, Elo: 2497.75
# Player 6 - Points: 1, Elo: 2140.14
# Player 7 - Points: 2, Elo: 2596.70
# Player 8 - Points: 1, Elo: 2448.97
# Player 9 - Points: 0, Elo: 1706.19
#
# After Round 3:
# Player 0 - Points: 1, Elo: 1787.44
# Player 1 - Points: 0, Elo: 1856.30
# Player 2 - Points: 2, Elo: 1958.65
# Player 3 - Points: 1, Elo: 1818.24
# Player 4 - Points: 2.5, Elo: 2477.55
# Player 5 - Points: 2.0, Elo: 2490.01
# Player 6 - Points: 1.5, Elo: 2147.88
# Player 7 - Points: 3, Elo: 2597.19
# Player 8 - Points: 2, Elo: 2449.61
# Player 9 - Points: 0, Elo: 1699.12
#
# After Round 4:
# Player 0 - Points: 2, Elo: 1798.32
# Player 1 - Points: 1, Elo: 1862.06
# Player 2 - Points: 3, Elo: 1977.75
# Player 3 - Points: 1, Elo: 1807.36
# Player 4 - Points: 2.5, Elo: 2470.87
# Player 5 - Points: 2.0, Elo: 2470.91
# Player 6 - Points: 1.5, Elo: 2144.88
# Player 7 - Points: 4, Elo: 2603.88
# Player 8 - Points: 3, Elo: 2452.61
# Player 9 - Points: 0, Elo: 1693.36
#
# After Round 5:
# Player 0 - Points: 2, Elo: 1798.13
# Player 1 - Points: 1, Elo: 1861.48
# Player 2 - Points: 3, Elo: 1976.53
# Player 3 - Points: 1, Elo: 1807.36
# Player 4 - Points: 3.5, Elo: 2473.52
# Player 5 - Points: 3.0, Elo: 2471.49
# Player 6 - Points: 1.5, Elo: 2142.23
# Player 7 - Points: 5, Elo: 2604.07
# Player 8 - Points: 4, Elo: 2453.83
# Player 9 - Points: 0, Elo: 1693.36
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2368.18
# Player 1 - Points: 0, Elo: 1547.82
# Player 2 - Points: 0.5, Elo: 2023.11
# Player 3 - Points: 0.5, Elo: 2537.89
# Player 4 - Points: 1, Elo: 2189.05
# Player 5 - Points: 0, Elo: 2031.95
# Player 6 - Points: 0, Elo: 1524.70
# Player 7 - Points: 1, Elo: 1758.30
# Player 8 - Points: 0, Elo: 1753.35
# Player 9 - Points: 1, Elo: 2174.65
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2373.43
# Player 1 - Points: 0, Elo: 1546.61
# Player 2 - Points: 1.5, Elo: 2024.33
# Player 3 - Points: 1.5, Elo: 2538.92
# Player 4 - Points: 1, Elo: 2183.80
# Player 5 - Points: 0, Elo: 2030.92
# Player 6 - Points: 1, Elo: 1540.47
# Player 7 - Points: 1, Elo: 1756.63
# Player 8 - Points: 0, Elo: 1737.58
# Player 9 - Points: 2, Elo: 2176.32
#
# After Round 3:
# Player 0 - Points: 2, Elo: 2358.30
# Player 1 - Points: 0, Elo: 1542.01
# Player 2 - Points: 1.5, Elo: 2018.62
# Player 3 - Points: 2.5, Elo: 2538.98
# Player 4 - Points: 2, Elo: 2189.50
# Player 5 - Points: 1, Elo: 2034.04
# Player 6 - Points: 1, Elo: 1540.41
# Player 7 - Points: 2, Elo: 1761.23
# Player 8 - Points: 0, Elo: 1734.46
# Player 9 - Points: 3, Elo: 2191.46
#
# After Round 4:
# Player 0 - Points: 2, Elo: 2338.92
# Player 1 - Points: 0, Elo: 1537.04
# Player 2 - Points: 2.5, Elo: 2029.06
# Player 3 - Points: 3.0, Elo: 2531.37
# Player 4 - Points: 3, Elo: 2189.97
# Player 5 - Points: 1, Elo: 2023.59
# Player 6 - Points: 1, Elo: 1539.94
# Player 7 - Points: 3, Elo: 1780.61
# Player 8 - Points: 1, Elo: 1739.42
# Player 9 - Points: 3.5, Elo: 2199.07
#
# After Round 5:
# Player 0 - Points: 2.5, Elo: 2331.80
# Player 1 - Points: 0, Elo: 1537.04
# Player 2 - Points: 3.0, Elo: 2036.19
# Player 3 - Points: 4.0, Elo: 2531.63
# Player 4 - Points: 3, Elo: 2180.23
# Player 5 - Points: 2, Elo: 2024.76
# Player 6 - Points: 1, Elo: 1538.78
# Player 7 - Points: 3, Elo: 1780.34
# Player 8 - Points: 1, Elo: 1739.42
# Player 9 - Points: 4.5, Elo: 2208.81
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2584.97
# Player 1 - Points: 0, Elo: 2196.03
# Player 2 - Points: 0, Elo: 1886.86
# Player 3 - Points: 1, Elo: 2185.14
# Player 4 - Points: 0, Elo: 2098.12
# Player 5 - Points: 1, Elo: 2261.88
# Player 6 - Points: 1, Elo: 2505.03
# Player 7 - Points: 0, Elo: 2199.97
# Player 8 - Points: 0.5, Elo: 2405.03
# Player 9 - Points: 0.5, Elo: 2177.97
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2586.79
# Player 1 - Points: 0, Elo: 2191.42
# Player 2 - Points: 0, Elo: 1883.71
# Player 3 - Points: 1, Elo: 2183.32
# Player 4 - Points: 1, Elo: 2110.97
# Player 5 - Points: 2, Elo: 2277.93
# Player 6 - Points: 1, Elo: 2488.99
# Player 7 - Points: 0, Elo: 2187.12
# Player 8 - Points: 1.5, Elo: 2409.65
# Player 9 - Points: 1.5, Elo: 2181.12
#
# After Round 3:
# Player 0 - Points: 3, Elo: 2589.68
# Player 1 - Points: 0, Elo: 2188.36
# Player 2 - Points: 0.5, Elo: 1890.74
# Player 3 - Points: 1, Elo: 2179.05
# Player 4 - Points: 1, Elo: 2102.96
# Player 5 - Points: 2, Elo: 2275.04
# Player 6 - Points: 2, Elo: 2492.05
# Player 7 - Points: 0.5, Elo: 2180.08
# Player 8 - Points: 2.5, Elo: 2413.93
# Player 9 - Points: 2.5, Elo: 2189.13
#
# After Round 4:
# Player 0 - Points: 3, Elo: 2575.01
# Player 1 - Points: 0.5, Elo: 2188.12
# Player 2 - Points: 0.5, Elo: 1886.18
# Player 3 - Points: 1, Elo: 2176.21
# Player 4 - Points: 2, Elo: 2107.51
# Player 5 - Points: 2, Elo: 2262.61
# Player 6 - Points: 3, Elo: 2494.88
# Player 7 - Points: 1.0, Elo: 2180.32
# Player 8 - Points: 3.5, Elo: 2428.59
# Player 9 - Points: 3.5, Elo: 2201.55
#
# After Round 5:
# Player 0 - Points: 4, Elo: 2577.10
# Player 1 - Points: 1.0, Elo: 2181.11
# Player 2 - Points: 1.0, Elo: 1893.19
# Player 3 - Points: 2, Elo: 2184.26
# Player 4 - Points: 2, Elo: 2099.46
# Player 5 - Points: 3, Elo: 2270.29
# Player 6 - Points: 3.5, Elo: 2492.99
# Player 7 - Points: 1.0, Elo: 2172.65
# Player 8 - Points: 4.0, Elo: 2430.48
# Player 9 - Points: 3.5, Elo: 2199.46
#
# After Round 1:
# Player 0 - Points: 1, Elo: 1441.20
# Player 1 - Points: 0, Elo: 1660.80
# Player 2 - Points: 1, Elo: 2051.43
# Player 3 - Points: 0, Elo: 1603.57
# Player 4 - Points: 1, Elo: 2285.22
# Player 5 - Points: 0, Elo: 1502.78
# Player 6 - Points: 1, Elo: 2397.64
# Player 7 - Points: 0, Elo: 1803.36
# Player 8 - Points: 1, Elo: 2082.11
# Player 9 - Points: 0, Elo: 1885.89
#
# After Round 2:
# Player 0 - Points: 1.5, Elo: 1450.62
# Player 1 - Points: 0, Elo: 1659.17
# Player 2 - Points: 1.5, Elo: 2042.01
# Player 3 - Points: 0, Elo: 1590.74
# Player 4 - Points: 2, Elo: 2298.35
# Player 5 - Points: 1, Elo: 1515.60
# Player 6 - Points: 1, Elo: 2384.51
# Player 7 - Points: 0.5, Elo: 1805.69
# Player 8 - Points: 2, Elo: 2083.73
# Player 9 - Points: 0.5, Elo: 1883.56
#
# After Round 3:
# Player 0 - Points: 2.0, Elo: 1452.47
# Player 1 - Points: 0, Elo: 1653.16
# Player 2 - Points: 1.5, Elo: 2039.57
# Player 3 - Points: 0, Elo: 1587.62
# Player 4 - Points: 3, Elo: 2302.85
# ...
# Player 6 - Points: 0.5, Elo: 1689.18
# Player 7 - Points: 1.5, Elo: 1876.16
# Player 8 - Points: 2.0, Elo: 2166.18
# Player 9 - Points: 2.5, Elo: 2377.35
#
# After Round 4:
# Player 0 - Points: 4, Elo: 2565.34
# Player 1 - Points: 1, Elo: 1653.12
# Player 2 - Points: 1.5, Elo: 1955.26
# Player 3 - Points: 3.0, Elo: 2094.39
# Player 4 - Points: 1.5, Elo: 2264.09
# Player 5 - Points: 0.5, Elo: 1891.92
# Player 6 - Points: 1.0, Elo: 1694.54
# Player 7 - Points: 2.0, Elo: 1884.31
# Player 8 - Points: 3.0, Elo: 2170.85
# Player 9 - Points: 2.5, Elo: 2372.17
#
# After Round 5:
# Player 0 - Points: 5, Elo: 2566.58
# Player 1 - Points: 1, Elo: 1652.55
# Player 2 - Points: 1.5, Elo: 1953.59
# Player 3 - Points: 3.0, Elo: 2093.15
# Player 4 - Points: 2.5, Elo: 2264.67
# Player 5 - Points: 0.5, Elo: 1891.92
# Player 6 - Points: 1.0, Elo: 1694.54
# Player 7 - Points: 3.0, Elo: 1901.08
# Player 8 - Points: 3.0, Elo: 2154.08
# Player 9 - Points: 3.5, Elo: 2373.84
#
# After Round 1:
# Player 0 - Points: 1, Elo: 1494.68
# Player 1 - Points: 0, Elo: 1431.32
# Player 2 - Points: 0.5, Elo: 1632.01
# Player 3 - Points: 0.5, Elo: 2127.99
# Player 4 - Points: 0, Elo: 1615.90
# Player 5 - Points: 1, Elo: 2541.10
# Player 6 - Points: 0.5, Elo: 1741.79
# Player 7 - Points: 0.5, Elo: 2088.21
# Player 8 - Points: 0.5, Elo: 2306.49
# Player 9 - Points: 0.5, Elo: 2222.51
#
# After Round 2:
# Player 0 - Points: 1.5, Elo: 1504.64
# Player 1 - Points: 0, Elo: 1431.19
# Player 2 - Points: 0.5, Elo: 1625.07
# Player 3 - Points: 1.5, Elo: 2136.85
# Player 4 - Points: 0, Elo: 1615.31
# Player 5 - Points: 1.5, Elo: 2531.15
# Player 6 - Points: 1.5, Elo: 1748.73
# Player 7 - Points: 0.5, Elo: 2079.35
# Player 8 - Points: 1.5, Elo: 2306.62
# Player 9 - Points: 1.5, Elo: 2223.10
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 1504.12
# Player 1 - Points: 1, Elo: 1446.04
# Player 2 - Points: 0.5, Elo: 1624.68
# Player 3 - Points: 2.5, Elo: 2137.36
# Player 4 - Points: 0, Elo: 1600.46
# Player 5 - Points: 2.5, Elo: 2531.36
# Player 6 - Points: 1.5, Elo: 1748.51
# Player 7 - Points: 1.5, Elo: 2093.27
# Player 8 - Points: 2.5, Elo: 2307.01
# Player 9 - Points: 1.5, Elo: 2209.18
#
# After Round 4:
# Player 0 - Points: 1.5, Elo: 1503.93
# Player 1 - Points: 1, Elo: 1445.57
# Player 2 - Points: 1.0, Elo: 1623.99
# Player 3 - Points: 3.0, Elo: 2145.48
# Player 4 - Points: 0.5, Elo: 1601.15
# Player 5 - Points: 3.0, Elo: 2523.24
# Player 6 - Points: 1.5, Elo: 1747.19
# Player 7 - Points: 2.5, Elo: 2093.74
# Player 8 - Points: 3.5, Elo: 2307.20
# Player 9 - Points: 2.5, Elo: 2210.50
#
# After Round 5:
# Player 0 - Points: 1.5, Elo: 1503.59
# Player 1 - Points: 1, Elo: 1442.57
# Player 2 - Points: 1.0, Elo: 1623.99
# Player 3 - Points: 3.0, Elo: 2139.83
# Player 4 - Points: 0.5, Elo: 1601.15
# Player 5 - Points: 4.0, Elo: 2524.80
# Player 6 - Points: 2.5, Elo: 1750.19
# Player 7 - Points: 2.5, Elo: 2092.18
# Player 8 - Points: 4.5, Elo: 2312.86
# Player 9 - Points: 3.5, Elo: 2210.84
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2304.40
# Player 1 - Points: 0, Elo: 1625.60
# Player 2 - Points: 0, Elo: 2179.83
# Player 3 - Points: 1, Elo: 2550.17
# Player 4 - Points: 1, Elo: 2347.98
# Player 5 - Points: 0, Elo: 1830.02
# Player 6 - Points: 0.5, Elo: 2011.13
# Player 7 - Points: 0.5, Elo: 2389.87
# Player 8 - Points: 1, Elo: 2517.39
# Player 9 - Points: 0, Elo: 1834.61
#
# After Round 2:
# Player 0 - Points: 1, Elo: 2300.49
# Player 1 - Points: 0, Elo: 1623.64
# Player 2 - Points: 0, Elo: 2175.23
# Player 3 - Points: 2, Elo: 2554.08
# Player 4 - Points: 2, Elo: 2362.50
# Player 5 - Points: 1, Elo: 1840.16
# Player 6 - Points: 1.5, Elo: 2013.09
# Player 7 - Points: 1.5, Elo: 2394.46
# Player 8 - Points: 1, Elo: 2502.86
# Player 9 - Points: 0, Elo: 1824.48
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 2293.70
# Player 1 - Points: 0, Elo: 1623.52
# Player 2 - Points: 1, Elo: 2177.58
# Player 3 - Points: 3, Elo: 2559.06
# Player 4 - Points: 2, Elo: 2357.51
# Player 5 - Points: 1, Elo: 1839.37
# Player 6 - Points: 2.0, Elo: 2019.88
# Player 7 - Points: 2.5, Elo: 2395.25
# Player 8 - Points: 2, Elo: 2502.99
# Player 9 - Points: 0, Elo: 1822.14
#
# After Round 4:
# Player 0 - Points: 1.5, Elo: 2289.08
# Player 1 - Points: 0, Elo: 1618.68
# Player 2 - Points: 2, Elo: 2180.08
# Player 3 - Points: 3, Elo: 2544.67
# Player 4 - Points: 3, Elo: 2360.02
# Player 5 - Points: 1, Elo: 1836.87
# Player 6 - Points: 2.0, Elo: 2017.38
# Player 7 - Points: 3.5, Elo: 2409.65
# Player 8 - Points: 3, Elo: 2507.60
# Player 9 - Points: 1, Elo: 1826.97
#
# After Round 5:
# Player 0 - Points: 2.5, Elo: 2290.46
# Player 1 - Points: 0, Elo: 1618.68
# Player 2 - Points: 3, Elo: 2185.71
# Player 3 - Points: 4, Elo: 2553.61
# Player 4 - Points: 3, Elo: 2351.44
# Player 5 - Points: 1, Elo: 1835.49
# Player 6 - Points: 2.0, Elo: 2011.75
# Player 7 - Points: 4.5, Elo: 2418.23
# Player 8 - Points: 3, Elo: 2498.66
# Player 9 - Points: 1, Elo: 1826.97
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2286.56
# Player 1 - Points: 0, Elo: 2065.44
# Player 2 - Points: 1, Elo: 2436.16
# Player 3 - Points: 0, Elo: 1598.84
# Player 4 - Points: 0.5, Elo: 1470.94
# Player 5 - Points: 0.5, Elo: 2446.06
# Player 6 - Points: 0, Elo: 1885.64
# Player 7 - Points: 1, Elo: 2582.36
# Player 8 - Points: 1, Elo: 1470.49
# Player 9 - Points: 0, Elo: 1400.51
#
# After Round 2:
# Player 0 - Points: 1.5, Elo: 2290.62
# Player 1 - Points: 0.5, Elo: 2056.07
# Player 2 - Points: 1.5, Elo: 2432.10
# Player 3 - Points: 0, Elo: 1598.69
# Player 4 - Points: 1.0, Elo: 1480.30
# Player 5 - Points: 1.5, Elo: 2446.22
# Player 6 - Points: 1, Elo: 1886.80
# Player 7 - Points: 2, Elo: 2582.39
# Player 8 - Points: 1, Elo: 1470.45
# Player 9 - Points: 0, Elo: 1399.36
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 2287.47
# Player 1 - Points: 1.5, Elo: 2056.74
# Player 2 - Points: 2.0, Elo: 2432.51
# Player 3 - Points: 1, Elo: 1603.51
# Player 4 - Points: 1.5, Elo: 1488.55
# Player 5 - Points: 2.0, Elo: 2445.81
# Player 6 - Points: 1.5, Elo: 1878.55
# Player 7 - Points: 3, Elo: 2585.53
# Player 8 - Points: 1, Elo: 1469.79
# Player 9 - Points: 0, Elo: 1394.54
#
# After Round 4:
# Player 0 - Points: 2.5, Elo: 2301.74
# Player 1 - Points: 2.5, Elo: 2062.02
# Player 2 - Points: 3.0, Elo: 2446.65
# Player 3 - Points: 1, Elo: 1590.31
# Player 4 - Points: 2.5, Elo: 1501.74
# Player 5 - Points: 2.0, Elo: 2431.54
# Player 6 - Points: 1.5, Elo: 1873.28
# Player 7 - Points: 3, Elo: 2571.39
# Player 8 - Points: 1, Elo: 1469.79
# Player 9 - Points: 0, Elo: 1394.54
#
# After Round 5:
# Player 0 - Points: 3.5, Elo: 2303.30
# Player 1 - Points: 2.5, Elo: 2060.05
# Player 2 - Points: 4.0, Elo: 2448.62
# Player 3 - Points: 1, Elo: 1590.31
# Player 4 - Points: 2.5, Elo: 1501.70
# Player 5 - Points: 3.0, Elo: 2431.62
# Player 6 - Points: 1.5, Elo: 1871.71
# Player 7 - Points: 4, Elo: 2571.44
# Player 8 - Points: 1, Elo: 1469.71
# Player 9 - Points: 0, Elo: 1394.54
#
# After Round 1:
# Player 0 - Points: 0, Elo: 1608.80
# Player 1 - Points: 1, Elo: 2404.20
# Player 2 - Points: 0.5, Elo: 1405.18
# Player 3 - Points: 0.5, Elo: 1477.82
# Player 4 - Points: 1, Elo: 2435.32
# Player 5 - Points: 0, Elo: 1717.68
# Player 6 - Points: 1, Elo: 1784.20
# Player 7 - Points: 0, Elo: 1803.80
# Player 8 - Points: 0.5, Elo: 1471.95
# Player 9 - Points: 0.5, Elo: 2483.05
#
# After Round 2:
# Player 0 - Points: 0, Elo: 1608.67
# Player 1 - Points: 1, Elo: 2395.10
# Player 2 - Points: 0.5, Elo: 1403.15
# Player 3 - Points: 1.5, Elo: 1487.65
# Player 4 - Points: 2, Elo: 2444.42
# Player 5 - Points: 1, Elo: 1730.11
# Player 6 - Points: 2, Elo: 1786.23
# Player 7 - Points: 0, Elo: 1791.37
# Player 8 - Points: 0.5, Elo: 1462.12
# Player 9 - Points: 1.5, Elo: 2483.18
#
# After Round 3:
# Player 0 - Points: 0.5, Elo: 1613.49
# Player 1 - Points: 2, Elo: 2395.52
# Player 2 - Points: 1.5, Elo: 1414.83
# Player 3 - Points: 2.0, Elo: 1497.59
# Player 4 - Points: 3, Elo: 2444.87
# Player 5 - Points: 1, Elo: 1729.69
# Player 6 - Points: 2, Elo: 1785.79
# Player 7 - Points: 0.5, Elo: 1786.55
# Player 8 - Points: 0.5, Elo: 1450.44
# Player 9 - Points: 2.0, Elo: 2473.25
#
# After Round 4:
# Player 0 - Points: 0.5, Elo: 1606.71
# Player 1 - Points: 3, Elo: 2396.10
# Player 2 - Points: 1.5, Elo: 1414.79
# Player 3 - Points: 2.0, Elo: 1497.50
# Player 4 - Points: 4, Elo: 2444.95
# Player 5 - Points: 2, Elo: 1736.46
# Player 6 - Points: 2, Elo: 1785.21
# Player 7 - Points: 1.5, Elo: 1789.07
# Player 8 - Points: 0.5, Elo: 1447.91
# Player 9 - Points: 3.0, Elo: 2473.29
#
# After Round 5:
# Player 0 - Points: 1.5, Elo: 1612.44
# Player 1 - Points: 4, Elo: 2396.22
# Player 2 - Points: 2.5, Elo: 1432.71
# Player 3 - Points: 2.0, Elo: 1497.39
# Player 4 - Points: 5, Elo: 2455.77
# Player 5 - Points: 3, Elo: 1747.85
# Player 6 - Points: 2, Elo: 1773.81
# Player 7 - Points: 1.5, Elo: 1771.15
# Player 8 - Points: 0.5, Elo: 1442.19
# Player 9 - Points: 3.0, Elo: 2462.48
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2367.17
# Player 1 - Points: 0, Elo: 1540.83
# Player 2 - Points: 0.5, Elo: 2456.09
# Player 3 - Points: 0.5, Elo: 2491.91
# Player 4 - Points: 0.5, Elo: 2241.74
# Player 5 - Points: 0.5, Elo: 2166.26
# Player 6 - Points: 1, Elo: 2539.22
# Player 7 - Points: 0, Elo: 2245.78
# Player 8 - Points: 0, Elo: 1447.90
# Player 9 - Points: 1, Elo: 2364.10
#
# After Round 2:
# Player 0 - Points: 1.5, Elo: 2371.75
# Player 1 - Points: 0, Elo: 1540.30
# Player 2 - Points: 0.5, Elo: 2443.50
# Player 3 - Points: 1.5, Elo: 2495.74
# Player 4 - Points: 0.5, Elo: 2237.91
# Player 5 - Points: 1.5, Elo: 2166.79
# Player 6 - Points: 1.5, Elo: 2534.63
# Player 7 - Points: 1, Elo: 2245.98
# Player 8 - Points: 0, Elo: 1447.70
# Player 9 - Points: 2, Elo: 2376.69
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 2361.90
# Player 1 - Points: 1, Elo: 1547.69
# Player 2 - Points: 0.5, Elo: 2436.07
# Player 3 - Points: 1.5, Elo: 2478.36
# Player 4 - Points: 0.5, Elo: 2228.14
# Player 5 - Points: 2.5, Elo: 2184.18
# Player 6 - Points: 2.5, Elo: 2542.07
# Player 7 - Points: 2, Elo: 2255.75
# Player 8 - Points: 0, Elo: 1440.30
# Player 9 - Points: 3, Elo: 2386.55
#
# After Round 4:
# Player 0 - Points: 2.5, Elo: 2368.93
# Player 1 - Points: 1, Elo: 1547.57
# Player 2 - Points: 1.5, Elo: 2436.19
# Player 3 - Points: 1.5, Elo: 2470.17
# Player 4 - Points: 1.5, Elo: 2228.35
# Player 5 - Points: 2.5, Elo: 2179.42
# Player 6 - Points: 3.5, Elo: 2550.26
# Player 7 - Points: 2, Elo: 2248.71
# Player 8 - Points: 0, Elo: 1440.09
# Player 9 - Points: 4, Elo: 2391.30
#
# After Round 5:
# Player 0 - Points: 3.5, Elo: 2373.96
# Player 1 - Points: 1, Elo: 1547.48
# Player 2 - Points: 2.0, Elo: 2431.26
# Player 3 - Points: 2.5, Elo: 2470.27
# Player 4 - Points: 1.5, Elo: 2228.35
# Player 5 - Points: 2.5, Elo: 2174.39
# Player 6 - Points: 4.5, Elo: 2555.97
# Player 7 - Points: 2.5, Elo: 2253.64
# Player 8 - Points: 0, Elo: 1440.09
# Player 9 - Points: 4, Elo: 2385.58
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2171.36
# Player 1 - Points: 0, Elo: 1713.64
# Player 2 - Points: 1, Elo: 2198.17
# Player 3 - Points: 0, Elo: 2366.83
# Player 4 - Points: 0.5, Elo: 2147.07
# Player 5 - Points: 0.5, Elo: 2288.93
# Player 6 - Points: 0.5, Elo: 2255.73
# Player 7 - Points: 0.5, Elo: 2144.27
# Player 8 - Points: 1, Elo: 2321.27
# Player 9 - Points: 0, Elo: 1850.73
#
# After Round 2:
# Player 0 - Points: 1.5, Elo: 2172.13
# Player 1 - Points: 0, Elo: 1712.09
# Player 2 - Points: 1.5, Elo: 2197.40
# Player 3 - Points: 1, Elo: 2367.80
# Player 4 - Points: 0.5, Elo: 2141.70
# Player 5 - Points: 0.5, Elo: 2277.98
# Player 6 - Points: 1.5, Elo: 2266.68
# Player 7 - Points: 1.5, Elo: 2145.82
# Player 8 - Points: 2, Elo: 2326.63
# Player 9 - Points: 0, Elo: 1849.76
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 2166.30
# Player 1 - Points: 0, Elo: 1710.54
# Player 2 - Points: 2.0, Elo: 2199.37
# Player 3 - Points: 1.5, Elo: 2362.16
# Player 4 - Points: 1.5, Elo: 2143.26
# Player 5 - Points: 1.5, Elo: 2279.55
# Player 6 - Points: 2.0, Elo: 2264.71
# Player 7 - Points: 2.0, Elo: 2151.46
# Player 8 - Points: 3, Elo: 2332.46
# Player 9 - Points: 0, Elo: 1848.19
#
# After Round 4:
# Player 0 - Points: 1.5, Elo: 2159.06
# Player 1 - Points: 1, Elo: 1724.31
# Player 2 - Points: 3.0, Elo: 2213.03
# Player 3 - Points: 2.5, Elo: 2369.83
# Player 4 - Points: 2.0, Elo: 2143.49
# Player 5 - Points: 1.5, Elo: 2271.88
# Player 6 - Points: 3.0, Elo: 2271.95
# Player 7 - Points: 2.5, Elo: 2151.22
# Player 8 - Points: 3, Elo: 2318.81
# Player 9 - Points: 0, Elo: 1834.42
#
# After Round 5:
# Player 0 - Points: 2.0, Elo: 2162.20
# Player 1 - Points: 1, Elo: 1724.31
# Player 2 - Points: 3.0, Elo: 2201.26
# Player 3 - Points: 3.5, Elo: 2374.10
# Player 4 - Points: 2.0, Elo: 2139.22
# Player 5 - Points: 2.0, Elo: 2268.74
# Player 6 - Points: 3.0, Elo: 2263.29
# Player 7 - Points: 3.5, Elo: 2162.98
# Player 8 - Points: 4, Elo: 2327.47
# Player 9 - Points: 0, Elo: 1834.42
#
# After Round 1:
# Player 0 - Points: 0, Elo: 2380.87
# Player 1 - Points: 1, Elo: 2535.13
# Player 2 - Points: 1, Elo: 1838.64
# Player 3 - Points: 0, Elo: 1506.36
# Player 4 - Points: 0, Elo: 2442.08
# Player 5 - Points: 1, Elo: 2431.92
# Player 6 - Points: 1, Elo: 2164.28
# Player 7 - Points: 0, Elo: 1423.72
# Player 8 - Points: 0.5, Elo: 1718.82
# Player 9 - Points: 0.5, Elo: 2511.18
#
# After Round 2:
# Player 0 - Points: 1, Elo: 2381.31
# Player 1 - Points: 2, Elo: 2535.48
# Player 2 - Points: 1, Elo: 1838.29
# Player 3 - Points: 0, Elo: 1506.30
# Player 4 - Points: 1, Elo: 2442.14
# Player 5 - Points: 2, Elo: 2435.45
# Player 6 - Points: 1, Elo: 2160.75
# Player 7 - Points: 0, Elo: 1423.66
# Player 8 - Points: 0.5, Elo: 1718.38
# Player 9 - Points: 1.5, Elo: 2511.25
#
# After Round 3:
# Player 0 - Points: 1, Elo: 2374.88
# Player 1 - Points: 2, Elo: 2522.68
# Player 2 - Points: 1.5, Elo: 1847.69
# Player 3 - Points: 1, Elo: 1513.96
# Player 4 - Points: 1.5, Elo: 2432.74
# Player 5 - Points: 3, Elo: 2448.25
# Player 6 - Points: 2, Elo: 2162.20
# Player 7 - Points: 0, Elo: 1416.00
# Player 8 - Points: 0.5, Elo: 1716.93
# Player 9 - Points: 2.5, Elo: 2517.67
#
# After Round 4:
# Player 0 - Points: 2, Elo: 2375.80
# Player 1 - Points: 3, Elo: 2524.91
# Player 2 - Points: 1.5, Elo: 1846.77
# Player 3 - Points: 1, Elo: 1513.86
# Player 4 - Points: 2.5, Elo: 2432.84
# Player 5 - Points: 4, Elo: 2460.22
# Player 6 - Points: 2, Elo: 2159.97
# Player 7 - Points: 0, Elo: 1412.99
# Player 8 - Points: 1.5, Elo: 1719.93
# Player 9 - Points: 2.5, Elo: 2505.70
#
# After Round 5:
# Player 0 - Points: 2, Elo: 2368.18
# Player 1 - Points: 4, Elo: 2532.32
# Player 2 - Points: 2.5, Elo: 1853.27
# Player 3 - Points: 1, Elo: 1513.86
# Player 4 - Points: 2.5, Elo: 2425.43
# Player 5 - Points: 5, Elo: 2467.84
# Player 6 - Points: 2, Elo: 2157.57
# Player 7 - Points: 0, Elo: 1412.99
# Player 8 - Points: 1.5, Elo: 1713.43
# Player 9 - Points: 3.5, Elo: 2508.10
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1433.73
# Player 1 - Points: 0.5, Elo: 1775.27
# Player 2 - Points: 1, Elo: 2048.30
# Player 3 - Points: 0, Elo: 1860.70
# Player 4 - Points: 0.5, Elo: 1931.27
# Player 5 - Points: 0.5, Elo: 2480.73
# Player 6 - Points: 1, Elo: 2281.18
# Player 7 - Points: 0, Elo: 1462.82
# Player 8 - Points: 1, Elo: 2221.40
# Player 9 - Points: 0, Elo: 1870.60
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 1433.52
# Player 1 - Points: 1.0, Elo: 1779.48
# Player 2 - Points: 1, Elo: 2044.16
# Player 3 - Points: 0, Elo: 1860.15
# Player 4 - Points: 1.0, Elo: 1927.06
# Player 5 - Points: 1.5, Elo: 2481.28
# Player 6 - Points: 2, Elo: 2285.33
# Player 7 - Points: 0.5, Elo: 1471.08
# Player 8 - Points: 2, Elo: 2221.61
# Player 9 - Points: 0.5, Elo: 1862.34
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 1444.59
# Player 1 - Points: 1.0, Elo: 1779.14
# Player 2 - Points: 1, Elo: 2030.91
# Player 3 - Points: 1, Elo: 1870.21
# Player 4 - Points: 2.0, Elo: 1940.31
# Player 5 - Points: 2.5, Elo: 2481.63
# Player 6 - Points: 3, Elo: 2293.51
# Player 7 - Points: 0.5, Elo: 1460.00
# Player 8 - Points: 2, Elo: 2213.43
# Player 9 - Points: 0.5, Elo: 1852.28
#
# After Round 4:
# Player 0 - Points: 1.5, Elo: 1443.93
# Player 1 - Points: 2.0, Elo: 1791.70
# Player 2 - Points: 2, Elo: 2031.57
# Player 3 - Points: 1, Elo: 1857.65
# Player 4 - Points: 2.5, Elo: 1946.87
# Player 5 - Points: 3.0, Elo: 2476.69
# Player 6 - Points: 3.5, Elo: 2298.45
# Player 7 - Points: 0.5, Elo: 1460.00
# Player 8 - Points: 2.5, Elo: 2206.87
# Player 9 - Points: 0.5, Elo: 1852.28
#
# After Round 5:
# Player 0 - Points: 1.5, Elo: 1442.24
# Player 1 - Points: 2.5, Elo: 1797.68
# Player 2 - Points: 2.5, Elo: 2025.59
# Player 3 - Points: 2, Elo: 1859.34
# Player 4 - Points: 2.5, Elo: 1944.53
# Player 5 - Points: 4.0, Elo: 2480.18
# Player 6 - Points: 4.5, Elo: 2300.79
# Player 7 - Points: 0.5, Elo: 1460.00
# Player 8 - Points: 2.5, Elo: 2203.37
# Player 9 - Points: 0.5, Elo: 1852.28

# %%
import random

# Number of Players, Rounds, and Simulations
num_players = 10
num_rounds = 5
num_simulations = 400
k_factor = 20  # K-factor for Elo rating updates

# Initialize Players with Elo ratings
players = [{'name': f'Player {i}', 'elo': random.randint(1400, 2600), 'points': 0} for i in range(num_players)]

def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2 """
    return 1 / (1 + 10 ** ((player2['elo'] - player1['elo']) / 400))

def update_elo_ratings(winner, loser, draw=False):
    """ Update Elo ratings after a game """
    expected_win_winner = calculate_win_probability(winner, loser)
    expected_win_loser = calculate_win_probability(loser, winner)

    score_winner = 0.5 if draw else 1
    score_loser = 0.5 if draw else 0

    winner['elo'] += k_factor * (score_winner - expected_win_winner)
    loser['elo'] += k_factor * (score_loser - expected_win_loser)

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
        update_elo_ratings(player1, player2)
    elif result < win_prob + (1 - win_prob) / 2:
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
        update_elo_ratings(player1, player2, draw=True)
    else:
        player2['points'] += 1  # Player 2 wins
        update_elo_ratings(player2, player1)

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

def print_final_round_statistics(players, simulation_number):
    """ Print statistics for the final round """
    if 390 <= simulation_number <= 400:
        print(f"\nSimulation {simulation_number} - Final Round Results:")
        for player in players:
            # Print probabilities of winning the tournament

            probability = tournament_wins[player['name']] / num_simulations
#           print(f"{player['name']} winning probability: {probability:.2f}")
            print(f"{player['name']} - Points: {player['points']}, Elo: {player['elo']:.2f} winning probability: {probability:.2f}")

def simulate_tournament(simulation_number):
    """ Simulate a single Swiss-system tournament """
    # Reset points and opponents for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []
        player['elo'] = random.randint(1400, 2600)  # Reset Elo for each simulation

    # Simulate rounds
    for round_number in range(1, num_rounds + 1):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)

    # Print final round statistics for specified simulations
    if round_number == num_rounds:
        print_final_round_statistics(players, simulation_number)

# Simulate and Print Results
for simulation_number in range(1, num_simulations + 1):
    simulate_tournament(simulation_number)
# Out:
# Simulation 390 - Final Round Results:
# Player 0 - Points: 3, Elo: 2014.10 winning probability: 1.29
# Player 1 - Points: 1, Elo: 1570.92 winning probability: 0.01
# Player 2 - Points: 3.5, Elo: 2099.65 winning probability: 0.23
# Player 3 - Points: 1, Elo: 1993.76 winning probability: 0.00
# Player 4 - Points: 2.5, Elo: 1956.72 winning probability: 0.09
# Player 5 - Points: 0, Elo: 1913.84 winning probability: 0.01
# Player 6 - Points: 2.0, Elo: 1972.64 winning probability: 0.04
# Player 7 - Points: 4.5, Elo: 2535.00 winning probability: 0.00
# Player 8 - Points: 2.5, Elo: 2197.72 winning probability: 0.08
# Player 9 - Points: 4, Elo: 2195.66 winning probability: 0.76
#
# Simulation 391 - Final Round Results:
# Player 0 - Points: 2.5, Elo: 1599.74 winning probability: 1.29
# Player 1 - Points: 1.5, Elo: 1498.82 winning probability: 0.01
# Player 2 - Points: 3.5, Elo: 2550.03 winning probability: 0.23
# Player 3 - Points: 0.5, Elo: 1432.34 winning probability: 0.00
# Player 4 - Points: 2.5, Elo: 1851.79 winning probability: 0.09
# Player 5 - Points: 4.0, Elo: 2364.05 winning probability: 0.01
# Player 6 - Points: 3, Elo: 2232.30 winning probability: 0.04
# Player 7 - Points: 3.0, Elo: 2219.85 winning probability: 0.00
# Player 8 - Points: 1.0, Elo: 1449.54 winning probability: 0.08
# Player 9 - Points: 3.5, Elo: 2192.55 winning probability: 0.76
#
# Simulation 392 - Final Round Results:
# Player 0 - Points: 3.0, Elo: 1800.36 winning probability: 1.29
# Player 1 - Points: 5, Elo: 2567.10 winning probability: 0.01
# Player 2 - Points: 2.5, Elo: 2342.35 winning probability: 0.23
# Player 3 - Points: 3.0, Elo: 2459.45 winning probability: 0.00
# Player 4 - Points: 2.5, Elo: 2267.54 winning probability: 0.09
# Player 5 - Points: 1, Elo: 1490.27 winning probability: 0.01
# Player 6 - Points: 2.5, Elo: 2130.13 winning probability: 0.04
# Player 7 - Points: 1.5, Elo: 1634.21 winning probability: 0.00
# Player 8 - Points: 2.0, Elo: 2176.44 winning probability: 0.08
# Player 9 - Points: 0, Elo: 1557.15 winning probability: 0.76
#
# Simulation 393 - Final Round Results:
# Player 0 - Points: 2, Elo: 1827.82 winning probability: 1.29
# Player 1 - Points: 4.0, Elo: 2375.50 winning probability: 0.01
# Player 2 - Points: 3.5, Elo: 2459.58 winning probability: 0.23
# Player 3 - Points: 2.5, Elo: 2496.06 winning probability: 0.00
# Player 4 - Points: 4.0, Elo: 2280.36 winning probability: 0.09
# Player 5 - Points: 0, Elo: 1903.73 winning probability: 0.01
# Player 6 - Points: 1, Elo: 1894.83 winning probability: 0.04
# Player 7 - Points: 1.5, Elo: 1870.44 winning probability: 0.00
# Player 8 - Points: 2.5, Elo: 2096.52 winning probability: 0.08
# Player 9 - Points: 3.0, Elo: 2259.16 winning probability: 0.76
#
# Simulation 394 - Final Round Results:
# Player 0 - Points: 5, Elo: 2516.11 winning probability: 1.29
# Player 1 - Points: 0, Elo: 1463.57 winning probability: 0.01
# Player 2 - Points: 1, Elo: 1943.16 winning probability: 0.23
# Player 3 - Points: 1.5, Elo: 1742.15 winning probability: 0.00
# Player 4 - Points: 3.5, Elo: 2318.89 winning probability: 0.09
# Player 5 - Points: 1, Elo: 1819.61 winning probability: 0.01
# Player 6 - Points: 2.5, Elo: 2087.45 winning probability: 0.04
# Player 7 - Points: 3.5, Elo: 2154.24 winning probability: 0.00
# Player 8 - Points: 3, Elo: 2335.66 winning probability: 0.08
# Player 9 - Points: 3, Elo: 2403.14 winning probability: 0.76
#
# Simulation 395 - Final Round Results:
# Player 0 - Points: 3.5, Elo: 2053.72 winning probability: 1.29
# Player 1 - Points: 1.5, Elo: 2039.81 winning probability: 0.01
# Player 2 - Points: 3.5, Elo: 2282.73 winning probability: 0.23
# Player 3 - Points: 1.5, Elo: 1885.65 winning probability: 0.00
# Player 4 - Points: 3, Elo: 2253.11 winning probability: 0.09
# Player 5 - Points: 0.5, Elo: 1662.13 winning probability: 0.01
# Player 6 - Points: 1.5, Elo: 1863.93 winning probability: 0.04
# Player 7 - Points: 2.5, Elo: 2030.22 winning probability: 0.00
# Player 8 - Points: 4.5, Elo: 2285.53 winning probability: 0.08
# Player 9 - Points: 2.0, Elo: 1902.17 winning probability: 0.76
#
# Simulation 396 - Final Round Results:
# Player 0 - Points: 2.0, Elo: 1690.70 winning probability: 1.29
# Player 1 - Points: 2.5, Elo: 2048.13 winning probability: 0.01
# Player 2 - Points: 0, Elo: 1810.30 winning probability: 0.23
# Player 3 - Points: 2.0, Elo: 2119.70 winning probability: 0.00
# Player 4 - Points: 2.0, Elo: 1831.95 winning probability: 0.09
# Player 5 - Points: 3.5, Elo: 2209.45 winning probability: 0.01
# Player 6 - Points: 5, Elo: 2534.66 winning probability: 0.04
# Player 7 - Points: 1, Elo: 1642.20 winning probability: 0.00
# Player 8 - Points: 2.0, Elo: 2085.30 winning probability: 0.08
# Player 9 - Points: 3.0, Elo: 2390.62 winning probability: 0.76
#
# Simulation 397 - Final Round Results:
# Player 0 - Points: 2.5, Elo: 2301.75 winning probability: 1.29
# Player 1 - Points: 1, Elo: 1728.81 winning probability: 0.01
# Player 2 - Points: 3.0, Elo: 1847.14 winning probability: 0.23
# Player 3 - Points: 2.0, Elo: 2042.38 winning probability: 0.00
# Player 4 - Points: 1.0, Elo: 1621.11 winning probability: 0.09
# Player 5 - Points: 3.0, Elo: 2115.20 winning probability: 0.01
# Player 6 - Points: 2.5, Elo: 2082.06 winning probability: 0.04
# Player 7 - Points: 4.5, Elo: 2495.35 winning probability: 0.00
# Player 8 - Points: 4, Elo: 2486.06 winning probability: 0.08
# Player 9 - Points: 0.5, Elo: 1930.14 winning probability: 0.76
#
# Simulation 398 - Final Round Results:
# Player 0 - Points: 2.5, Elo: 2155.08 winning probability: 1.29
# Player 1 - Points: 4.0, Elo: 2544.81 winning probability: 0.01
# Player 2 - Points: 3.0, Elo: 2306.53 winning probability: 0.23
# Player 3 - Points: 1, Elo: 1578.00 winning probability: 0.00
# Player 4 - Points: 3.0, Elo: 2346.57 winning probability: 0.09
# Player 5 - Points: 0, Elo: 1430.76 winning probability: 0.01
# Player 6 - Points: 4.5, Elo: 2523.80 winning probability: 0.04
# Player 7 - Points: 2.5, Elo: 2361.11 winning probability: 0.00
# Player 8 - Points: 2.5, Elo: 2407.41 winning probability: 0.08
# Player 9 - Points: 1, Elo: 1756.93 winning probability: 0.76
#
# Simulation 399 - Final Round Results:
# Player 0 - Points: 1.5, Elo: 1715.55 winning probability: 1.29
# Player 1 - Points: 2, Elo: 1735.77 winning probability: 0.01
# Player 2 - Points: 4.5, Elo: 2360.57 winning probability: 0.23
# Player 3 - Points: 4, Elo: 2095.58 winning probability: 0.00
# Player 4 - Points: 3, Elo: 1798.14 winning probability: 0.09
# Player 5 - Points: 0.5, Elo: 1692.55 winning probability: 0.01
# Player 6 - Points: 2, Elo: 2301.10 winning probability: 0.04
# Player 7 - Points: 0.5, Elo: 1686.79 winning probability: 0.00
# Player 8 - Points: 3, Elo: 1606.34 winning probability: 0.08
# Player 9 - Points: 3, Elo: 1931.62 winning probability: 0.76
#
# Simulation 400 - Final Round Results:
# Player 0 - Points: 3.5, Elo: 2493.09 winning probability: 1.29
# Player 1 - Points: 1.5, Elo: 1529.65 winning probability: 0.01
# Player 2 - Points: 1, Elo: 1816.70 winning probability: 0.23
# Player 3 - Points: 0.5, Elo: 2023.60 winning probability: 0.00
# Player 4 - Points: 4.5, Elo: 2341.15 winning probability: 0.09
# Player 5 - Points: 4.0, Elo: 2370.89 winning probability: 0.01
# Player 6 - Points: 2.5, Elo: 1573.98 winning probability: 0.04
# Player 7 - Points: 1.0, Elo: 1599.71 winning probability: 0.00
# Player 8 - Points: 3, Elo: 1740.73 winning probability: 0.08
# Player 9 - Points: 2.5, Elo: 1777.50 winning probability: 0.76

# %%
import random

# Number of Players, Rounds, and Simulations
num_players = 10
num_rounds = 5
num_simulations = 1000
k_factor = 20  # K-factor for Elo rating updates

# Initialize Players with Elo ratings
players = [{'name': f'Player {i}', 'elo': random.randint(1400, 2600), 'points': 0, 'wins': 0} for i in range(num_players)]

def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2 """
    return 1 / (1 + 10 ** ((player2['elo'] - player1['elo']) / 400))

def update_elo_ratings(winner, loser, draw=False):
    """ Update Elo ratings after a game """
    expected_win_winner = calculate_win_probability(winner, loser)
    expected_win_loser = calculate_win_probability(loser, winner)

    score_winner = 0.5 if draw else 1
    score_loser = 0.5 if draw else 0

    winner['elo'] += k_factor * (score_winner - expected_win_winner)
    loser['elo'] += k_factor * (score_loser - expected_win_loser)

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
        update_elo_ratings(player1, player2)
    elif result < win_prob + (1 - win_prob) / 2:
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
        update_elo_ratings(player1, player2, draw=True)
    else:
        player2['points'] += 1  # Player 2 wins
        update_elo_ratings(player2, player1)

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

def print_final_round_statistics(players, simulation_number):
    """ Print statistics for the final round """
    if 990 <= simulation_number <= 1000:
        print(f"\nSimulation {simulation_number} - Final Round Results:")
        for player in players:
            winning_probability = player['wins'] / num_simulations
            print(f"{player['name']} - Points: {player['points']}, Elo: {player['elo']:.2f}, Winning Probability: {winning_probability:.2f}")

def simulate_tournament(simulation_number):
    """ Simulate a single Swiss-system tournament """
    # Reset points and opponents for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []

    # Simulate rounds
    for round_number in range(1, num_rounds + 1):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)

    # Determine winner and update wins
    winner = max(players, key=lambda x: x['points'])
    winner['wins'] += 1

    # Print final round statistics for specified simulations
    if round_number == num_rounds:
        print_final_round_statistics(players, simulation_number)

# Simulate and Print Results
for simulation_number in range(1, num_simulations + 1):
    simulate_tournament(simulation_number)

# Reset wins count for next simulation
for player in players:
    player['wins'] = 0
# Out:
# Simulation 990 - Final Round Results:
# Player 0 - Points: 5, Elo: 2901.79, Winning Probability: 0.79
# Player 1 - Points: 1, Elo: 1457.79, Winning Probability: 0.00
# Player 2 - Points: 2.5, Elo: 1970.77, Winning Probability: 0.06
# Player 3 - Points: 3.0, Elo: 2028.35, Winning Probability: 0.00
# Player 4 - Points: 4, Elo: 2078.52, Winning Probability: 0.11
# Player 5 - Points: 2, Elo: 1836.34, Winning Probability: 0.00
# Player 6 - Points: 3.0, Elo: 1986.12, Winning Probability: 0.02
# Player 7 - Points: 2, Elo: 1851.67, Winning Probability: 0.00
# Player 8 - Points: 1.5, Elo: 2019.37, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1053.26, Winning Probability: 0.00
#
# Simulation 991 - Final Round Results:
# Player 0 - Points: 5, Elo: 2902.30, Winning Probability: 0.79
# Player 1 - Points: 1, Elo: 1457.89, Winning Probability: 0.00
# Player 2 - Points: 3, Elo: 1992.08, Winning Probability: 0.06
# Player 3 - Points: 3.0, Elo: 2028.91, Winning Probability: 0.00
# Player 4 - Points: 3, Elo: 2084.80, Winning Probability: 0.11
# Player 5 - Points: 2.0, Elo: 1831.71, Winning Probability: 0.00
# Player 6 - Points: 2.5, Elo: 1986.56, Winning Probability: 0.02
# Player 7 - Points: 2.5, Elo: 1854.28, Winning Probability: 0.00
# Player 8 - Points: 2, Elo: 1994.49, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1050.99, Winning Probability: 0.00
#
# Simulation 992 - Final Round Results:
# Player 0 - Points: 5, Elo: 2902.77, Winning Probability: 0.79
# Player 1 - Points: 2.0, Elo: 1492.19, Winning Probability: 0.00
# Player 2 - Points: 2, Elo: 1988.05, Winning Probability: 0.06
# Player 3 - Points: 1.5, Elo: 1993.91, Winning Probability: 0.00
# Player 4 - Points: 2.5, Elo: 2077.00, Winning Probability: 0.11
# Player 5 - Points: 2.0, Elo: 1838.56, Winning Probability: 0.00
# Player 6 - Points: 3.0, Elo: 1983.60, Winning Probability: 0.02
# Player 7 - Points: 2, Elo: 1839.51, Winning Probability: 0.00
# Player 8 - Points: 4, Elo: 2017.92, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1050.51, Winning Probability: 0.00
#
# Simulation 993 - Final Round Results:
# Player 0 - Points: 5, Elo: 2903.17, Winning Probability: 0.79
# Player 1 - Points: 1, Elo: 1490.63, Winning Probability: 0.00
# Player 2 - Points: 3.5, Elo: 2007.45, Winning Probability: 0.06
# Player 3 - Points: 2.5, Elo: 2005.73, Winning Probability: 0.00
# Player 4 - Points: 2.5, Elo: 2052.19, Winning Probability: 0.11
# Player 5 - Points: 1.5, Elo: 1846.20, Winning Probability: 0.00
# Player 6 - Points: 2.5, Elo: 1968.75, Winning Probability: 0.02
# Player 7 - Points: 1, Elo: 1829.36, Winning Probability: 0.00
# Player 8 - Points: 3.5, Elo: 2031.77, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1048.75, Winning Probability: 0.00
#
# Simulation 994 - Final Round Results:
# Player 0 - Points: 5, Elo: 2903.64, Winning Probability: 0.79
# Player 1 - Points: 0, Elo: 1484.00, Winning Probability: 0.00
# Player 2 - Points: 2.5, Elo: 2012.00, Winning Probability: 0.06
# Player 3 - Points: 3, Elo: 1991.42, Winning Probability: 0.00
# Player 4 - Points: 4, Elo: 2077.81, Winning Probability: 0.11
# Player 5 - Points: 2, Elo: 1838.26, Winning Probability: 0.00
# Player 6 - Points: 2, Elo: 1950.31, Winning Probability: 0.02
# Player 7 - Points: 2.5, Elo: 1845.43, Winning Probability: 0.00
# Player 8 - Points: 3, Elo: 2032.87, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1048.27, Winning Probability: 0.00
#
# Simulation 995 - Final Round Results:
# Player 0 - Points: 5, Elo: 2904.04, Winning Probability: 0.79
# Player 1 - Points: 2, Elo: 1499.92, Winning Probability: 0.00
# Player 2 - Points: 1.5, Elo: 2001.44, Winning Probability: 0.06
# Player 3 - Points: 2, Elo: 1980.88, Winning Probability: 0.00
# Player 4 - Points: 1.5, Elo: 2041.41, Winning Probability: 0.11
# Player 5 - Points: 3, Elo: 1847.90, Winning Probability: 0.00
# Player 6 - Points: 3.5, Elo: 1973.25, Winning Probability: 0.02
# Player 7 - Points: 2.5, Elo: 1848.21, Winning Probability: 0.00
# Player 8 - Points: 3, Elo: 2040.59, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1046.35, Winning Probability: 0.00
#
# Simulation 996 - Final Round Results:
# Player 0 - Points: 5, Elo: 2904.48, Winning Probability: 0.80
# Player 1 - Points: 1, Elo: 1496.76, Winning Probability: 0.00
# Player 2 - Points: 1.5, Elo: 1975.91, Winning Probability: 0.06
# Player 3 - Points: 2.5, Elo: 1993.42, Winning Probability: 0.00
# Player 4 - Points: 3.5, Elo: 2060.83, Winning Probability: 0.11
# Player 5 - Points: 1, Elo: 1830.64, Winning Probability: 0.00
# Player 6 - Points: 3, Elo: 1970.05, Winning Probability: 0.02
# Player 7 - Points: 3, Elo: 1858.41, Winning Probability: 0.00
# Player 8 - Points: 3.5, Elo: 2049.01, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1044.49, Winning Probability: 0.00
#
# Simulation 997 - Final Round Results:
# Player 0 - Points: 5, Elo: 2904.95, Winning Probability: 0.80
# Player 1 - Points: 1, Elo: 1493.88, Winning Probability: 0.00
# Player 2 - Points: 3, Elo: 1993.86, Winning Probability: 0.06
# Player 3 - Points: 2.5, Elo: 1975.93, Winning Probability: 0.00
# Player 4 - Points: 3.5, Elo: 2079.87, Winning Probability: 0.11
# Player 5 - Points: 1, Elo: 1815.14, Winning Probability: 0.00
# Player 6 - Points: 2.0, Elo: 1962.04, Winning Probability: 0.02
# Player 7 - Points: 3, Elo: 1867.63, Winning Probability: 0.00
# Player 8 - Points: 3, Elo: 2048.10, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1042.61, Winning Probability: 0.00
#
# Simulation 998 - Final Round Results:
# Player 0 - Points: 5, Elo: 2905.48, Winning Probability: 0.80
# Player 1 - Points: 1, Elo: 1492.39, Winning Probability: 0.00
# Player 2 - Points: 3, Elo: 2004.64, Winning Probability: 0.06
# Player 3 - Points: 3.0, Elo: 1992.76, Winning Probability: 0.00
# Player 4 - Points: 1.5, Elo: 2050.30, Winning Probability: 0.11
# Player 5 - Points: 2.0, Elo: 1811.94, Winning Probability: 0.00
# Player 6 - Points: 3.0, Elo: 1975.67, Winning Probability: 0.02
# Player 7 - Points: 2.5, Elo: 1855.12, Winning Probability: 0.00
# Player 8 - Points: 3.0, Elo: 2054.93, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1040.76, Winning Probability: 0.00
#
# Simulation 999 - Final Round Results:
# Player 0 - Points: 5, Elo: 2905.91, Winning Probability: 0.80
# Player 1 - Points: 1, Elo: 1489.83, Winning Probability: 0.00
# Player 2 - Points: 3.5, Elo: 2028.60, Winning Probability: 0.06
# Player 3 - Points: 3.5, Elo: 2015.62, Winning Probability: 0.00
# Player 4 - Points: 2.5, Elo: 2048.70, Winning Probability: 0.11
# Player 5 - Points: 2.5, Elo: 1826.41, Winning Probability: 0.00
# Player 6 - Points: 2, Elo: 1947.86, Winning Probability: 0.02
# Player 7 - Points: 2, Elo: 1856.98, Winning Probability: 0.00
# Player 8 - Points: 2, Elo: 2025.08, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1039.02, Winning Probability: 0.00
#
# Simulation 1000 - Final Round Results:
# Player 0 - Points: 5, Elo: 2906.38, Winning Probability: 0.80
# Player 1 - Points: 1, Elo: 1487.29, Winning Probability: 0.00
# Player 2 - Points: 1.5, Elo: 2013.38, Winning Probability: 0.06
# Player 3 - Points: 3, Elo: 2000.28, Winning Probability: 0.00
# Player 4 - Points: 4, Elo: 2076.30, Winning Probability: 0.11
# Player 5 - Points: 3, Elo: 1855.09, Winning Probability: 0.00
# Player 6 - Points: 1, Elo: 1914.60, Winning Probability: 0.02
# Player 7 - Points: 3, Elo: 1875.90, Winning Probability: 0.00
# Player 8 - Points: 2.5, Elo: 2017.43, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1037.35, Winning Probability: 0.00

# %%
import random

# Number of Players, Rounds, and Simulations
num_players = 10
num_rounds = 5
num_simulations = 10000
k_factor = 30  # Higher K-factor for more responsive Elo rating updates

# Initialize Players with Elo ratings
players = [{'name': f'Player {i}', 'elo': random.randint(1400, 2000), 'points': 0, 'wins': 0, 'current_form': 0} for i in range(num_players)]

def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2, considering current form """
    # Adjusting Elo ratings based on current form
    adjusted_elo1 = player1['elo'] + player1['current_form']
    adjusted_elo2 = player2['elo'] + player2['current_form']
    return 1 / (1 + 10 ** ((adjusted_elo2 - adjusted_elo1) / 400))

def update_elo_ratings(winner, loser, draw=False):
    """ Update Elo ratings and current form after a game """
    expected_win_winner = calculate_win_probability(winner, loser)
    expected_win_loser = calculate_win_probability(loser, winner)

    score_winner = 0.5 if draw else 1
    score_loser = 0.5 if draw else 0

    winner['elo'] += k_factor * (score_winner - expected_win_winner)
    loser['elo'] += k_factor * (score_loser - expected_win_loser)

    # Update current form based on recent game outcome
    winner['current_form'] += k_factor * 0.5 if not draw else -k_factor * 0.2
    loser['current_form'] += -k_factor * 0.5 if not draw else k_factor * 0.2

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
        update_elo_ratings(player1, player2)
    elif result < win_prob + (1 - win_prob) / 2:
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
        update_elo_ratings(player1, player2, draw=True)
    else:
        player2['points'] += 1  # Player 2 wins
        update_elo_ratings(player2, player1)

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

def print_final_round_statistics(players, simulation_number):
    """ Print statistics for the final round """
    if 9990 <= simulation_number <= 10000:
        print(f"\nSimulation {simulation_number} - Final Round Results:")
        for player in players:
            winning_probability = player['wins'] / num_simulations
            print(f"{player['name']} - Points: {player['points']}, Elo: {player['elo']:.2f}, Winning Probability: {winning_probability:.2f}")

def simulate_tournament(simulation_number):
    """ Simulate a single Swiss-system tournament """
    # Reset points, opponents, and current form for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []
        player['current_form'] = 0
        player['elo'] = random.randint(1400, 2000)  # Reset Elo for each simulation

    # Simulate rounds
    for round_number in range(1, num_rounds + 1):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)

    # Determine winner and update wins
    winner = max(players, key=lambda x: x['points'])
    winner['wins'] += 1

    # Print final round statistics for specified simulations
    if round_number == num_rounds:
        print_final_round_statistics(players, simulation_number)

# Simulate and Print Results
for simulation_number in range(1, num_simulations + 1):
    simulate_tournament(simulation_number)
# Out:
# Simulation 9990 - Final Round Results:
# Player 0 - Points: 2, Elo: 1865.93, Winning Probability: 0.19
# Player 1 - Points: 3, Elo: 1960.75, Winning Probability: 0.13
# Player 2 - Points: 0.5, Elo: 1529.58, Winning Probability: 0.12
# Player 3 - Points: 4.5, Elo: 1936.63, Winning Probability: 0.08
# Player 4 - Points: 1.0, Elo: 1666.22, Winning Probability: 0.11
# Player 5 - Points: 2, Elo: 1954.33, Winning Probability: 0.07
# Player 6 - Points: 3, Elo: 1918.40, Winning Probability: 0.09
# Player 7 - Points: 2.5, Elo: 1797.20, Winning Probability: 0.06
# Player 8 - Points: 1.5, Elo: 1636.23, Winning Probability: 0.08
# Player 9 - Points: 4.0, Elo: 1809.74, Winning Probability: 0.05
#
# Simulation 9991 - Final Round Results:
# Player 0 - Points: 3, Elo: 1874.72, Winning Probability: 0.19
# Player 1 - Points: 2.5, Elo: 1948.65, Winning Probability: 0.13
# Player 2 - Points: 0.5, Elo: 1395.86, Winning Probability: 0.12
# Player 3 - Points: 3.5, Elo: 1477.66, Winning Probability: 0.08
# Player 4 - Points: 5, Elo: 1915.94, Winning Probability: 0.11
# Player 5 - Points: 1, Elo: 1439.50, Winning Probability: 0.07
# Player 6 - Points: 2.5, Elo: 1597.65, Winning Probability: 0.09
# Player 7 - Points: 2.5, Elo: 1640.00, Winning Probability: 0.06
# Player 8 - Points: 2, Elo: 1903.75, Winning Probability: 0.08
# Player 9 - Points: 0.5, Elo: 1497.27, Winning Probability: 0.05
#
# Simulation 9992 - Final Round Results:
# Player 0 - Points: 2.0, Elo: 1690.02, Winning Probability: 0.19
# Player 1 - Points: 3.5, Elo: 1750.30, Winning Probability: 0.13
# Player 2 - Points: 1.5, Elo: 1491.63, Winning Probability: 0.12
# Player 3 - Points: 2.5, Elo: 1795.99, Winning Probability: 0.08
# Player 4 - Points: 2.5, Elo: 1854.03, Winning Probability: 0.11
# Player 5 - Points: 4.5, Elo: 1946.31, Winning Probability: 0.07
# Player 6 - Points: 1.5, Elo: 1430.49, Winning Probability: 0.09
# Player 7 - Points: 2.0, Elo: 1772.85, Winning Probability: 0.06
# Player 8 - Points: 0.5, Elo: 1404.37, Winning Probability: 0.08
# Player 9 - Points: 3.5, Elo: 1937.00, Winning Probability: 0.05
#
# Simulation 9993 - Final Round Results:
# Player 0 - Points: 1.5, Elo: 1522.98, Winning Probability: 0.19
# Player 1 - Points: 3.5, Elo: 1870.86, Winning Probability: 0.13
# Player 2 - Points: 4.0, Elo: 1790.64, Winning Probability: 0.12
# Player 3 - Points: 0.5, Elo: 1481.42, Winning Probability: 0.08
# Player 4 - Points: 3.5, Elo: 1953.98, Winning Probability: 0.11
# Player 5 - Points: 2.5, Elo: 1724.62, Winning Probability: 0.07
# Player 6 - Points: 1.0, Elo: 1423.71, Winning Probability: 0.09
# Player 7 - Points: 2, Elo: 1679.44, Winning Probability: 0.06
# Player 8 - Points: 1.5, Elo: 1604.30, Winning Probability: 0.08
# Player 9 - Points: 4, Elo: 1885.05, Winning Probability: 0.05
#
# Simulation 9994 - Final Round Results:
# Player 0 - Points: 3.0, Elo: 1902.98, Winning Probability: 0.19
# Player 1 - Points: 2.5, Elo: 1718.92, Winning Probability: 0.13
# Player 2 - Points: 5, Elo: 1975.76, Winning Probability: 0.12
# Player 3 - Points: 1.5, Elo: 1655.74, Winning Probability: 0.08
# Player 4 - Points: 2.5, Elo: 1737.21, Winning Probability: 0.11
# Player 5 - Points: 2.0, Elo: 1692.58, Winning Probability: 0.07
# Player 6 - Points: 1.5, Elo: 1832.08, Winning Probability: 0.09
# Player 7 - Points: 0, Elo: 1705.51, Winning Probability: 0.06
# Player 8 - Points: 3.0, Elo: 1958.52, Winning Probability: 0.08
# Player 9 - Points: 3.0, Elo: 1721.70, Winning Probability: 0.05
#
# Simulation 9995 - Final Round Results:
# Player 0 - Points: 1.5, Elo: 1477.05, Winning Probability: 0.19
# Player 1 - Points: 2.0, Elo: 1454.23, Winning Probability: 0.13
# Player 2 - Points: 1.5, Elo: 1487.42, Winning Probability: 0.12
# Player 3 - Points: 3.5, Elo: 1957.39, Winning Probability: 0.08
# Player 4 - Points: 4.0, Elo: 1877.32, Winning Probability: 0.11
# Player 5 - Points: 2, Elo: 1670.47, Winning Probability: 0.07
# Player 6 - Points: 1, Elo: 1577.80, Winning Probability: 0.09
# Player 7 - Points: 0, Elo: 1393.90, Winning Probability: 0.06
# Player 8 - Points: 3.5, Elo: 1793.02, Winning Probability: 0.08
# Player 9 - Points: 4.0, Elo: 1871.40, Winning Probability: 0.05
#
# Simulation 9996 - Final Round Results:
# Player 0 - Points: 1.5, Elo: 1430.19, Winning Probability: 0.19
# Player 1 - Points: 3.0, Elo: 1898.81, Winning Probability: 0.13
# Player 2 - Points: 5, Elo: 1957.24, Winning Probability: 0.12
# Player 3 - Points: 3, Elo: 1620.73, Winning Probability: 0.08
# Player 4 - Points: 2.0, Elo: 1673.35, Winning Probability: 0.11
# Player 5 - Points: 2.5, Elo: 1545.32, Winning Probability: 0.07
# Player 6 - Points: 1, Elo: 1544.96, Winning Probability: 0.09
# Player 7 - Points: 2.5, Elo: 1525.88, Winning Probability: 0.06
# Player 8 - Points: 3.5, Elo: 1631.50, Winning Probability: 0.08
# Player 9 - Points: 1, Elo: 1521.03, Winning Probability: 0.05
#
# Simulation 9997 - Final Round Results:
# Player 0 - Points: 1, Elo: 1458.16, Winning Probability: 0.19
# Player 1 - Points: 2.0, Elo: 1816.01, Winning Probability: 0.13
# Player 2 - Points: 3.0, Elo: 1830.23, Winning Probability: 0.12
# Player 3 - Points: 2.5, Elo: 1945.66, Winning Probability: 0.08
# Player 4 - Points: 4.0, Elo: 1798.89, Winning Probability: 0.11
# Player 5 - Points: 0.5, Elo: 1481.37, Winning Probability: 0.07
# Player 6 - Points: 3, Elo: 1943.76, Winning Probability: 0.09
# Player 7 - Points: 2.0, Elo: 1600.35, Winning Probability: 0.06
# Player 8 - Points: 2.5, Elo: 1733.66, Winning Probability: 0.08
# Player 9 - Points: 4.5, Elo: 1893.92, Winning Probability: 0.05
#
# Simulation 9998 - Final Round Results:
# Player 0 - Points: 3.0, Elo: 1714.92, Winning Probability: 0.19
# Player 1 - Points: 3.5, Elo: 1704.22, Winning Probability: 0.13
# Player 2 - Points: 3.0, Elo: 1611.46, Winning Probability: 0.12
# Player 3 - Points: 0.5, Elo: 1521.48, Winning Probability: 0.08
# Player 4 - Points: 1.5, Elo: 1615.09, Winning Probability: 0.11
# Player 5 - Points: 0.5, Elo: 1442.52, Winning Probability: 0.07
# Player 6 - Points: 4, Elo: 1939.89, Winning Probability: 0.09
# Player 7 - Points: 2.5, Elo: 1654.69, Winning Probability: 0.06
# Player 8 - Points: 3.5, Elo: 1673.74, Winning Probability: 0.08
# Player 9 - Points: 2.0, Elo: 1751.00, Winning Probability: 0.05
#
# Simulation 9999 - Final Round Results:
# Player 0 - Points: 0, Elo: 1383.68, Winning Probability: 0.19
# Player 1 - Points: 1.5, Elo: 1619.47, Winning Probability: 0.13
# Player 2 - Points: 3.0, Elo: 1732.14, Winning Probability: 0.12
# Player 3 - Points: 2, Elo: 1609.82, Winning Probability: 0.08
# Player 4 - Points: 3.0, Elo: 1813.31, Winning Probability: 0.11
# Player 5 - Points: 2, Elo: 1636.53, Winning Probability: 0.07
# Player 6 - Points: 3.0, Elo: 1786.79, Winning Probability: 0.09
# Player 7 - Points: 3.5, Elo: 1908.24, Winning Probability: 0.06
# Player 8 - Points: 1, Elo: 1764.79, Winning Probability: 0.08
# Player 9 - Points: 5, Elo: 1978.22, Winning Probability: 0.05
#
# Simulation 10000 - Final Round Results:
# Player 0 - Points: 4.0, Elo: 1819.48, Winning Probability: 0.19
# Player 1 - Points: 1, Elo: 1448.00, Winning Probability: 0.13
# Player 2 - Points: 2.5, Elo: 1641.25, Winning Probability: 0.12
# Player 3 - Points: 3, Elo: 1905.08, Winning Probability: 0.08
# Player 4 - Points: 1, Elo: 1514.29, Winning Probability: 0.11
# Player 5 - Points: 3, Elo: 1787.27, Winning Probability: 0.07
# Player 6 - Points: 0, Elo: 1480.08, Winning Probability: 0.09
# Player 7 - Points: 4.5, Elo: 1671.41, Winning Probability: 0.06
# Player 8 - Points: 2.0, Elo: 1426.47, Winning Probability: 0.08
# Player 9 - Points: 3.0, Elo: 1625.66, Winning Probability: 0.05

# %%
import random

# Number of Players, Rounds, and Simulations
num_players = 10
num_rounds = 5
num_simulations = 1000
k_factor = 30  # Higher K-factor for more responsive Elo rating updates

# Initialize Players with Elo ratings
players = [{'name': f'Player {i}', 'initial_elo': random.randint(1400, 2600), 'elo': 0, 'points': 0, 'total_points': 0, 'wins': 0, 'current_form': 0} for i in range(num_players)]

def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2, considering current form """
    adjusted_elo1 = player1['elo'] + player1['current_form']
    adjusted_elo2 = player2['elo'] + player2['current_form']
    return 1 / (1 + 10 ** ((adjusted_elo2 - adjusted_elo1) / 400))

def update_elo_ratings(winner, loser, draw=False):
    """ Update Elo ratings and current form after a game """
    expected_win_winner = calculate_win_probability(winner, loser)
    expected_win_loser = calculate_win_probability(loser, winner)

    score_winner = 0.5 if draw else 1
    score_loser = 0.5 if draw else 0

    winner['elo'] += k_factor * (score_winner - expected_win_winner)
    loser['elo'] += k_factor * (score_loser - expected_win_loser)

    # Update current form based on recent game outcome
    winner['current_form'] += k_factor * 0.5 if not draw else -k_factor * 0.2
    loser['current_form'] += -k_factor * 0.5 if not draw else k_factor * 0.2

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
        update_elo_ratings(player1, player2)
    elif result < win_prob + (1 - win_prob) / 2:
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
        update_elo_ratings(player1, player2, draw=True)
    else:
        player2['points'] += 1  # Player 2 wins
        update_elo_ratings(player2, player1)

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

def simulate_tournament():
    """ Simulate a single Swiss-system tournament """
    # Reset points and opponents for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []
        player['current_form'] = 0
        player['elo'] = player['initial_elo']  # Reset Elo to initial Elo for each simulation

    # Simulate rounds
    for round_number in range(1, num_rounds + 1):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)

    # Determine winner and update wins
    winner = max(players, key=lambda x: x['points'])
    winner['wins'] += 1

    # Accumulate total points for each player
    for player in players:
        player['total_points'] += player['points']

# Simulate all tournaments
for _ in range(1, num_simulations + 1):
    simulate_tournament()

# Calculate and print final results after all simulations
print("\nFinal Tournament Results after all simulations:")
for player in players:
    winning_probability = player['wins'] / num_simulations
    average_points = player['total_points'] / num_simulations
    print(f"{player['name']} - Initial Elo: {player['initial_elo']}, Final Elo: {player['elo']:.2f}, Average Points: {average_points:.2f}, Winning Probability: {winning_probability:.2f}")
# Out:
# Final Tournament Results after all simulations:
# Player 0 - Initial Elo: 1837, Final Elo: 1842.54, Average Points: 2.12, Winning Probability: 0.01
# Player 1 - Initial Elo: 1722, Final Elo: 1694.50, Average Points: 1.55, Winning Probability: 0.00
# Player 2 - Initial Elo: 2261, Final Elo: 2239.87, Average Points: 3.60, Winning Probability: 0.35
# Player 3 - Initial Elo: 1563, Final Elo: 1534.74, Average Points: 1.05, Winning Probability: 0.00
# Player 4 - Initial Elo: 2314, Final Elo: 2335.21, Average Points: 3.69, Winning Probability: 0.30
# Player 5 - Initial Elo: 2365, Final Elo: 2347.04, Average Points: 3.66, Winning Probability: 0.26
# Player 6 - Initial Elo: 1752, Final Elo: 1761.65, Average Points: 1.94, Winning Probability: 0.00
# Player 7 - Initial Elo: 1471, Final Elo: 1518.49, Average Points: 0.87, Winning Probability: 0.00
# Player 8 - Initial Elo: 2050, Final Elo: 2044.62, Average Points: 2.81, Winning Probability: 0.04
# Player 9 - Initial Elo: 2124, Final Elo: 2140.33, Average Points: 2.90, Winning Probability: 0.04

# %% [markdown]
# # Final code- 04 Dec

# %%
import random

# Number of Players, Rounds, and Simulations
num_players = 10
num_rounds = 5
num_simulations = 1000
k_factor = 10  # Higher K-factor for more responsive Elo rating updates

# Initialize Players with Elo ratings
players = [{'name': f'Player {i}', 'elo': random.randint(1200, 2000), 'points': 0, 'wins': 0, 'current_form': 0} for i in range(num_players)]

for player in players:
    print(f"{player ['name']} - Init Elo: {player['elo']:.2f}")
    
def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2, considering current form """
    # Adjusting Elo ratings based on current form
    adjusted_elo1 = player1['elo'] + player1['current_form']
    adjusted_elo2 = player2['elo'] + player2['current_form']
    return 1 / (1 + 10 ** ((adjusted_elo2 - adjusted_elo1) / 400))

def update_elo_ratings(winner, loser, draw=False):
    """ Update Elo ratings and current form after a game """
    expected_win_winner = calculate_win_probability(winner, loser)
    expected_win_loser = calculate_win_probability(loser, winner)

    score_winner = 0.5 if draw else 1
    score_loser = 0.5 if draw else 0

    winner['elo'] += k_factor * (score_winner - expected_win_winner)
    loser['elo'] += k_factor * (score_loser - expected_win_loser)

    # Update current form based on recent game outcome
    winner['current_form'] += k_factor * 1.2 if not draw else -k_factor * 0.3
    loser['current_form'] += -k_factor * 1.2 if not draw else k_factor * 0.5

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
        update_elo_ratings(player1, player2)
    elif result < win_prob + (1 - win_prob) / 2:
#         print(player1['name'], player2['name'], " draw")
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
        update_elo_ratings(player1, player2, draw=True)
    else:
        player2['points'] += 1  # Player 2 wins
        update_elo_ratings(player2, player1)

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

def print_final_round_statistics(players, simulation_number):
    """ Print statistics for the final round """
    if 9990 <= simulation_number <= 10000:
        print(f"\nSimulation {simulation_number} - Final Round Results:")
        for player in players:
            winning_probability = player['wins'] / num_simulations
            print(f"{player['name']} - Points: {player['points']}, Elo: {player['elo']:.2f}, Winning Probability: {winning_probability:.2f}")

def simulate_tournament():
    """ Simulate a single Swiss-system tournament """
    # Reset points and opponents for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []
        player['current_form'] = 0

    # Simulate rounds
    for round_number in range(1, num_rounds + 1):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)

    # Determine winner and update wins
    winner = max(players, key=lambda x: x['points'])
    winner['wins'] += 1
    
    
# Reset wins count before all simulations
for player in players:
    player['wins'] = 0

# Simulate all tournaments
for _ in range(1, num_simulations + 1):
    simulate_tournament()

    
# Calculate and print final probabilities after all simulations
print("\nFinal Tournament Results after all simulations:")
for player in players:
    winning_probability = player['wins'] / num_simulations
    print(f"{player['name']} - - Points: {player['points']} - - Final Elo: {player['elo']:.2f} - - Winning Probability: {winning_probability:.2f}")
# Out:
# Player 0 - Init Elo: 1556.00
# Player 1 - Init Elo: 1548.00
# Player 2 - Init Elo: 1991.00
# Player 3 - Init Elo: 1214.00
# Player 4 - Init Elo: 1232.00
# Player 5 - Init Elo: 1698.00
# Player 6 - Init Elo: 1396.00
# Player 7 - Init Elo: 1531.00
# Player 8 - Init Elo: 1751.00
# Player 9 - Init Elo: 1707.00
#
# Final Tournament Results after all simulations:
# Player 0 - - Points: 4.5 - - Final Elo: 2165.36 - - Winning Probability: 0.76
# Player 1 - - Points: 1 - - Final Elo: 1236.82 - - Winning Probability: 0.01
# Player 2 - - Points: 2.5 - - Final Elo: 1606.58 - - Winning Probability: 0.12
# Player 3 - - Points: 3 - - Final Elo: 1609.79 - - Winning Probability: 0.00
# Player 4 - - Points: 4.5 - - Final Elo: 1989.47 - - Winning Probability: 0.05
# Player 5 - - Points: 1 - - Final Elo: 1345.61 - - Winning Probability: 0.01
# Player 6 - - Points: 2 - - Final Elo: 1662.80 - - Winning Probability: 0.01
# Player 7 - - Points: 2.5 - - Final Elo: 1485.15 - - Winning Probability: 0.00
# Player 8 - - Points: 3 - - Final Elo: 1722.38 - - Winning Probability: 0.04
# Player 9 - - Points: 0 - - Final Elo: 800.05 - - Winning Probability: 0.00
