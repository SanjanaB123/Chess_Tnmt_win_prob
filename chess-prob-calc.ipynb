# %%
import random

# Number of Players and Rounds
num_players = 10
num_rounds = 5
num_simulations = 1000

# Sample Players with Elo ratings (example data)
players = [{'name': f'Player {i}', 'elo': random.randint(1400, 2600), 'points': 0} for i in range(num_players)]



def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2 """
    return 1 / (1 + 10 ** ((player2['elo'] - player1['elo']) / 400))

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
    elif result < win_prob + (1 - win_prob) / 2:
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
    else:
        player2['points'] += 1  # Player 2 wins

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            # Avoid pairing the same players again (simple check)
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

# %%
def simulate_tournament():
    """ Simulate a single Swiss-system tournament """
    # Reset points and opponents for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []

    # Simulate rounds
    for _ in range(num_rounds):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)

    # Determine winner (basic - most points)
    winner = max(players, key=lambda x: x['points'])
    return winner['name']

# Run multiple simulations and tally wins
tournament_wins = {player['name']: 0 for player in players}
for _ in range(num_simulations):
    winner = simulate_tournament()
    tournament_wins[winner] += 1

# Print probabilities of winning the tournament
for player in players:
    probability = tournament_wins[player['name']] / num_simulations
    print(f"{player['name']} winning probability: {probability:.2f}")
# Out:
# Player 0 winning probability: 0.52
# Player 1 winning probability: 0.00
# Player 2 winning probability: 0.09
# Player 3 winning probability: 0.00
# Player 4 winning probability: 0.04
# Player 5 winning probability: 0.00
# Player 6 winning probability: 0.02
# Player 7 winning probability: 0.00
# Player 8 winning probability: 0.03
# Player 9 winning probability: 0.30

# %%
import random

# Number of Players, Rounds, and Simulations
num_players = 10
num_rounds = 5
num_simulations = 1000
k_factor = 20  # K-factor for Elo rating updates

# Initialize Players with Elo ratings
players = [{'name': f'Player {i}', 'elo': random.randint(1400, 2600), 'points': 0} for i in range(num_players)]

def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2 """
    return 1 / (1 + 10 ** ((player2['elo'] - player1['elo']) / 400))

def update_elo_ratings(winner, loser, draw=False):
    """ Update Elo ratings after a game """
    expected_win_winner = calculate_win_probability(winner, loser)
    expected_win_loser = calculate_win_probability(loser, winner)

    score_winner = 0.5 if draw else 1
    score_loser = 0.5 if draw else 0

    winner['elo'] += k_factor * (score_winner - expected_win_winner)
    loser['elo'] += k_factor * (score_loser - expected_win_loser)

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
        update_elo_ratings(player1, player2)
    elif result < win_prob + (1 - win_prob) / 2:
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
        update_elo_ratings(player1, player2, draw=True)
    else:
        player2['points'] += 1  # Player 2 wins
        update_elo_ratings(player2, player1)

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

def print_round_statistics(players, round_number):
    """ Print statistics after each round """
    print(f"\nAfter Round {round_number}:")
    for player in players:
        print(f"{player['name']} - Points: {player['points']}, Elo: {player['elo']:.2f}")

def simulate_tournament():
    """ Simulate a single Swiss-system tournament """
    # Reset points and opponents for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []
        player['elo'] = random.randint(1400, 2600)  # Reset Elo for each simulation

    # Simulate rounds
    for round_number in range(1, num_rounds + 1):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)
        print_round_statistics(players, round_number)

    # Determine winner (most points)
    winner = max(players, key=lambda x: x['points'])
    return winner['name']

# Simulate and Print Results
for _ in range(num_simulations):
    simulate_tournament()
# Out:
# After Round 1:
# Player 0 - Points: 1, Elo: 2520.01
# Player 1 - Points: 0, Elo: 2134.99
# Player 2 - Points: 0, Elo: 1936.46
# Player 3 - Points: 1, Elo: 2560.54
# Player 4 - Points: 0, Elo: 1726.17
# Player 5 - Points: 1, Elo: 2273.83
# Player 6 - Points: 1, Elo: 1647.09
# Player 7 - Points: 0, Elo: 1662.91
# Player 8 - Points: 1, Elo: 2365.82
# Player 9 - Points: 0, Elo: 2478.18
#
# After Round 2:
# Player 0 - Points: 1, Elo: 2511.17
# Player 1 - Points: 0, Elo: 2130.81
# Player 2 - Points: 1, Elo: 1941.05
# Player 3 - Points: 2, Elo: 2569.38
# Player 4 - Points: 0, Elo: 1721.58
# Player 5 - Points: 2, Elo: 2274.36
# Player 6 - Points: 1, Elo: 1646.56
# Player 7 - Points: 0.5, Elo: 1672.73
# Player 8 - Points: 2, Elo: 2370.01
# Player 9 - Points: 0.5, Elo: 2468.36
#
# After Round 3:
# Player 0 - Points: 2, Elo: 2517.32
# Player 1 - Points: 0.5, Elo: 2122.14
# Player 2 - Points: 2, Elo: 1944.15
# Player 3 - Points: 2.5, Elo: 2562.47
# Player 4 - Points: 0, Elo: 1721.31
# Player 5 - Points: 2.5, Elo: 2281.26
# Player 6 - Points: 1, Elo: 1643.46
# Player 7 - Points: 1.0, Elo: 1681.39
# Player 8 - Points: 2, Elo: 2363.87
# Player 9 - Points: 1.5, Elo: 2468.62
#
# After Round 4:
# Player 0 - Points: 2.5, Elo: 2511.40
# Player 1 - Points: 1.0, Elo: 2113.34
# Player 2 - Points: 2, Elo: 1943.22
# Player 3 - Points: 3.5, Elo: 2567.31
# Player 4 - Points: 0, Elo: 1710.17
# Player 5 - Points: 3.0, Elo: 2287.17
# Player 6 - Points: 1.5, Elo: 1652.26
# Player 7 - Points: 2.0, Elo: 1692.54
# Player 8 - Points: 2, Elo: 2359.03
# Player 9 - Points: 2.5, Elo: 2469.56
#
# After Round 5:
# Player 0 - Points: 3.5, Elo: 2511.58
# Player 1 - Points: 2.0, Elo: 2115.13
# Player 2 - Points: 2, Elo: 1940.80
# Player 3 - Points: 3.5, Elo: 2554.56
# Player 4 - Points: 0, Elo: 1708.38
# Player 5 - Points: 4.0, Elo: 2289.60
# Player 6 - Points: 1.5, Elo: 1651.93
# Player 7 - Points: 2.0, Elo: 1692.36
# Player 8 - Points: 3, Elo: 2359.37
# Player 9 - Points: 3.5, Elo: 2482.30
#
# After Round 1:
# Player 0 - Points: 0, Elo: 1999.54
# Player 1 - Points: 1, Elo: 1699.46
# Player 2 - Points: 0.5, Elo: 1488.60
# Player 3 - Points: 0.5, Elo: 1819.40
# Player 4 - Points: 0.5, Elo: 1639.85
# Player 5 - Points: 0.5, Elo: 2464.15
# Player 6 - Points: 0.5, Elo: 1632.28
# Player 7 - Points: 0.5, Elo: 1825.72
# Player 8 - Points: 1, Elo: 2575.32
# Player 9 - Points: 0, Elo: 1859.68
#
# After Round 2:
# Player 0 - Points: 1, Elo: 2001.69
# Player 1 - Points: 1.5, Elo: 1709.33
# Player 2 - Points: 1.0, Elo: 1492.70
# Player 3 - Points: 1.0, Elo: 1828.92
# Player 4 - Points: 1.0, Elo: 1635.75
# Player 5 - Points: 1.0, Elo: 2454.63
# Player 6 - Points: 0.5, Elo: 1630.12
# Player 7 - Points: 1.0, Elo: 1826.70
# Player 8 - Points: 1.5, Elo: 2565.45
# Player 9 - Points: 0.5, Elo: 1858.70
#
# After Round 3:
# Player 0 - Points: 1, Elo: 2000.94
# Player 1 - Points: 2.5, Elo: 1713.80
# Player 2 - Points: 1.0, Elo: 1488.23
# Player 3 - Points: 2.0, Elo: 1833.87
# Player 4 - Points: 1.0, Elo: 1630.80
# Player 5 - Points: 2.0, Elo: 2455.16
# Player 6 - Points: 1.5, Elo: 1645.89
# Player 7 - Points: 1.0, Elo: 1826.17
# Player 8 - Points: 2.5, Elo: 2566.20
# Player 9 - Points: 0.5, Elo: 1842.94
#
# After Round 4:
# Player 0 - Points: 2, Elo: 2003.07
# Player 1 - Points: 2.5, Elo: 1707.12
# Player 2 - Points: 1.0, Elo: 1482.48
# Player 3 - Points: 3.0, Elo: 1840.55
# Player 4 - Points: 1.0, Elo: 1628.68
# Player 5 - Points: 2.0, Elo: 2448.25
# Player 6 - Points: 2.5, Elo: 1651.64
# Player 7 - Points: 1.0, Elo: 1826.17
# Player 8 - Points: 3.5, Elo: 2573.11
# Player 9 - Points: 0.5, Elo: 1842.94
#
# After Round 5:
# Player 0 - Points: 2.5, Elo: 2011.63
# Player 1 - Points: 3.5, Elo: 1715.54
# Player 2 - Points: 1.5, Elo: 1490.05
# Player 3 - Points: 3.0, Elo: 1840.26
# Player 4 - Points: 1.5, Elo: 1634.16
# Player 5 - Points: 2.5, Elo: 2439.68
# Player 6 - Points: 2.5, Elo: 1643.23
# Player 7 - Points: 1.5, Elo: 1818.60
# Player 8 - Points: 4.5, Elo: 2573.40
# Player 9 - Points: 1.0, Elo: 1837.45
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1719.16
# Player 1 - Points: 0.5, Elo: 1864.84
# Player 2 - Points: 1, Elo: 2290.47
# Player 3 - Points: 0, Elo: 1642.53
# Player 4 - Points: 0.5, Elo: 2003.87
# Player 5 - Points: 0.5, Elo: 1708.13
# Player 6 - Points: 0.5, Elo: 1867.25
# Player 7 - Points: 0.5, Elo: 1842.75
# Player 8 - Points: 1, Elo: 2023.57
# Player 9 - Points: 0, Elo: 1751.43
#
# After Round 2:
# Player 0 - Points: 1.0, Elo: 1725.91
# Player 1 - Points: 1.0, Elo: 1860.61
# Player 2 - Points: 2, Elo: 2294.01
# Player 3 - Points: 0, Elo: 1638.22
# Player 4 - Points: 1.0, Elo: 1997.13
# Player 5 - Points: 1.0, Elo: 1712.35
# Player 6 - Points: 1.5, Elo: 1871.56
# Player 7 - Points: 1.5, Elo: 1850.18
# Player 8 - Points: 1, Elo: 2020.03
# Player 9 - Points: 0, Elo: 1744.00
#
# After Round 3:
# Player 0 - Points: 1.0, Elo: 1719.34
# Player 1 - Points: 2.0, Elo: 1874.35
# Player 2 - Points: 3, Elo: 2295.63
# Player 3 - Points: 1, Elo: 1651.18
# Player 4 - Points: 1.0, Elo: 1983.39
# Player 5 - Points: 1.5, Elo: 1719.44
# Player 6 - Points: 1.5, Elo: 1869.94
# Player 7 - Points: 2.5, Elo: 1856.75
# Player 8 - Points: 1.5, Elo: 2012.94
# Player 9 - Points: 0, Elo: 1731.04
#
# After Round 4:
# Player 0 - Points: 2.0, Elo: 1729.35
# Player 1 - Points: 3.0, Elo: 1884.22
# Player 2 - Points: 4, Elo: 2297.11
# Player 3 - Points: 2, Elo: 1668.96
# Player 4 - Points: 2.0, Elo: 1987.18
# Player 5 - Points: 1.5, Elo: 1709.44
# Player 6 - Points: 1.5, Elo: 1860.07
# Player 7 - Points: 2.5, Elo: 1855.27
# Player 8 - Points: 1.5, Elo: 1995.16
# Player 9 - Points: 0, Elo: 1727.25
#
# After Round 5:
# Player 0 - Points: 2.5, Elo: 1732.94
# Player 1 - Points: 3.0, Elo: 1882.52
# Player 2 - Points: 5, Elo: 2298.81
# Player 3 - Points: 2, Elo: 1663.86
# Player 4 - Points: 2.5, Elo: 1987.41
# Player 5 - Points: 2.5, Elo: 1719.95
# Player 6 - Points: 2.0, Elo: 1856.47
# Player 7 - Points: 3.5, Elo: 1860.36
# Player 8 - Points: 2.0, Elo: 1994.93
# Player 9 - Points: 0, Elo: 1716.74
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2526.11
# Player 1 - Points: 0, Elo: 1615.89
# Player 2 - Points: 0, Elo: 1463.14
# Player 3 - Points: 1, Elo: 2003.86
# Player 4 - Points: 1, Elo: 2522.99
# Player 5 - Points: 0, Elo: 2401.01
# Player 6 - Points: 0, Elo: 1544.52
# Player 7 - Points: 1, Elo: 1769.48
# Player 8 - Points: 0.5, Elo: 2544.12
# Player 9 - Points: 0.5, Elo: 2481.88
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2527.05
# Player 1 - Points: 0, Elo: 1615.80
# Player 2 - Points: 0, Elo: 1463.08
# Player 3 - Points: 1, Elo: 2002.92
# Player 4 - Points: 2, Elo: 2523.25
# Player 5 - Points: 1, Elo: 2401.16
# Player 6 - Points: 0, Elo: 1544.38
# Player 7 - Points: 1, Elo: 1769.22
# Player 8 - Points: 1.5, Elo: 2544.22
# Player 9 - Points: 1.5, Elo: 2481.93
#
# After Round 3:
# Player 0 - Points: 2, Elo: 2516.94
# Player 1 - Points: 0.5, Elo: 1619.95
# Player 2 - Points: 0.5, Elo: 1465.38
# Player 3 - Points: 1, Elo: 2002.07
# Player 4 - Points: 3, Elo: 2533.36
# Player 5 - Points: 1.5, Elo: 2403.44
# Player 6 - Points: 0.5, Elo: 1542.08
# Player 7 - Points: 1.5, Elo: 1765.07
# Player 8 - Points: 2.5, Elo: 2545.07
# Player 9 - Points: 2.0, Elo: 2479.65
#
# After Round 4:
# Player 0 - Points: 3, Elo: 2525.87
# Player 1 - Points: 0.5, Elo: 1617.95
# Player 2 - Points: 0.5, Elo: 1465.38
# Player 3 - Points: 2, Elo: 2004.06
# Player 4 - Points: 3, Elo: 2523.69
# Player 5 - Points: 2.5, Elo: 2403.93
# Player 6 - Points: 0.5, Elo: 1542.08
# Player 7 - Points: 1.5, Elo: 1764.57
# Player 8 - Points: 3.5, Elo: 2554.73
# Player 9 - Points: 2.0, Elo: 2470.72
#
# After Round 5:
# Player 0 - Points: 3, Elo: 2516.70
# Player 1 - Points: 0.5, Elo: 1617.74
# Player 2 - Points: 0.5, Elo: 1465.38
# Player 3 - Points: 2, Elo: 2003.11
# Player 4 - Points: 4, Elo: 2524.65
# Player 5 - Points: 3.5, Elo: 2404.15
# Player 6 - Points: 0.5, Elo: 1542.08
# Player 7 - Points: 1.5, Elo: 1764.24
# Player 8 - Points: 4.5, Elo: 2563.90
# Player 9 - Points: 3.0, Elo: 2471.06
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1479.93
# Player 1 - Points: 0.5, Elo: 2438.07
# Player 2 - Points: 0, Elo: 2579.93
# Player 3 - Points: 1, Elo: 2531.07
# Player 4 - Points: 0, Elo: 2320.23
# Player 5 - Points: 1, Elo: 2380.77
# Player 6 - Points: 0.5, Elo: 1420.52
# Player 7 - Points: 0.5, Elo: 1842.48
# Player 8 - Points: 1, Elo: 1809.92
# Player 9 - Points: 0, Elo: 1557.08
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 1477.33
# Player 1 - Points: 1.5, Elo: 2438.13
# Player 2 - Points: 1, Elo: 2580.21
# Player 3 - Points: 2, Elo: 2537.00
# Player 4 - Points: 1, Elo: 2320.48
# Player 5 - Points: 1, Elo: 2374.84
# Player 6 - Points: 0.5, Elo: 1420.46
# Player 7 - Points: 0.5, Elo: 1842.20
# Player 8 - Points: 2, Elo: 1812.53
# Player 9 - Points: 0, Elo: 1556.83
#
# After Round 3:
# Player 0 - Points: 0.5, Elo: 1477.17
# Player 1 - Points: 1.5, Elo: 2432.00
# Player 2 - Points: 2, Elo: 2586.34
# Player 3 - Points: 3, Elo: 2537.30
# Player 4 - Points: 2, Elo: 2320.63
# Player 5 - Points: 2, Elo: 2374.93
# Player 6 - Points: 0.5, Elo: 1420.38
# Player 7 - Points: 0.5, Elo: 1825.44
# Player 8 - Points: 2, Elo: 1812.22
# Player 9 - Points: 1, Elo: 1573.59
#
# After Round 4:
# Player 0 - Points: 1.0, Elo: 1479.88
# Player 1 - Points: 2.0, Elo: 2422.55
# Player 2 - Points: 3, Elo: 2590.91
# Player 3 - Points: 4, Elo: 2541.76
# Player 4 - Points: 2, Elo: 2316.17
# Player 5 - Points: 2, Elo: 2370.36
# Player 6 - Points: 0.5, Elo: 1420.38
# Player 7 - Points: 0.5, Elo: 1825.44
# Player 8 - Points: 2.5, Elo: 1821.67
# Player 9 - Points: 1.5, Elo: 1570.88
#
# After Round 5:
# Player 0 - Points: 1.0, Elo: 1477.47
# Player 1 - Points: 2.0, Elo: 2415.86
# Player 2 - Points: 4, Elo: 2591.14
# Player 3 - Points: 5, Elo: 2548.46
# Player 4 - Points: 3, Elo: 2316.28
# Player 5 - Points: 3, Elo: 2370.55
# Player 6 - Points: 0.5, Elo: 1420.27
# Player 7 - Points: 1.5, Elo: 1827.85
# Player 8 - Points: 2.5, Elo: 1821.44
# Player 9 - Points: 1.5, Elo: 1570.69
#
# After Round 1:
# Player 0 - Points: 0, Elo: 1574.77
# Player 1 - Points: 1, Elo: 1867.23
# Player 2 - Points: 0, Elo: 1977.49
# Player 3 - Points: 1, Elo: 2319.51
# Player 4 - Points: 1, Elo: 1924.07
# Player 5 - Points: 0, Elo: 2045.93
# Player 6 - Points: 1, Elo: 2488.63
# Player 7 - Points: 0, Elo: 2456.37
# Player 8 - Points: 0.5, Elo: 1991.52
# Player 9 - Points: 0.5, Elo: 2196.48
#
# After Round 2:
# Player 0 - Points: 0, Elo: 1573.10
# Player 1 - Points: 1, Elo: 1865.85
# Player 2 - Points: 0, Elo: 1973.07
# Player 3 - Points: 2, Elo: 2320.89
# Player 4 - Points: 1, Elo: 1923.32
# Player 5 - Points: 0.5, Elo: 2054.21
# Player 6 - Points: 2, Elo: 2489.37
# Player 7 - Points: 0.5, Elo: 2448.10
# Player 8 - Points: 1.5, Elo: 1993.19
# Player 9 - Points: 1.5, Elo: 2200.89
#
# After Round 3:
# Player 0 - Points: 0, Elo: 1571.92
# Player 1 - Points: 1, Elo: 1859.36
# Player 2 - Points: 0, Elo: 1971.85
# Player 3 - Points: 2.5, Elo: 2325.39
# Player 4 - Points: 1.5, Elo: 1929.96
# Player 5 - Points: 1.5, Elo: 2055.39
# Player 6 - Points: 2.5, Elo: 2484.87
# Player 7 - Points: 1.5, Elo: 2449.31
# Player 8 - Points: 2.5, Elo: 1999.68
# Player 9 - Points: 2.0, Elo: 2194.26
#
# After Round 4:
# Player 0 - Points: 0.5, Elo: 1580.10
# Player 1 - Points: 1, Elo: 1854.47
# Player 2 - Points: 0.5, Elo: 1963.67
# Player 3 - Points: 3.5, Elo: 2328.05
# Player 4 - Points: 2.0, Elo: 1939.00
# Player 5 - Points: 2.5, Elo: 2060.28
# Player 6 - Points: 3.5, Elo: 2488.03
# Player 7 - Points: 2.0, Elo: 2440.27
# Player 8 - Points: 2.5, Elo: 1997.02
# Player 9 - Points: 2.0, Elo: 2191.10
#
# After Round 5:
# Player 0 - Points: 0.5, Elo: 1580.10
# Player 1 - Points: 1, Elo: 1846.86
# Player 2 - Points: 0.5, Elo: 1963.67
# Player 3 - Points: 4.5, Elo: 2331.58
# Player 4 - Points: 3.0, Elo: 1946.61
# Player 5 - Points: 2.5, Elo: 2056.75
# Player 6 - Points: 4.5, Elo: 2489.15
# Player 7 - Points: 3.0, Elo: 2444.12
# Player 8 - Points: 2.5, Elo: 1995.90
# Player 9 - Points: 2.0, Elo: 2187.25
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2483.45
# Player 1 - Points: 0, Elo: 2136.55
# Player 2 - Points: 1, Elo: 1452.95
# Player 3 - Points: 0, Elo: 1794.05
# Player 4 - Points: 1, Elo: 2577.02
# Player 5 - Points: 0, Elo: 1407.98
# Player 6 - Points: 0.5, Elo: 1717.80
# Player 7 - Points: 0.5, Elo: 2497.20
# Player 8 - Points: 0, Elo: 2048.82
# Player 9 - Points: 1, Elo: 1996.18
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2483.50
# Player 1 - Points: 1, Elo: 2138.20
# Player 2 - Points: 1, Elo: 1452.90
# Player 3 - Points: 0, Elo: 1793.71
# Player 4 - Points: 2, Elo: 2577.71
# Player 5 - Points: 1, Elo: 1427.49
# Player 6 - Points: 0.5, Elo: 1716.15
# Player 7 - Points: 1.5, Elo: 2497.54
# Player 8 - Points: 0, Elo: 2029.31
# Player 9 - Points: 1, Elo: 1995.50
#
# After Round 3:
# Player 0 - Points: 2, Elo: 2476.15
# Player 1 - Points: 1, Elo: 2135.95
# Player 2 - Points: 1, Elo: 1442.17
# Player 3 - Points: 0, Elo: 1789.61
# Player 4 - Points: 3, Elo: 2585.06
# Player 5 - Points: 2, Elo: 1438.22
# Player 6 - Points: 0.5, Elo: 1712.82
# Player 7 - Points: 2.5, Elo: 2499.79
# Player 8 - Points: 1, Elo: 2033.40
# Player 9 - Points: 2, Elo: 1998.84
#
# After Round 4:
# Player 0 - Points: 3, Elo: 2476.20
# Player 1 - Points: 1.5, Elo: 2132.20
# Player 2 - Points: 1, Elo: 1441.52
# Player 3 - Points: 0, Elo: 1777.43
# Player 4 - Points: 4, Elo: 2592.65
# Player 5 - Points: 2, Elo: 1438.17
# Player 6 - Points: 1.5, Elo: 1724.99
# Player 7 - Points: 2.5, Elo: 2492.19
# Player 8 - Points: 2, Elo: 2034.05
# Player 9 - Points: 2.5, Elo: 2002.59
#
# After Round 5:
# Player 0 - Points: 3, Elo: 2466.66
# Player 1 - Points: 2.5, Elo: 2132.57
# Player 2 - Points: 1, Elo: 1441.16
# Player 3 - Points: 0, Elo: 1777.43
# Player 4 - Points: 5, Elo: 2593.42
# Player 5 - Points: 2, Elo: 1437.42
# Player 6 - Points: 1.5, Elo: 1724.99
# Player 7 - Points: 3.5, Elo: 2501.73
# Player 8 - Points: 2, Elo: 2033.28
# Player 9 - Points: 3.5, Elo: 2003.34
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1597.88
# Player 1 - Points: 0.5, Elo: 2464.12
# Player 2 - Points: 0.5, Elo: 2262.63
# Player 3 - Points: 0.5, Elo: 2250.37
# Player 4 - Points: 1, Elo: 1524.95
# Player 5 - Points: 0, Elo: 1866.05
# Player 6 - Points: 0, Elo: 1985.02
# Player 7 - Points: 1, Elo: 2372.98
# Player 8 - Points: 1, Elo: 1834.63
# Player 9 - Points: 0, Elo: 1735.37
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 1593.80
# Player 1 - Points: 1.5, Elo: 2468.89
# Player 2 - Points: 0.5, Elo: 2257.85
# Player 3 - Points: 1.5, Elo: 2252.35
# Player 4 - Points: 1.5, Elo: 1534.80
# Player 5 - Points: 0, Elo: 1864.08
# Player 6 - Points: 1, Elo: 1988.86
# Player 7 - Points: 1.5, Elo: 2363.13
# Player 8 - Points: 2, Elo: 1838.70
# Player 9 - Points: 0, Elo: 1731.53
#
# After Round 3:
# Player 0 - Points: 0.5, Elo: 1593.57
# Player 1 - Points: 2.0, Elo: 2459.41
# Player 2 - Points: 1.0, Elo: 2251.36
# Player 3 - Points: 2.5, Elo: 2252.66
# Player 4 - Points: 1.5, Elo: 1534.48
# Player 5 - Points: 1, Elo: 1870.44
# Player 6 - Points: 1.5, Elo: 1995.36
# Player 7 - Points: 2.5, Elo: 2363.36
# Player 8 - Points: 2.5, Elo: 1848.19
# Player 9 - Points: 0, Elo: 1725.17
#
# After Round 4:
# Player 0 - Points: 0.5, Elo: 1587.18
# Player 1 - Points: 3.0, Elo: 2460.71
# Player 2 - Points: 2.0, Elo: 2253.37
# Player 3 - Points: 3.0, Elo: 2255.75
# Player 4 - Points: 1.5, Elo: 1531.66
# Player 5 - Points: 1, Elo: 1868.43
# Player 6 - Points: 1.5, Elo: 1994.06
# Player 7 - Points: 3.0, Elo: 2360.28
# Player 8 - Points: 3.5, Elo: 1851.01
# Player 9 - Points: 1, Elo: 1731.56
#
# After Round 5:
# Player 0 - Points: 0.5, Elo: 1587.18
# Player 1 - Points: 4.0, Elo: 2467.89
# Player 2 - Points: 3.0, Elo: 2253.68
# Player 3 - Points: 3.0, Elo: 2237.52
# Player 4 - Points: 1.5, Elo: 1531.35
# Player 5 - Points: 1, Elo: 1861.89
# Player 6 - Points: 2.5, Elo: 2000.60
# Player 7 - Points: 3.0, Elo: 2353.09
# Player 8 - Points: 4.5, Elo: 1869.24
# Player 9 - Points: 1, Elo: 1731.56
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1967.13
# Player 1 - Points: 0.5, Elo: 2262.87
# Player 2 - Points: 0.5, Elo: 2484.17
# Player 3 - Points: 0.5, Elo: 2591.83
# Player 4 - Points: 1, Elo: 1782.02
# Player 5 - Points: 0, Elo: 1397.98
# Player 6 - Points: 0, Elo: 2178.17
# Player 7 - Points: 1, Elo: 2580.83
# Player 8 - Points: 1, Elo: 1961.85
# Player 9 - Points: 0, Elo: 1418.15
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 1956.97
# Player 1 - Points: 0.5, Elo: 2258.50
# Player 2 - Points: 1.5, Elo: 2488.54
# Player 3 - Points: 1.5, Elo: 2591.85
# Player 4 - Points: 1.5, Elo: 1791.82
# Player 5 - Points: 0, Elo: 1397.96
# Player 6 - Points: 1, Elo: 2178.42
# Player 7 - Points: 1.5, Elo: 2571.03
# Player 8 - Points: 2, Elo: 1972.00
# Player 9 - Points: 0, Elo: 1417.91
#
# After Round 3:
# Player 0 - Points: 0.5, Elo: 1956.41
# Player 1 - Points: 1.5, Elo: 2266.24
# Player 2 - Points: 2.0, Elo: 2479.51
# Player 3 - Points: 2.5, Elo: 2592.05
# Player 4 - Points: 1.5, Elo: 1791.62
# Player 5 - Points: 0.5, Elo: 1398.54
# Player 6 - Points: 1, Elo: 2170.69
# Player 7 - Points: 2.5, Elo: 2571.59
# Player 8 - Points: 2.5, Elo: 1981.02
# Player 9 - Points: 0.5, Elo: 1417.33
#
# After Round 4:
# Player 0 - Points: 0.5, Elo: 1951.89
# Player 1 - Points: 2.5, Elo: 2269.48
# Player 2 - Points: 3.0, Elo: 2479.89
# Player 3 - Points: 3.0, Elo: 2591.46
# Player 4 - Points: 1.5, Elo: 1791.25
# Player 5 - Points: 0.5, Elo: 1398.54
# Player 6 - Points: 2, Elo: 2175.20
# Player 7 - Points: 3.0, Elo: 2572.18
# Player 8 - Points: 2.5, Elo: 1977.78
# Player 9 - Points: 0.5, Elo: 1417.33
#
# After Round 5:
# Player 0 - Points: 1.0, Elo: 1947.57
# Player 1 - Points: 2.5, Elo: 2266.77
# Player 2 - Points: 3.0, Elo: 2472.48
# Player 3 - Points: 4.0, Elo: 2594.17
# Player 4 - Points: 2.0, Elo: 1795.57
# Player 5 - Points: 0.5, Elo: 1398.54
# Player 6 - Points: 2, Elo: 2160.06
# Player 7 - Points: 4.0, Elo: 2579.59
# Player 8 - Points: 3.5, Elo: 1992.92
# Player 9 - Points: 0.5, Elo: 1417.33
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1669.91
# Player 1 - Points: 0.5, Elo: 2027.09
# Player 2 - Points: 1, Elo: 1911.95
# Player 3 - Points: 0, Elo: 1601.05
# Player 4 - Points: 1, Elo: 1793.82
# Player 5 - Points: 0, Elo: 1906.18
# Player 6 - Points: 1, Elo: 2169.30
# Player 7 - Points: 0, Elo: 1442.70
# Player 8 - Points: 1, Elo: 2513.06
# Player 9 - Points: 0, Elo: 1501.94
#
# After Round 2:
# Player 0 - Points: 1.5, Elo: 1677.95
# Player 1 - Points: 0.5, Elo: 2013.75
# Player 2 - Points: 2, Elo: 1918.67
# Player 3 - Points: 0, Elo: 1593.01
# Player 4 - Points: 1, Elo: 1787.10
# Player 5 - Points: 1, Elo: 1919.52
# Player 6 - Points: 1, Elo: 2166.87
# Player 7 - Points: 0.5, Elo: 1444.39
# Player 8 - Points: 2, Elo: 2515.49
# Player 9 - Points: 0.5, Elo: 1500.25
#
# After Round 3:
# Player 0 - Points: 2.0, Elo: 1680.99
# Player 1 - Points: 1.5, Elo: 2014.47
# Player 2 - Points: 2, Elo: 1918.05
# Player 3 - Points: 0.5, Elo: 1590.40
# Player 4 - Points: 1.5, Elo: 1784.06
# Player 5 - Points: 1.5, Elo: 1925.64
# Player 6 - Points: 1.5, Elo: 2160.75
# Player 7 - Points: 0.5, Elo: 1443.66
# Player 8 - Points: 3, Elo: 2516.11
# Player 9 - Points: 1.0, Elo: 1502.86
#
# After Round 4:
# Player 0 - Points: 2.0, Elo: 1680.83
# Player 1 - Points: 1.5, Elo: 2001.77
# Player 2 - Points: 3, Elo: 1930.75
# Player 3 - Points: 0.5, Elo: 1576.41
# Player 4 - Points: 1.5, Elo: 1782.00
# Player 5 - Points: 2.5, Elo: 1927.25
# Player 6 - Points: 2.5, Elo: 2162.81
# Player 7 - Points: 1.5, Elo: 1457.65
# Player 8 - Points: 4, Elo: 2516.27
# Player 9 - Points: 1.0, Elo: 1501.25
#
# After Round 5:
# Player 0 - Points: 3.0, Elo: 1685.17
# Player 1 - Points: 2.5, Elo: 2006.17
# Player 2 - Points: 3, Elo: 1926.59
# Player 3 - Points: 0.5, Elo: 1576.41
# Player 4 - Points: 1.5, Elo: 1777.60
# Player 5 - Points: 2.5, Elo: 1926.60
# Player 6 - Points: 3.5, Elo: 2166.97
# Player 7 - Points: 1.5, Elo: 1453.31
# Player 8 - Points: 5, Elo: 2516.93
# Player 9 - Points: 1.0, Elo: 1501.25
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1448.02
# Player 1 - Points: 0.5, Elo: 1945.98
# Player 2 - Points: 1, Elo: 2364.93
# Player 3 - Points: 0, Elo: 1839.07
# Player 4 - Points: 1, Elo: 2342.44
# Player 5 - Points: 0, Elo: 2160.56
# Player 6 - Points: 0.5, Elo: 2454.86
# Player 7 - Points: 0.5, Elo: 2348.14
# Player 8 - Points: 1, Elo: 1491.72
# Player 9 - Points: 0, Elo: 1563.28
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 1439.28
# Player 1 - Points: 1.0, Elo: 1954.96
# Player 2 - Points: 1.5, Elo: 2364.29
# Player 3 - Points: 0, Elo: 1838.05
# Player 4 - Points: 1.5, Elo: 2343.09
# Player 5 - Points: 1, Elo: 2161.18
# Player 6 - Points: 1.0, Elo: 2445.87
# Player 7 - Points: 1.5, Elo: 2349.16
# Player 8 - Points: 2, Elo: 1500.47
# Player 9 - Points: 0, Elo: 1562.66
#
# After Round 3:
# Player 0 - Points: 0.5, Elo: 1439.21
# Player 1 - Points: 1.0, Elo: 1950.29
# Player 2 - Points: 2.5, Elo: 2364.42
# Player 3 - Points: 1, Elo: 1841.45
# Player 4 - Points: 2.5, Elo: 2353.26
# Player 5 - Points: 2, Elo: 2165.86
# Player 6 - Points: 2.0, Elo: 2445.93
# Player 7 - Points: 1.5, Elo: 2338.98
# Player 8 - Points: 2, Elo: 1500.33
# Player 9 - Points: 0, Elo: 1559.26
#
# After Round 4:
# Player 0 - Points: 1.5, Elo: 1452.54
# Player 1 - Points: 2.0, Elo: 1957.25
# Player 2 - Points: 3.5, Elo: 2369.26
# Player 3 - Points: 1, Elo: 1834.49
# Player 4 - Points: 3.0, Elo: 2355.87
# Player 5 - Points: 2, Elo: 2161.02
# Player 6 - Points: 2.5, Elo: 2443.33
# Player 7 - Points: 2.0, Elo: 2329.14
# Player 8 - Points: 2.5, Elo: 1510.17
# Player 9 - Points: 0, Elo: 1545.93
#
# After Round 5:
# Player 0 - Points: 1.5, Elo: 1452.21
# Player 1 - Points: 2.5, Elo: 1965.15
# Player 2 - Points: 4.0, Elo: 2371.36
# Player 3 - Points: 1, Elo: 1834.49
# Player 4 - Points: 4.0, Elo: 2356.02
# Player 5 - Points: 3, Elo: 2161.36
# Player 6 - Points: 3.0, Elo: 2441.23
# Player 7 - Points: 2.5, Elo: 2321.24
# Player 8 - Points: 2.5, Elo: 1510.02
# Player 9 - Points: 0, Elo: 1545.93
#
# After Round 1:
# Player 0 - Points: 0, Elo: 2514.96
# Player 1 - Points: 1, Elo: 2467.04
# Player 2 - Points: 0, Elo: 1646.34
# Player 3 - Points: 1, Elo: 1710.66
# Player 4 - Points: 1, Elo: 2484.94
# Player 5 - Points: 0, Elo: 2430.06
# Player 6 - Points: 0, Elo: 1448.89
# Player 7 - Points: 1, Elo: 2360.11
# Player 8 - Points: 0.5, Elo: 2176.90
# Player 9 - Points: 0.5, Elo: 2533.10
#
# After Round 2:
# Player 0 - Points: 0, Elo: 2497.46
# Player 1 - Points: 2, Elo: 2467.30
# Player 2 - Points: 0, Elo: 1646.22
# Player 3 - Points: 1, Elo: 1710.40
# Player 4 - Points: 2, Elo: 2491.49
# Player 5 - Points: 1, Elo: 2430.13
# Player 6 - Points: 0, Elo: 1448.82
# Player 7 - Points: 1, Elo: 2353.55
# Player 8 - Points: 1.5, Elo: 2194.40
# Player 9 - Points: 1.5, Elo: 2533.22
#
# After Round 3:
# Player 0 - Points: 1, Elo: 2503.54
# Player 1 - Points: 3, Elo: 2477.99
# Player 2 - Points: 1, Elo: 1651.08
# Player 3 - Points: 1, Elo: 1709.24
# Player 4 - Points: 2, Elo: 2480.80
# Player 5 - Points: 1, Elo: 2423.01
# Player 6 - Points: 0, Elo: 1443.96
# Player 7 - Points: 1, Elo: 2347.47
# Player 8 - Points: 2.5, Elo: 2195.56
# Player 9 - Points: 2.5, Elo: 2540.34
#
# After Round 4:
# Player 0 - Points: 2, Elo: 2503.68
# Player 1 - Points: 4, Elo: 2481.28
# Player 2 - Points: 1, Elo: 1650.94
# Player 3 - Points: 1, Elo: 1708.92
# Player 4 - Points: 2.5, Elo: 2482.49
# Player 5 - Points: 2, Elo: 2423.34
# Player 6 - Points: 0, Elo: 1443.96
# Player 7 - Points: 1, Elo: 2347.47
# Player 8 - Points: 2.5, Elo: 2192.27
# Player 9 - Points: 3.0, Elo: 2538.64
#
# After Round 5:
# Player 0 - Points: 3, Elo: 2511.41
# Player 1 - Points: 5, Elo: 2492.92
# Player 2 - Points: 1, Elo: 1650.58
# Player 3 - Points: 2, Elo: 1712.49
# Player 4 - Points: 2.5, Elo: 2465.66
# Player 5 - Points: 2, Elo: 2415.61
# Player 6 - Points: 0, Elo: 1440.39
# Player 7 - Points: 2, Elo: 2347.83
# Player 8 - Points: 3.5, Elo: 2209.10
# Player 9 - Points: 3.0, Elo: 2527.01
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2127.57
# Player 1 - Points: 0, Elo: 1513.43
# Player 2 - Points: 1, Elo: 2166.82
# Player 3 - Points: 0, Elo: 1617.18
# Player 4 - Points: 1, Elo: 2159.45
# Player 5 - Points: 0, Elo: 1812.55
# Player 6 - Points: 0.5, Elo: 1521.63
# Player 7 - Points: 0.5, Elo: 1785.37
# Player 8 - Points: 0.5, Elo: 1488.95
# Player 9 - Points: 0.5, Elo: 1626.05
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2138.69
# Player 1 - Points: 0, Elo: 1506.56
# Player 2 - Points: 1, Elo: 2155.69
# Player 3 - Points: 0.5, Elo: 1622.28
# Player 4 - Points: 2, Elo: 2159.95
# Player 5 - Points: 0.5, Elo: 1807.45
# Player 6 - Points: 0.5, Elo: 1521.13
# Player 7 - Points: 1.0, Elo: 1778.45
# Player 8 - Points: 1.0, Elo: 1495.87
# Player 9 - Points: 1.5, Elo: 1632.92
#
# After Round 3:
# Player 0 - Points: 3, Elo: 2149.31
# Player 1 - Points: 1, Elo: 1516.98
# Player 2 - Points: 1.5, Elo: 2146.63
# Player 3 - Points: 1.5, Elo: 1636.49
# Player 4 - Points: 2, Elo: 2149.34
# Player 5 - Points: 1.0, Elo: 1800.31
# Player 6 - Points: 0.5, Elo: 1510.71
# Player 7 - Points: 1.0, Elo: 1764.23
# Player 8 - Points: 1.5, Elo: 1503.02
# Player 9 - Points: 2.0, Elo: 1641.98
#
# After Round 4:
# Player 0 - Points: 4, Elo: 2150.33
# Player 1 - Points: 1.5, Elo: 1523.71
# Player 2 - Points: 1.5, Elo: 2136.71
# Player 3 - Points: 2.5, Elo: 1642.83
# Player 4 - Points: 3, Elo: 2159.26
# Player 5 - Points: 1.5, Elo: 1793.58
# Player 6 - Points: 0.5, Elo: 1510.71
# Player 7 - Points: 1.0, Elo: 1764.23
# Player 8 - Points: 1.5, Elo: 1496.68
# Player 9 - Points: 2.0, Elo: 1640.96
#
# After Round 5:
# Player 0 - Points: 5, Elo: 2151.35
# Player 1 - Points: 1.5, Elo: 1523.14
# Player 2 - Points: 2.5, Elo: 2137.28
# Player 3 - Points: 2.5, Elo: 1641.81
# Player 4 - Points: 4, Elo: 2160.22
# Player 5 - Points: 2.5, Elo: 1802.74
# Player 6 - Points: 0.5, Elo: 1500.31
# Player 7 - Points: 1.0, Elo: 1755.08
# Player 8 - Points: 2.5, Elo: 1507.09
# Player 9 - Points: 2.0, Elo: 1639.99
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2047.28
# Player 1 - Points: 0, Elo: 2177.72
# Player 2 - Points: 1, Elo: 2298.77
# Player 3 - Points: 0, Elo: 2337.23
# Player 4 - Points: 1, Elo: 2250.50
# Player 5 - Points: 0, Elo: 1613.50
# Player 6 - Points: 1, Elo: 1882.17
# Player 7 - Points: 0, Elo: 1641.83
# Player 8 - Points: 1, Elo: 1658.42
# Player 9 - Points: 0, Elo: 1755.58
#
# After Round 2:
# Player 0 - Points: 1.5, Elo: 2053.47
# Player 1 - Points: 1, Elo: 2178.68
# Player 2 - Points: 1.5, Elo: 2292.57
# Player 3 - Points: 1, Elo: 2337.54
# Player 4 - Points: 2, Elo: 2252.64
# Player 5 - Points: 0, Elo: 1613.19
# Player 6 - Points: 1, Elo: 1880.02
# Player 7 - Points: 1, Elo: 1655.00
# Player 8 - Points: 1, Elo: 1657.47
# Player 9 - Points: 0, Elo: 1742.41
#
# After Round 3:
# Player 0 - Points: 2.5, Elo: 2068.65
# Player 1 - Points: 2, Elo: 2191.84
# Player 2 - Points: 1.5, Elo: 2279.41
# Player 3 - Points: 2, Elo: 2338.88
# Player 4 - Points: 2, Elo: 2237.47
# Player 5 - Points: 1, Elo: 1626.75
# Player 6 - Points: 1, Elo: 1878.68
# Player 7 - Points: 2, Elo: 1665.07
# Player 8 - Points: 1, Elo: 1647.40
# Player 9 - Points: 0, Elo: 1728.86
#
# After Round 4:
# Player 0 - Points: 3.0, Elo: 2075.17
# Player 1 - Points: 3, Elo: 2203.15
# Player 2 - Points: 2.5, Elo: 2279.97
# Player 3 - Points: 2.5, Elo: 2332.37
# Player 4 - Points: 2, Elo: 2226.16
# Player 5 - Points: 1, Elo: 1622.95
# Player 6 - Points: 2, Elo: 1882.48
# Player 7 - Points: 2, Elo: 1664.50
# Player 8 - Points: 1, Elo: 1647.40
# Player 9 - Points: 0, Elo: 1728.86
#
# After Round 5:
# Player 0 - Points: 4.0, Elo: 2080.13
# Player 1 - Points: 3, Elo: 2196.70
# Player 2 - Points: 3.5, Elo: 2288.44
# Player 3 - Points: 3.5, Elo: 2338.81
# Player 4 - Points: 2, Elo: 2217.70
# Player 5 - Points: 1, Elo: 1614.14
# Player 6 - Points: 2, Elo: 1877.52
# Player 7 - Points: 3, Elo: 1673.31
# Player 8 - Points: 1, Elo: 1647.40
# Player 9 - Points: 0, Elo: 1728.86
#
# After Round 1:
# Player 0 - Points: 0, Elo: 1925.20
# Player 1 - Points: 1, Elo: 1951.80
# Player 2 - Points: 1, Elo: 2214.70
# Player 3 - Points: 0, Elo: 2322.30
# Player 4 - Points: 0.5, Elo: 1409.07
# Player 5 - Points: 0.5, Elo: 1592.93
# Player 6 - Points: 1, Elo: 2135.93
# Player 7 - Points: 0, Elo: 1610.07
# Player 8 - Points: 1, Elo: 2256.05
# Player 9 - Points: 0, Elo: 1750.95
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 1916.18
# Player 1 - Points: 2, Elo: 1968.19
# Player 2 - Points: 1, Elo: 2198.31
# Player 3 - Points: 1, Elo: 2322.59
# Player 4 - Points: 1.0, Elo: 1418.09
# Player 5 - Points: 0.5, Elo: 1592.64
# Player 6 - Points: 1.5, Elo: 2139.26
# Player 7 - Points: 0, Elo: 1603.91
# Player 8 - Points: 1.5, Elo: 2252.72
# Player 9 - Points: 1, Elo: 1757.11
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 1921.89
# Player 1 - Points: 2, Elo: 1962.75
# Player 2 - Points: 1, Elo: 2189.86
# Player 3 - Points: 2, Elo: 2322.70
# Player 4 - Points: 1.0, Elo: 1417.98
# Player 5 - Points: 1.5, Elo: 1602.96
# Player 6 - Points: 2.5, Elo: 2144.70
# Player 7 - Points: 0, Elo: 1593.59
# Player 8 - Points: 2.5, Elo: 2261.17
# Player 9 - Points: 1, Elo: 1751.39
#
# After Round 4:
# Player 0 - Points: 2.5, Elo: 1924.64
# Player 1 - Points: 2, Elo: 1959.71
# Player 2 - Points: 2, Elo: 2190.10
# Player 3 - Points: 2.5, Elo: 2317.99
# Player 4 - Points: 1.0, Elo: 1417.75
# Player 5 - Points: 1.5, Elo: 1600.21
# Player 6 - Points: 3.0, Elo: 2149.42
# Player 7 - Points: 0, Elo: 1593.59
# Player 8 - Points: 3.5, Elo: 2264.21
# Player 9 - Points: 1, Elo: 1751.39
#
# After Round 5:
# Player 0 - Points: 2.5, Elo: 1922.16
# Player 1 - Points: 2, Elo: 1957.45
# Player 2 - Points: 2.5, Elo: 2188.93
# Player 3 - Points: 3.5, Elo: 2320.24
# Player 4 - Points: 1.5, Elo: 1422.42
# Player 5 - Points: 2.0, Elo: 1604.31
# Player 6 - Points: 3.5, Elo: 2150.58
# Player 7 - Points: 0.5, Elo: 1588.92
# Player 8 - Points: 4.5, Elo: 2266.69
# Player 9 - Points: 1.5, Elo: 1747.29
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2490.46
# Player 1 - Points: 0, Elo: 1836.54
# Player 2 - Points: 0, Elo: 1548.85
# Player 3 - Points: 1, Elo: 2400.15
# Player 4 - Points: 1, Elo: 2424.57
# Player 5 - Points: 0, Elo: 2456.43
# Player 6 - Points: 1, Elo: 2294.33
# Player 7 - Points: 0, Elo: 1832.67
# Player 8 - Points: 1, Elo: 1713.39
# Player 9 - Points: 0, Elo: 1605.61
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2497.91
# Player 1 - Points: 0.5, Elo: 1833.14
# Player 2 - Points: 0.5, Elo: 1558.74
# Player 3 - Points: 1, Elo: 2392.69
# Player 4 - Points: 2, Elo: 2430.99
# Player 5 - Points: 0.5, Elo: 2446.54
# Player 6 - Points: 1, Elo: 2287.91
# Player 7 - Points: 1, Elo: 1836.93
# Player 8 - Points: 1.5, Elo: 1716.79
# Player 9 - Points: 0, Elo: 1601.35
#
# After Round 3:
# Player 0 - Points: 2.5, Elo: 2496.01
# Player 1 - Points: 0.5, Elo: 1831.78
# Player 2 - Points: 0.5, Elo: 1555.39
# Player 3 - Points: 1.5, Elo: 2383.09
# Player 4 - Points: 2.5, Elo: 2432.89
# Player 5 - Points: 1.5, Elo: 2446.69
# Player 6 - Points: 2, Elo: 2289.27
# Player 7 - Points: 2, Elo: 1840.29
# Player 8 - Points: 2.0, Elo: 1726.39
# Player 9 - Points: 0, Elo: 1601.20
#
# After Round 4:
# Player 0 - Points: 3.5, Elo: 2500.68
# Player 1 - Points: 0.5, Elo: 1830.98
# Player 2 - Points: 1.5, Elo: 1566.70
# Player 3 - Points: 2.5, Elo: 2383.89
# Player 4 - Points: 3.5, Elo: 2433.53
# Player 5 - Points: 2.0, Elo: 2437.00
# Player 6 - Points: 2, Elo: 2284.61
# Player 7 - Points: 2, Elo: 1839.65
# Player 8 - Points: 2.5, Elo: 1736.08
# Player 9 - Points: 0, Elo: 1589.89
#
# After Round 5:
# Player 0 - Points: 4.5, Elo: 2500.92
# Player 1 - Points: 0.5, Elo: 1821.23
# Player 2 - Points: 1.5, Elo: 1566.70
# Player 3 - Points: 3.5, Elo: 2395.31
# Player 4 - Points: 3.5, Elo: 2422.11
# Player 5 - Points: 2.0, Elo: 2422.88
# Player 6 - Points: 3, Elo: 2298.73
# Player 7 - Points: 3, Elo: 1849.40
# Player 8 - Points: 2.5, Elo: 1735.83
# Player 9 - Points: 0, Elo: 1589.89
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2014.46
# Player 1 - Points: 0, Elo: 1833.54
# Player 2 - Points: 1, Elo: 2265.20
# Player 3 - Points: 0, Elo: 1469.80
# Player 4 - Points: 1, Elo: 1966.93
# Player 5 - Points: 0, Elo: 1763.07
# Player 6 - Points: 0, Elo: 2296.45
# Player 7 - Points: 1, Elo: 2298.55
# Player 8 - Points: 0.5, Elo: 1477.86
# Player 9 - Points: 0.5, Elo: 2320.14
#
# After Round 2:
# Player 0 - Points: 1, Elo: 2010.64
# Player 1 - Points: 1, Elo: 1835.82
# Player 2 - Points: 2, Elo: 2269.02
# Player 3 - Points: 0, Elo: 1469.65
# Player 4 - Points: 1, Elo: 1964.35
# Player 5 - Points: 0.5, Elo: 1772.18
# Player 6 - Points: 0.5, Elo: 2287.34
# Player 7 - Points: 2, Elo: 2301.13
# Player 8 - Points: 0.5, Elo: 1475.57
# Player 9 - Points: 1.5, Elo: 2320.29
#
# After Round 3:
# Player 0 - Points: 1, Elo: 2007.76
# Player 1 - Points: 1.5, Elo: 1839.36
# Player 2 - Points: 2, Elo: 2259.95
# Player 3 - Points: 0, Elo: 1469.47
# Player 4 - Points: 1.5, Elo: 1960.81
# Player 5 - Points: 1.5, Elo: 1775.25
# Player 6 - Points: 1.5, Elo: 2287.52
# Player 7 - Points: 3, Elo: 2310.21
# Player 8 - Points: 0.5, Elo: 1472.50
# Player 9 - Points: 2.5, Elo: 2323.17
#
# After Round 4:
# Player 0 - Points: 1.5, Elo: 2001.92
# Player 1 - Points: 1.5, Elo: 1837.73
# Player 2 - Points: 3, Elo: 2261.58
# Player 3 - Points: 0, Elo: 1459.56
# Player 4 - Points: 2.5, Elo: 1978.16
# Player 5 - Points: 2.0, Elo: 1781.10
# Player 6 - Points: 1.5, Elo: 2270.17
# Player 7 - Points: 3, Elo: 2300.58
# Player 8 - Points: 1.5, Elo: 1482.42
# Player 9 - Points: 3.5, Elo: 2332.79
#
# After Round 5:
# Player 0 - Points: 2.5, Elo: 2011.24
# Player 1 - Points: 1.5, Elo: 1836.20
# Player 2 - Points: 3, Elo: 2253.60
# Player 3 - Points: 0, Elo: 1459.56
# Player 4 - Points: 2.5, Elo: 1968.85
# Player 5 - Points: 2.0, Elo: 1780.14
# Player 6 - Points: 2.5, Elo: 2271.70
# Player 7 - Points: 4, Elo: 2301.54
# Player 8 - Points: 1.5, Elo: 1482.42
# Player 9 - Points: 4.5, Elo: 2340.77
#
# After Round 1:
# Player 0 - Points: 1, Elo: 1953.41
# Player 1 - Points: 0, Elo: 1846.59
# Player 2 - Points: 0.5, Elo: 2412.95
# Player 3 - Points: 0.5, Elo: 2230.05
# Player 4 - Points: 0.5, Elo: 1570.40
# Player 5 - Points: 0.5, Elo: 1517.60
# Player 6 - Points: 1, Elo: 2541.36
# Player 7 - Points: 0, Elo: 1847.64
# Player 8 - Points: 0.5, Elo: 1524.74
# Player 9 - Points: 0.5, Elo: 2259.26
#
# After Round 2:
# Player 0 - Points: 1, Elo: 1952.76
# Player 1 - Points: 0, Elo: 1829.30
# Player 2 - Points: 1.5, Elo: 2413.11
# Player 3 - Points: 1.5, Elo: 2230.37
# Player 4 - Points: 0.5, Elo: 1570.25
# Player 5 - Points: 0.5, Elo: 1517.27
# Player 6 - Points: 2, Elo: 2542.02
# Player 7 - Points: 0, Elo: 1845.93
# Player 8 - Points: 1.5, Elo: 1542.03
# Player 9 - Points: 1.5, Elo: 2260.97
#
# After Round 3:
# Player 0 - Points: 1, Elo: 1949.86
# Player 1 - Points: 1, Elo: 1832.97
# Player 2 - Points: 1.5, Elo: 2406.66
# Player 3 - Points: 2.5, Elo: 2230.75
# Player 4 - Points: 0.5, Elo: 1566.57
# Player 5 - Points: 1.0, Elo: 1524.65
# Player 6 - Points: 3, Elo: 2548.47
# Player 7 - Points: 0.5, Elo: 1838.55
# Player 8 - Points: 1.5, Elo: 1541.66
# Player 9 - Points: 2.5, Elo: 2263.87
#
# After Round 4:
# Player 0 - Points: 1.5, Elo: 1941.60
# Player 1 - Points: 2, Elo: 1835.87
# Player 2 - Points: 2.5, Elo: 2412.76
# Player 3 - Points: 2.5, Elo: 2227.98
# Player 4 - Points: 1.0, Elo: 1573.12
# Player 5 - Points: 1.0, Elo: 1521.75
# Player 6 - Points: 4, Elo: 2551.24
# Player 7 - Points: 1.0, Elo: 1832.00
# Player 8 - Points: 2.0, Elo: 1549.92
# Player 9 - Points: 2.5, Elo: 2257.76
#
# After Round 5:
# Player 0 - Points: 1.5, Elo: 1938.37
# Player 1 - Points: 2, Elo: 1835.18
# Player 2 - Points: 3.5, Elo: 2413.46
# Player 3 - Points: 3.5, Elo: 2231.20
# Player 4 - Points: 1.5, Elo: 1572.45
# Player 5 - Points: 1.0, Elo: 1521.75
# Player 6 - Points: 5, Elo: 2554.35
# Player 7 - Points: 1.0, Elo: 1832.00
# Player 8 - Points: 2.5, Elo: 1550.58
# Player 9 - Points: 2.5, Elo: 2254.64
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2597.83
# Player 1 - Points: 0, Elo: 2539.17
# Player 2 - Points: 1, Elo: 2458.82
# Player 3 - Points: 0, Elo: 2200.18
# Player 4 - Points: 0, Elo: 1964.70
# Player 5 - Points: 1, Elo: 2198.30
# Player 6 - Points: 0.5, Elo: 1581.89
# Player 7 - Points: 0.5, Elo: 2469.11
# Player 8 - Points: 0.5, Elo: 1485.56
# Player 9 - Points: 0.5, Elo: 2125.44
#
# After Round 2:
# Player 0 - Points: 1.5, Elo: 2594.03
# Player 1 - Points: 1, Elo: 2540.87
# Player 2 - Points: 1.5, Elo: 2462.62
# Player 3 - Points: 1, Elo: 2204.28
# Player 4 - Points: 0, Elo: 1960.60
# Player 5 - Points: 2, Elo: 2198.86
# Player 6 - Points: 0.5, Elo: 1581.33
# Player 7 - Points: 1.5, Elo: 2469.18
# Player 8 - Points: 0.5, Elo: 1485.49
# Player 9 - Points: 0.5, Elo: 2123.75
#
# After Round 3:
# Player 0 - Points: 2.0, Elo: 2585.89
# Player 1 - Points: 2, Elo: 2543.38
# Player 2 - Points: 2.0, Elo: 2462.81
# Player 3 - Points: 1, Elo: 2201.77
# Player 4 - Points: 0, Elo: 1954.98
# Player 5 - Points: 2.5, Elo: 2206.99
# Player 6 - Points: 1.5, Elo: 1588.64
# Player 7 - Points: 2.0, Elo: 2468.99
# Player 8 - Points: 0.5, Elo: 1478.18
# Player 9 - Points: 1.5, Elo: 2129.37
#
# After Round 4:
# Player 0 - Points: 3.0, Elo: 2592.65
# Player 1 - Points: 2.5, Elo: 2535.91
# Player 2 - Points: 3.0, Elo: 2462.93
# Player 3 - Points: 1.5, Elo: 2199.71
# Player 4 - Points: 0, Elo: 1936.19
# Player 5 - Points: 3.0, Elo: 2214.47
# Player 6 - Points: 1.5, Elo: 1588.51
# Player 7 - Points: 2.0, Elo: 2462.23
# Player 8 - Points: 1.5, Elo: 1496.97
# Player 9 - Points: 2.0, Elo: 2131.42
#
# After Round 5:
# Player 0 - Points: 4.0, Elo: 2593.96
# Player 1 - Points: 3.5, Elo: 2543.82
# Player 2 - Points: 4.0, Elo: 2466.80
# Player 3 - Points: 2.5, Elo: 2200.29
# Player 4 - Points: 0, Elo: 1936.19
# Player 5 - Points: 3.0, Elo: 2210.61
# Player 6 - Points: 1.5, Elo: 1587.94
# Player 7 - Points: 2.0, Elo: 2454.32
# Player 8 - Points: 1.5, Elo: 1496.97
# Player 9 - Points: 2.0, Elo: 2130.11
#
# After Round 1:
# Player 0 - Points: 0, Elo: 1754.96
# Player 1 - Points: 1, Elo: 2262.04
# Player 2 - Points: 1, Elo: 2584.70
# Player 3 - Points: 0, Elo: 2007.30
# Player 4 - Points: 1, Elo: 2589.04
# Player 5 - Points: 0, Elo: 1513.96
# Player 6 - Points: 0, Elo: 1612.93
# Player 7 - Points: 1, Elo: 2585.07
# Player 8 - Points: 0, Elo: 1619.56
# Player 9 - Points: 1, Elo: 2066.44
#
# After Round 2:
# Player 0 - Points: 0, Elo: 1752.11
# Player 1 - Points: 1.5, Elo: 2269.34
# Player 2 - Points: 1.5, Elo: 2577.40
# Player 3 - Points: 1, Elo: 2008.40
# Player 4 - Points: 2, Elo: 2598.93
# Player 5 - Points: 0, Elo: 1512.85
# Player 6 - Points: 0, Elo: 1603.12
# Player 7 - Points: 1, Elo: 2575.19
# Player 8 - Points: 1, Elo: 1629.37
# Player 9 - Points: 2, Elo: 2069.29
#
# After Round 3:
# Player 0 - Points: 1, Elo: 1758.72
# Player 1 - Points: 2.5, Elo: 2272.98
# Player 2 - Points: 2.0, Elo: 2577.34
# Player 3 - Points: 1, Elo: 2004.76
# Player 4 - Points: 3, Elo: 2599.83
# Player 5 - Points: 1, Elo: 1525.40
# Player 6 - Points: 0, Elo: 1590.58
# Player 7 - Points: 1.5, Elo: 2575.25
# Player 8 - Points: 1, Elo: 1622.76
# Player 9 - Points: 2, Elo: 2068.39
#
# After Round 4:
# Player 0 - Points: 1, Elo: 1758.54
# Player 1 - Points: 2.5, Elo: 2270.33
# Player 2 - Points: 3.0, Elo: 2578.35
# Player 3 - Points: 2, Elo: 2006.76
# Player 4 - Points: 4, Elo: 2602.48
# Player 5 - Points: 1, Elo: 1525.40
# Player 6 - Points: 0, Elo: 1590.58
# Player 7 - Points: 2.5, Elo: 2575.43
# Player 8 - Points: 1, Elo: 1620.76
# Player 9 - Points: 2, Elo: 2067.38
#
# After Round 5:
# Player 0 - Points: 2, Elo: 1762.68
# Player 1 - Points: 2.5, Elo: 2267.39
# Player 2 - Points: 3.0, Elo: 2569.04
# Player 3 - Points: 3, Elo: 2018.49
# Player 4 - Points: 5, Elo: 2611.78
# Player 5 - Points: 1, Elo: 1521.25
# Player 6 - Points: 0, Elo: 1590.58
# Player 7 - Points: 3.5, Elo: 2578.38
# Player 8 - Points: 1, Elo: 1620.76
# Player 9 - Points: 2, Elo: 2055.65
#
# After Round 1:
# Player 0 - Points: 1, Elo: 2230.35
# Player 1 - Points: 0, Elo: 2155.65
# Player 2 - Points: 1, Elo: 1724.12
# Player 3 - Points: 0, Elo: 1606.88
# Player 4 - Points: 0.5, Elo: 1773.25
# Player 5 - Points: 0.5, Elo: 1680.75
# Player 6 - Points: 0.5, Elo: 1953.40
# Player 7 - Points: 0.5, Elo: 2539.60
# Player 8 - Points: 1, Elo: 2432.94
# Player 9 - Points: 0, Elo: 2041.06
#
# After Round 2:
# Player 0 - Points: 2, Elo: 2231.38
# Player 1 - Points: 0, Elo: 2153.68
# Player 2 - Points: 1, Elo: 1723.09
# Player 3 - Points: 0, Elo: 1605.36
# Player 4 - Points: 0.5, Elo: 1772.81
# Player 5 - Points: 1.5, Elo: 1697.30
# Player 6 - Points: 0.5, Elo: 1936.85
# Player 7 - Points: 1.5, Elo: 2541.57
# Player 8 - Points: 2, Elo: 2433.37
# Player 9 - Points: 1, Elo: 2042.58
#
# After Round 3:
# Player 0 - Points: 2.5, Elo: 2236.61
# Player 1 - Points: 1, Elo: 2154.49
# Player 2 - Points: 1, Elo: 1720.35
# Player 3 - Points: 0, Elo: 1604.55
# Player 4 - Points: 1.5, Elo: 1787.21
# Player 5 - Points: 2.0, Elo: 1707.15
# Player 6 - Points: 0.5, Elo: 1922.45
# Player 7 - Points: 2.0, Elo: 2531.73
# Player 8 - Points: 2.5, Elo: 2428.14
# Player 9 - Points: 2, Elo: 2045.33
#
# After Round 4:
# Player 0 - Points: 3.5, Elo: 2237.52
# Player 1 - Points: 2, Elo: 2156.01
# Player 2 - Points: 1, Elo: 1718.83
# Player 3 - Points: 0, Elo: 1601.78
# Player 4 - Points: 1.5, Elo: 1783.52
# Player 5 - Points: 2.0, Elo: 1706.24
# Player 6 - Points: 1.5, Elo: 1925.21
# Player 7 - Points: 2.0, Elo: 2518.83
# Player 8 - Points: 3.5, Elo: 2441.03
# Player 9 - Points: 3, Elo: 2049.02
#
# After Round 5:
# Player 0 - Points: 4.5, Elo: 2242.57
# Player 1 - Points: 2, Elo: 2152.77
# Player 2 - Points: 1.5, Elo: 1718.47
# Player 3 - Points: 0, Elo: 1601.78
# Player 4 - Points: 1.5, Elo: 1783.24
# Player 5 - Points: 2.5, Elo: 1706.60
# Player 6 - Points: 1.5, Elo: 1925.21
# Player 7 - Points: 3.0, Elo: 2519.12
# Player 8 - Points: 4.5, Elo: 2444.28
# Player 9 - Points: 3, Elo: 2043.97
#
# After Round 1:
# Player 0 - Points: 0, Elo: 2115.75
# Player 1 - Points: 1, Elo: 2407.25
# Player 2 - Points: 0, Elo: 1481.93
# Player 3 - Points: 1, Elo: 2470.07
# Player 4 - Points: 0.5, Elo: 2101.32
# Player 5 - Points: 0.5, Elo: 2296.68
# Player 6 - Points: 1, Elo: 2139.56
# Player 7 - Points: 0, Elo: 1918.44
# Player 8 - Points: 1, Elo: 2200.00
# Player 9 - Points: 0, Elo: 1951.00
#
# After Round 2:
# Player 0 - Points: 0, Elo: 2105.34
# Player 1 - Points: 1, Elo: 2399.04
# Player 2 - Points: 0, Elo: 1481.75
# Player 3 - Points: 2, Elo: 2478.28
# Player 4 - Points: 1.5, Elo: 2111.74
# Player 5 - Points: 1.5, Elo: 2296.86
# Player 6 - Points: 1.5, Elo: 2141.28
# Player 7 - Points: 1, Elo: 1929.38
# Player 8 - Points: 1.5, Elo: 2198.27
# Player 9 - Points: 0, Elo: 1940.07
#
# After Round 3:
# Player 0 - Points: 0, Elo: 2090.67
# Player 1 - Points: 1.5, Elo: 2393.83
# Player 2 - Points: 0.5, Elo: 1490.42
# Player 3 - Points: 3, Elo: 2480.44
# Player 4 - Points: 1.5, Elo: 2109.57
# Player 5 - Points: 1.5, Elo: 2282.66
# Player 6 - Points: 2.5, Elo: 2155.48
# Player 7 - Points: 2, Elo: 1944.05
# Player 8 - Points: 2.0, Elo: 2203.49
# Player 9 - Points: 0.5, Elo: 1931.40
#
# After Round 4:
# Player 0 - Points: 0.5, Elo: 2081.28
# Player 1 - Points: 2.5, Elo: 2397.08
# Player 2 - Points: 1.0, Elo: 1499.80
# Player 3 - Points: 4, Elo: 2483.11
# Player 4 - Points: 1.5, Elo: 2106.31
# Player 5 - Points: 2.5, Elo: 2285.00
# Player 6 - Points: 2.5, Elo: 2152.81
# Player 7 - Points: 2, Elo: 1940.38
# Player 8 - Points: 3.0, Elo: 2207.15
# Player 9 - Points: 0.5, Elo: 1929.06
#
# After Round 5:
# Player 0 - Points: 1.5, Elo: 2087.16
# Player 1 - Points: 2.5, Elo: 2383.97
# Player 2 - Points: 1.0, Elo: 1498.34
# Player 3 - Points: 5, Elo: 2486.50
# Player 4 - Points: 1.5, Elo: 2097.64
# Player 5 - Points: 3.5, Elo: 2298.12
# Player 6 - Points: 3.5, Elo: 2161.48
# Player 7 - Points: 3, Elo: 1941.85
# Player 8 - Points: 3.0, Elo: 2203.76
# Player 9 - Points: 0.5, Elo: 1923.19
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1789.38
# Player 1 - Points: 0.5, Elo: 2369.62
# Player 2 - Points: 1, Elo: 1751.63
# Player 3 - Points: 0, Elo: 2065.37
# Player 4 - Points: 1, Elo: 2353.14
# Player 5 - Points: 0, Elo: 1487.86
# Player 6 - Points: 0.5, Elo: 2333.44
# Player 7 - Points: 0.5, Elo: 2490.56
# Player 8 - Points: 1, Elo: 2050.11
# Player 9 - Points: 0, Elo: 1555.89
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 1785.74
# Player 1 - Points: 1.5, Elo: 2378.58
# Player 2 - Points: 1, Elo: 1751.03
# Player 3 - Points: 0, Elo: 2063.77
# Player 4 - Points: 2, Elo: 2353.74
# Player 5 - Points: 0.5, Elo: 1489.80
# Player 6 - Points: 0.5, Elo: 2324.48
# Player 7 - Points: 1.5, Elo: 2492.15
# Player 8 - Points: 2, Elo: 2053.76
# Player 9 - Points: 0.5, Elo: 1553.95
#
# After Round 3:
# Player 0 - Points: 0.5, Elo: 1774.74
# Player 1 - Points: 1.5, Elo: 2371.74
# Player 2 - Points: 2, Elo: 1762.02
# Player 3 - Points: 0.5, Elo: 2054.78
# Player 4 - Points: 3, Elo: 2356.76
# Player 5 - Points: 0.5, Elo: 1489.63
# Player 6 - Points: 1.5, Elo: 2324.64
# Player 7 - Points: 2.5, Elo: 2498.99
# Player 8 - Points: 2, Elo: 2050.74
# Player 9 - Points: 1.0, Elo: 1562.95
#
# After Round 4:
# Player 0 - Points: 0.5, Elo: 1773.93
# Player 1 - Points: 2.5, Elo: 2371.92
# Player 2 - Points: 2, Elo: 1758.83
# Player 3 - Points: 1.5, Elo: 2055.53
# Player 4 - Points: 3.5, Elo: 2360.64
# Player 5 - Points: 0.5, Elo: 1488.89
# Player 6 - Points: 2.5, Elo: 2325.45
# Player 7 - Points: 3.0, Elo: 2495.11
# Player 8 - Points: 3, Elo: 2053.93
# Player 9 - Points: 1.0, Elo: 1562.76
#
# After Round 5:
# Player 0 - Points: 0.5, Elo: 1770.63
# Player 1 - Points: 3.5, Elo: 2381.60
# Player 2 - Points: 2, Elo: 1758.09
# Player 3 - Points: 2.5, Elo: 2058.83
# Player 4 - Points: 3.5, Elo: 2350.97
# Player 5 - Points: 0.5, Elo: 1488.89
# Player 6 - Points: 3.5, Elo: 2326.19
# Player 7 - Points: 4.0, Elo: 2496.57
# Player 8 - Points: 3, Elo: 2052.47
# Player 9 - Points: 1.0, Elo: 1562.76
#
# After Round 1:
# Player 0 - Points: 1, Elo: 1829.44
# Player 1 - Points: 0, Elo: 1602.56
# Player 2 - Points: 1, Elo: 1965.88
# Player 3 - Points: 0, Elo: 1909.12
# Player 4 - Points: 0.5, Elo: 2242.87
# Player 5 - Points: 0.5, Elo: 2007.13
# Player 6 - Points: 1, Elo: 2224.74
# Player 7 - Points: 0, Elo: 1899.26
# Player 8 - Points: 0, Elo: 1651.56
# Player 9 - Points: 1, Elo: 2312.44
#
# After Round 2:
# Player 0 - Points: 1, Elo: 1823.17
# Player 1 - Points: 0, Elo: 1602.07
# Player 2 - Points: 2, Elo: 1972.15
# Player 3 - Points: 0, Elo: 1901.87
# Player 4 - Points: 1.5, Elo: 2243.36
# Player 5 - Points: 1.5, Elo: 2014.38
# Player 6 - Points: 2, Elo: 2237.21
# Player 7 - Points: 1, Elo: 1903.14
# Player 8 - Points: 0, Elo: 1647.69
# Player 9 - Points: 1, Elo: 2299.97
#
# After Round 3:
# Player 0 - Points: 1, Elo: 1821.54
# Player 1 - Points: 0, Elo: 1601.72
# Player 2 - Points: 2, Elo: 1968.57
# Player 3 - Points: 0, Elo: 1885.63
# Player 4 - Points: 2.5, Elo: 2244.99
# Player 5 - Points: 2.5, Elo: 2021.29
# Player 6 - Points: 3, Elo: 2240.78
# Player 7 - Points: 1, Elo: 1896.24
# Player 8 - Points: 1, Elo: 1663.93
# Player 9 - Points: 2, Elo: 2300.32
#
# After Round 4:
# Player 0 - Points: 1, Elo: 1820.34
# Player 1 - Points: 0, Elo: 1598.62
# Player 2 - Points: 2.5, Elo: 1970.08
# Player 3 - Points: 0, Elo: 1885.63
# Player 4 - Points: 2.5, Elo: 2234.87
# Player 5 - Points: 3.0, Elo: 2019.78
# Player 6 - Points: 4, Elo: 2250.90
# Player 7 - Points: 2, Elo: 1899.34
# Player 8 - Points: 1, Elo: 1663.93
# Player 9 - Points: 3, Elo: 2301.51
#
# After Round 5:
# Player 0 - Points: 2, Elo: 1826.12
# Player 1 - Points: 0, Elo: 1595.40
# Player 2 - Points: 2.5, Elo: 1967.49
# Player 3 - Points: 1, Elo: 1888.84
# Player 4 - Points: 3.5, Elo: 2237.40
# Player 5 - Points: 3.0, Elo: 2015.60
# Player 6 - Points: 5, Elo: 2255.08
# Player 7 - Points: 2, Elo: 1896.81
# Player 8 - Points: 1, Elo: 1658.15
# Player 9 - Points: 4, Elo: 2304.10
#
# After Round 1:
# Player 0 - Points: 0, Elo: 1753.46
# Player 1 - Points: 1, Elo: 1567.54
# Player 2 - Points: 1, Elo: 2302.16
# Player 3 - Points: 0, Elo: 1464.84
# Player 4 - Points: 1, Elo: 2255.44
# Player 5 - Points: 0, Elo: 1594.56
# Player 6 - Points: 1, Elo: 1928.80
# Player 7 - Points: 0, Elo: 1669.20
# Player 8 - Points: 1, Elo: 1830.60
# Player 9 - Points: 0, Elo: 1730.40
#
# After Round 2:
# Player 0 - Points: 0, Elo: 1745.64
# Player 1 - Points: 1, Elo: 1567.26
# Player 2 - Points: 2, Elo: 2302.45
# Player 3 - Points: 1, Elo: 1478.41
# Player 4 - Points: 2, Elo: 2258.09
# Player 5 - Points: 0, Elo: 1580.99
# Player 6 - Points: 1, Elo: 1926.15
# Player 7 - Points: 0.5, Elo: 1670.95
# Player 8 - Points: 2, Elo: 1838.42
# Player 9 - Points: 0.5, Elo: 1728.66
#
# After Round 3:
# Player 0 - Points: 0, Elo: 1733.52
# Player 1 - Points: 1.5, Elo: 1573.79
# Player 2 - Points: 3, Elo: 2311.18
# Player 3 - Points: 1, Elo: 1477.00
# Player 4 - Points: 2, Elo: 2249.36
# Player 5 - Points: 0, Elo: 1575.00
# Player 6 - Points: 2, Elo: 1927.56
# Player 7 - Points: 1.5, Elo: 1683.06
# Player 8 - Points: 2.5, Elo: 1831.89
# Player 9 - Points: 1.5, Elo: 1734.64
#
# After Round 4:
# Player 0 - Points: 0.5, Elo: 1729.25
# Player 1 - Points: 1.5, Elo: 1573.38
# Player 2 - Points: 4, Elo: 2312.37
# Player 3 - Points: 1, Elo: 1472.32
# Player 4 - Points: 3, Elo: 2249.76
# Player 5 - Points: 0.5, Elo: 1579.27
# Player 6 - Points: 2.5, Elo: 1922.52
# Player 7 - Points: 2.5, Elo: 1687.74
# Player 8 - Points: 2.5, Elo: 1830.70
# Player 9 - Points: 2.0, Elo: 1739.69
#
# After Round 5:
# Player 0 - Points: 0.5, Elo: 1729.25
# Player 1 - Points: 1.5, Elo: 1567.84
# Player 2 - Points: 5, Elo: 2314.29
# Player 3 - Points: 1, Elo: 1470.06
# Player 4 - Points: 4, Elo: 2250.51
# Player 5 - Points: 0.5, Elo: 1579.27
# Player 6 - Points: 2.5, Elo: 1920.60
# Player 7 - Points: 2.5, Elo: 1686.98
# Player 8 - Points: 3.5, Elo: 1832.95
# Player 9 - Points: 3.0, Elo: 1745.24
#
# After Round 1:
# Player 0 - Points: 0, Elo: 1593.23
# Player 1 - Points: 1, Elo: 2152.77
# Player 2 - Points: 0.5, Elo: 1766.86
# Player 3 - Points: 0.5, Elo: 1660.14
# Player 4 - Points: 1, Elo: 1983.45
# Player 5 - Points: 0, Elo: 1537.55
# Player 6 - Points: 1, Elo: 2219.23
# Player 7 - Points: 0, Elo: 1445.77
# Player 8 - Points: 1, Elo: 1738.91
# Player 9 - Points: 0, Elo: 1716.09
#
# After Round 2:
# Player 0 - Points: 0, Elo: 1587.84
# Player 1 - Points: 2, Elo: 2158.25
# Player 2 - Points: 1.5, Elo: 1772.24
# Player 3 - Points: 1.5, Elo: 1666.75
# Player 4 - Points: 1, Elo: 1977.97
# Player 5 - Points: 0, Elo: 1530.94
# Player 6 - Points: 2, Elo: 2220.42
# Player 7 - Points: 0.5, Elo: 1452.28
# Player 8 - Points: 1, Elo: 1737.73
# Player 9 - Points: 0.5, Elo: 1709.57
#
# After Round 3:
# Player 0 - Points: 1, Elo: 1594.13
# Player 1 - Points: 2.5, Elo: 2160.02
# Player 2 - Points: 2.5, Elo: 1787.55
# Player 3 - Points: 2.0, Elo: 1668.77
# ...
# Player 5 - Points: 1.0, Elo: 1492.47
# Player 6 - Points: 1.5, Elo: 1768.42
# Player 7 - Points: 2.5, Elo: 1853.46
# Player 8 - Points: 1.0, Elo: 1663.10
# Player 9 - Points: 1.5, Elo: 2053.94
#
# After Round 4:
# Player 0 - Points: 2.5, Elo: 2014.14
# Player 1 - Points: 3.5, Elo: 2398.56
# Player 2 - Points: 2, Elo: 2048.36
# Player 3 - Points: 0.5, Elo: 1863.18
# Player 4 - Points: 2.5, Elo: 2003.83
# Player 5 - Points: 1.0, Elo: 1491.68
# Player 6 - Points: 1.5, Elo: 1764.43
# Player 7 - Points: 3.0, Elo: 1858.67
# Player 8 - Points: 1.5, Elo: 1668.41
# Player 9 - Points: 2.0, Elo: 2048.74
#
# After Round 5:
# Player 0 - Points: 3.5, Elo: 2023.84
# Player 1 - Points: 4.5, Elo: 2399.42
# Player 2 - Points: 3, Elo: 2058.38
# Player 3 - Points: 1.0, Elo: 1855.28
# Player 4 - Points: 2.5, Elo: 1994.13
# Player 5 - Points: 1.5, Elo: 1499.57
# Player 6 - Points: 2.5, Elo: 1771.74
# Player 7 - Points: 3.0, Elo: 1857.81
# Player 8 - Points: 1.5, Elo: 1661.11
# Player 9 - Points: 2.0, Elo: 2038.73
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 2232.86
# Player 1 - Points: 0.5, Elo: 2586.14
# Player 2 - Points: 1, Elo: 2181.15
# Player 3 - Points: 0, Elo: 1883.85
# Player 4 - Points: 1, Elo: 2054.56
# Player 5 - Points: 0, Elo: 1781.44
# Player 6 - Points: 1, Elo: 2565.12
# Player 7 - Points: 0, Elo: 1678.88
# Player 8 - Points: 0.5, Elo: 2198.67
# Player 9 - Points: 0.5, Elo: 2465.33
#
# After Round 2:
# Player 0 - Points: 1.5, Elo: 2250.29
# Player 1 - Points: 1.5, Elo: 2588.08
# Player 2 - Points: 2, Elo: 2187.66
# Player 3 - Points: 0, Elo: 1883.17
# Player 4 - Points: 1, Elo: 2048.05
# Player 5 - Points: 0, Elo: 1768.57
# Player 6 - Points: 1, Elo: 2547.69
# Player 7 - Points: 1, Elo: 1691.75
# Player 8 - Points: 0.5, Elo: 2196.73
# Player 9 - Points: 1.5, Elo: 2466.01
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 2238.51
# Player 1 - Points: 2.5, Elo: 2594.70
# Player 2 - Points: 3, Elo: 2199.45
# Player 3 - Points: 1, Elo: 1889.98
# Player 4 - Points: 1.5, Elo: 2056.98
# Player 5 - Points: 0, Elo: 1761.76
# Player 6 - Points: 1.5, Elo: 2538.76
# Player 7 - Points: 1, Elo: 1690.71
# Player 8 - Points: 1.5, Elo: 2197.77
# Player 9 - Points: 1.5, Elo: 2459.38
#
# After Round 4:
# Player 0 - Points: 2.5, Elo: 2243.71
# Player 1 - Points: 3.5, Elo: 2596.56
# Player 2 - Points: 3, Elo: 2197.58
# Player 3 - Points: 1, Elo: 1889.98
# Player 4 - Points: 1.5, Elo: 2051.78
# Player 5 - Points: 0, Elo: 1761.76
# Player 6 - Points: 2.5, Elo: 2541.22
# Player 7 - Points: 1, Elo: 1690.48
# Player 8 - Points: 1.5, Elo: 2195.31
# Player 9 - Points: 2.5, Elo: 2459.62
#
# After Round 5:
# Player 0 - Points: 3.5, Elo: 2252.33
# Player 1 - Points: 4.5, Elo: 2604.99
# Player 2 - Points: 3.5, Elo: 2203.96
# Player 3 - Points: 1, Elo: 1884.33
# Player 4 - Points: 2.5, Elo: 2057.43
# Player 5 - Points: 0, Elo: 1761.76
# Player 6 - Points: 2.5, Elo: 2532.80
# Player 7 - Points: 1, Elo: 1690.48
# Player 8 - Points: 1.5, Elo: 2186.69
# Player 9 - Points: 3.0, Elo: 2453.24
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1879.28
# Player 1 - Points: 0.5, Elo: 2072.72
# Player 2 - Points: 1, Elo: 2226.58
# Player 3 - Points: 0, Elo: 1614.42
# Player 4 - Points: 0, Elo: 1727.85
# Player 5 - Points: 1, Elo: 1969.15
# Player 6 - Points: 1, Elo: 2107.99
# Player 7 - Points: 0, Elo: 1721.01
# Player 8 - Points: 1, Elo: 2297.88
# Player 9 - Points: 0, Elo: 2134.12
#
# After Round 2:
# Player 0 - Points: 1.5, Elo: 1882.85
# Player 1 - Points: 1.5, Elo: 2075.14
# Player 2 - Points: 1, Elo: 2210.28
# Player 3 - Points: 0, Elo: 1610.85
# Player 4 - Points: 0, Elo: 1725.44
# Player 5 - Points: 2, Elo: 1985.44
# Player 6 - Points: 1.5, Elo: 2112.97
# Player 7 - Points: 0, Elo: 1719.32
# Player 8 - Points: 1.5, Elo: 2292.90
# Player 9 - Points: 1, Elo: 2135.81
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 1875.72
# Player 1 - Points: 1.5, Elo: 2066.22
# Player 2 - Points: 1, Elo: 2202.61
# Player 3 - Points: 0, Elo: 1609.92
# Player 4 - Points: 1, Elo: 1735.26
# Player 5 - Points: 3, Elo: 1992.57
# Player 6 - Points: 2.5, Elo: 2121.88
# Player 7 - Points: 0, Elo: 1709.49
# Player 8 - Points: 2.5, Elo: 2300.57
# Player 9 - Points: 2, Elo: 2136.74
#
# After Round 4:
# Player 0 - Points: 1.5, Elo: 1874.13
# Player 1 - Points: 1.5, Elo: 2058.22
# Player 2 - Points: 2, Elo: 2203.88
# Player 3 - Points: 0.5, Elo: 1612.71
# Player 4 - Points: 1, Elo: 1733.99
# Player 5 - Points: 3.5, Elo: 1996.13
# Player 6 - Points: 3.0, Elo: 2118.32
# Player 7 - Points: 0.5, Elo: 1706.70
# Player 8 - Points: 3.5, Elo: 2302.17
# Player 9 - Points: 3, Elo: 2144.74
#
# After Round 5:
# Player 0 - Points: 1.5, Elo: 1871.52
# Player 1 - Points: 2.5, Elo: 2059.65
# Player 2 - Points: 3, Elo: 2206.49
# Player 3 - Points: 0.5, Elo: 1611.28
# Player 4 - Points: 1, Elo: 1733.99
# Player 5 - Points: 3.5, Elo: 1993.20
# Player 6 - Points: 4.0, Elo: 2129.08
# Player 7 - Points: 0.5, Elo: 1706.70
# Player 8 - Points: 4.5, Elo: 2305.10
# Player 9 - Points: 3, Elo: 2133.98
#
# After Round 1:
# Player 0 - Points: 0, Elo: 2360.42
# Player 1 - Points: 1, Elo: 2257.58
# Player 2 - Points: 1, Elo: 2548.14
# Player 3 - Points: 0, Elo: 1690.86
# Player 4 - Points: 0.5, Elo: 1652.89
# Player 5 - Points: 0.5, Elo: 2534.11
# Player 6 - Points: 1, Elo: 2001.72
# Player 7 - Points: 0, Elo: 1428.28
# Player 8 - Points: 1, Elo: 1922.35
# Player 9 - Points: 0, Elo: 1776.65
#
# After Round 2:
# Player 0 - Points: 1, Elo: 2360.76
# Player 1 - Points: 2, Elo: 2274.41
# Player 2 - Points: 1, Elo: 2531.30
# Player 3 - Points: 0, Elo: 1690.70
# Player 4 - Points: 0.5, Elo: 1652.55
# Player 5 - Points: 1.5, Elo: 2534.27
# Player 6 - Points: 2, Elo: 2009.47
# Player 7 - Points: 0.5, Elo: 1435.91
# Player 8 - Points: 1, Elo: 1914.59
# Player 9 - Points: 0.5, Elo: 1769.02
#
# After Round 3:
# Player 0 - Points: 1, Elo: 2355.37
# Player 1 - Points: 3, Elo: 2277.99
# Player 2 - Points: 2, Elo: 2531.86
# Player 3 - Points: 1, Elo: 1702.92
# Player 4 - Points: 1.0, Elo: 1647.02
# Player 5 - Points: 2.5, Elo: 2539.65
# Player 6 - Points: 2, Elo: 2005.90
# Player 7 - Points: 1.0, Elo: 1441.45
# Player 8 - Points: 1, Elo: 1914.04
# Player 9 - Points: 0.5, Elo: 1756.81
#
# After Round 4:
# Player 0 - Points: 2, Elo: 2355.83
# Player 1 - Points: 4, Elo: 2294.36
# Player 2 - Points: 3, Elo: 2532.79
# Player 3 - Points: 1, Elo: 1702.46
# Player 4 - Points: 2.0, Elo: 1663.48
# Player 5 - Points: 2.5, Elo: 2523.28
# Player 6 - Points: 2, Elo: 2004.97
# Player 7 - Points: 1.0, Elo: 1441.45
# Player 8 - Points: 1, Elo: 1897.57
# Player 9 - Points: 0.5, Elo: 1756.81
#
# After Round 5:
# Player 0 - Points: 2, Elo: 2338.17
# Player 1 - Points: 5, Elo: 2294.87
# Player 2 - Points: 3, Elo: 2522.51
# Player 3 - Points: 2, Elo: 1706.10
# Player 4 - Points: 2.0, Elo: 1662.96
# Player 5 - Points: 3.5, Elo: 2533.55
# Player 6 - Points: 3, Elo: 2022.63
# Player 7 - Points: 1.0, Elo: 1437.81
# Player 8 - Points: 1, Elo: 1897.57
# Player 9 - Points: 0.5, Elo: 1756.81
#
# After Round 1:
# Player 0 - Points: 0, Elo: 2300.15
# Player 1 - Points: 1, Elo: 2186.85
# Player 2 - Points: 1, Elo: 1691.60
# Player 3 - Points: 0, Elo: 1835.40
# Player 4 - Points: 1, Elo: 2432.37
# Player 5 - Points: 0, Elo: 2287.63
# Player 6 - Points: 0.5, Elo: 1448.44
# Player 7 - Points: 0.5, Elo: 1860.56
# Player 8 - Points: 1, Elo: 1977.86
# Player 9 - Points: 0, Elo: 2428.14
#
# After Round 2:
# Player 0 - Points: 1, Elo: 2300.30
# Player 1 - Points: 2, Elo: 2187.94
# Player 2 - Points: 1, Elo: 1690.51
# Player 3 - Points: 0, Elo: 1826.12
# Player 4 - Points: 2, Elo: 2433.74
# Player 5 - Points: 0, Elo: 2281.46
# Player 6 - Points: 0.5, Elo: 1448.29
# Player 7 - Points: 1.5, Elo: 1869.84
# Player 8 - Points: 1, Elo: 1976.50
# Player 9 - Points: 1, Elo: 2434.30
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 2291.85
# Player 1 - Points: 3, Elo: 2204.03
# Player 2 - Points: 2, Elo: 1707.28
# Player 3 - Points: 0, Elo: 1824.76
# Player 4 - Points: 2, Elo: 2417.64
# Player 5 - Points: 1, Elo: 2282.82
# Player 6 - Points: 0.5, Elo: 1448.22
# Player 7 - Points: 2.0, Elo: 1878.29
# Player 8 - Points: 1, Elo: 1959.73
# Player 9 - Points: 2, Elo: 2434.37
#
# After Round 4:
# Player 0 - Points: 1.5, Elo: 2285.73
# Player 1 - Points: 4, Elo: 2206.69
# Player 2 - Points: 2.5, Elo: 1716.95
# Player 3 - Points: 1, Elo: 1826.82
# Player 4 - Points: 2.5, Elo: 2407.97
# Player 5 - Points: 2, Elo: 2285.51
# Player 6 - Points: 0.5, Elo: 1446.17
# Player 7 - Points: 2.0, Elo: 1875.63
# Player 8 - Points: 1, Elo: 1957.04
# Player 9 - Points: 3, Elo: 2440.48
#
# After Round 5:
# Player 0 - Points: 2.5, Elo: 2287.06
# Player 1 - Points: 4.5, Elo: 2212.56
# Player 2 - Points: 2.5, Elo: 1716.22
# Player 3 - Points: 1, Elo: 1825.49
# Player 4 - Points: 3.5, Elo: 2408.87
# Player 5 - Points: 3, Elo: 2286.24
# Player 6 - Points: 0.5, Elo: 1445.17
# Player 7 - Points: 2.0, Elo: 1874.74
# Player 8 - Points: 2, Elo: 1958.04
# Player 9 - Points: 3.5, Elo: 2434.61
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1455.66
# Player 1 - Points: 0.5, Elo: 1895.34
# Player 2 - Points: 1, Elo: 2434.31
# Player 3 - Points: 0, Elo: 2075.69
# Player 4 - Points: 0, Elo: 2059.24
# Player 5 - Points: 1, Elo: 2153.76
# Player 6 - Points: 0.5, Elo: 1574.67
# Player 7 - Points: 0.5, Elo: 1741.33
# Player 8 - Points: 0.5, Elo: 1995.97
# Player 9 - Points: 0.5, Elo: 2484.03
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 1448.95
# Player 1 - Points: 1.5, Elo: 1901.18
# Player 2 - Points: 2, Elo: 2437.62
# Player 3 - Points: 0, Elo: 2063.44
# Player 4 - Points: 0, Elo: 2057.64
# Player 5 - Points: 1, Elo: 2150.45
# Player 6 - Points: 1.5, Elo: 1581.38
# Player 7 - Points: 0.5, Elo: 1735.49
# Player 8 - Points: 1.5, Elo: 2008.22
# Player 9 - Points: 1.5, Elo: 2485.63
#
# After Round 3:
# Player 0 - Points: 0.5, Elo: 1445.73
# Player 1 - Points: 1.5, Elo: 1900.31
# Player 2 - Points: 3, Elo: 2438.50
# Player 3 - Points: 1, Elo: 2073.27
# Player 4 - Points: 0, Elo: 2047.81
# Player 5 - Points: 1, Elo: 2147.91
# Player 6 - Points: 1.5, Elo: 1579.80
# Player 7 - Points: 1.5, Elo: 1738.71
# Player 8 - Points: 2.5, Elo: 2009.80
# Player 9 - Points: 2.5, Elo: 2488.16
#
# After Round 4:
# Player 0 - Points: 0.5, Elo: 1445.12
# Player 1 - Points: 1.5, Elo: 1899.65
# Player 2 - Points: 4, Elo: 2440.06
# Player 3 - Points: 1.5, Elo: 2064.38
# Player 4 - Points: 1, Elo: 2048.41
# Player 5 - Points: 1.5, Elo: 2139.64
# Player 6 - Points: 2.0, Elo: 1588.69
# Player 7 - Points: 2.0, Elo: 1746.98
# Player 8 - Points: 2.5, Elo: 2008.24
# Player 9 - Points: 3.5, Elo: 2488.82
#
# After Round 5:
# Player 0 - Points: 0.5, Elo: 1445.12
# Player 1 - Points: 2.5, Elo: 1902.51
# Player 2 - Points: 4.5, Elo: 2441.45
# Player 3 - Points: 1.5, Elo: 2056.51
# Player 4 - Points: 1, Elo: 2048.41
# Player 5 - Points: 2.5, Elo: 2147.51
# Player 6 - Points: 2.0, Elo: 1585.83
# Player 7 - Points: 2.0, Elo: 1743.35
# Player 8 - Points: 3.5, Elo: 2011.88
# Player 9 - Points: 4.0, Elo: 2487.42
#
# After Round 1:
# Player 0 - Points: 1, Elo: 1811.00
# Player 1 - Points: 0, Elo: 1562.00
# Player 2 - Points: 1, Elo: 2519.45
# Player 3 - Points: 0, Elo: 1861.55
# Player 4 - Points: 0, Elo: 2095.30
# Player 5 - Points: 1, Elo: 1901.70
# Player 6 - Points: 1, Elo: 2455.57
# Player 7 - Points: 0, Elo: 2024.43
# Player 8 - Points: 0.5, Elo: 2541.49
# Player 9 - Points: 0.5, Elo: 2590.51
#
# After Round 2:
# Player 0 - Points: 1, Elo: 1810.66
# Player 1 - Points: 0, Elo: 1561.93
# Player 2 - Points: 2, Elo: 2519.78
# Player 3 - Points: 0, Elo: 1861.26
# Player 4 - Points: 1, Elo: 2103.29
# Player 5 - Points: 1, Elo: 1900.91
# Player 6 - Points: 2, Elo: 2456.36
# Player 7 - Points: 0, Elo: 2016.44
# Player 8 - Points: 1.5, Elo: 2541.56
# Player 9 - Points: 1.5, Elo: 2590.81
#
# After Round 3:
# Player 0 - Points: 1, Elo: 1810.37
# Player 1 - Points: 0, Elo: 1559.44
# Player 2 - Points: 2, Elo: 2507.97
# Player 3 - Points: 1, Elo: 1875.45
# Player 4 - Points: 1, Elo: 2102.15
# Player 5 - Points: 2, Elo: 1903.40
# Player 6 - Points: 3, Elo: 2468.17
# Player 7 - Points: 0, Elo: 2002.25
# Player 8 - Points: 2.5, Elo: 2541.85
# Player 9 - Points: 2.5, Elo: 2591.95
#
# After Round 4:
# Player 0 - Points: 1, Elo: 1802.99
# Player 1 - Points: 0, Elo: 1557.99
# Player 2 - Points: 2.5, Elo: 2510.34
# Player 3 - Points: 2, Elo: 1891.18
# Player 4 - Points: 1, Elo: 2086.41
# Player 5 - Points: 3, Elo: 1910.78
# Player 6 - Points: 3, Elo: 2460.26
# Player 7 - Points: 1, Elo: 2003.70
# Player 8 - Points: 3.5, Elo: 2549.76
# Player 9 - Points: 3.0, Elo: 2589.58
#
# After Round 5:
# Player 0 - Points: 1, Elo: 1795.47
# Player 1 - Points: 0, Elo: 1557.99
# Player 2 - Points: 2.5, Elo: 2491.95
# Player 3 - Points: 3, Elo: 1898.70
# Player 4 - Points: 2, Elo: 2104.81
# Player 5 - Points: 3, Elo: 1910.29
# Player 6 - Points: 3.5, Elo: 2463.82
# Player 7 - Points: 1, Elo: 2003.70
# Player 8 - Points: 4.5, Elo: 2550.25
# Player 9 - Points: 3.5, Elo: 2586.02
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 1814.52
# Player 1 - Points: 0.5, Elo: 2139.48
# Player 2 - Points: 0.5, Elo: 1702.79
# Player 3 - Points: 0.5, Elo: 2473.21
# Player 4 - Points: 1, Elo: 1971.83
# Player 5 - Points: 0, Elo: 1424.17
# Player 6 - Points: 1, Elo: 2171.90
# Player 7 - Points: 0, Elo: 1639.10
# Player 8 - Points: 1, Elo: 1867.40
# Player 9 - Points: 0, Elo: 1683.60
#
# After Round 2:
# Player 0 - Points: 0.5, Elo: 1806.03
# Player 1 - Points: 1.5, Elo: 2140.97
# Player 2 - Points: 0.5, Elo: 1701.29
# Player 3 - Points: 1.5, Elo: 2473.26
# Player 4 - Points: 1, Elo: 1967.02
# Player 5 - Points: 0, Elo: 1424.13
# Player 6 - Points: 2, Elo: 2176.70
# Player 7 - Points: 1, Elo: 1650.38
# Player 8 - Points: 2, Elo: 1875.88
# Player 9 - Points: 0, Elo: 1672.33
#
# After Round 3:
# Player 0 - Points: 1.5, Elo: 1813.11
# Player 1 - Points: 1.5, Elo: 2138.40
# Player 2 - Points: 0.5, Elo: 1694.22
# Player 3 - Points: 2.5, Elo: 2475.83
# Player 4 - Points: 2, Elo: 1969.81
# Player 5 - Points: 0, Elo: 1420.26
# Player 6 - Points: 3, Elo: 2179.71
# Player 7 - Points: 1, Elo: 1647.59
# Player 8 - Points: 2, Elo: 1872.88
# Player 9 - Points: 1, Elo: 1676.20
#
# After Round 4:
# Player 0 - Points: 2.5, Elo: 1818.67
# Player 1 - Points: 2.5, Elo: 2139.71
# Player 2 - Points: 1.5, Elo: 1697.64
# Player 3 - Points: 3.0, Elo: 2468.91
# Player 4 - Points: 3, Elo: 1977.09
# Player 5 - Points: 0, Elo: 1416.84
# Player 6 - Points: 3.5, Elo: 2186.63
# Player 7 - Points: 1, Elo: 1642.03
# Player 8 - Points: 2, Elo: 1865.60
# Player 9 - Points: 1, Elo: 1674.89
#
# After Round 5:
# Player 0 - Points: 2.5, Elo: 1816.53
# Player 1 - Points: 3.5, Elo: 2143.13
# Player 2 - Points: 1.5, Elo: 1686.06
# Player 3 - Points: 4.0, Elo: 2470.02
# Player 4 - Points: 3, Elo: 1975.97
# Player 5 - Points: 0, Elo: 1416.84
# Player 6 - Points: 4.5, Elo: 2188.78
# Player 7 - Points: 2, Elo: 1653.61
# Player 8 - Points: 2, Elo: 1862.18
# Player 9 - Points: 1, Elo: 1674.89
#
# After Round 1:
# Player 0 - Points: 0.5, Elo: 2008.92
# Player 1 - Points: 0.5, Elo: 2145.08
# Player 2 - Points: 0, Elo: 2094.48
# Player 3 - Points: 1, Elo: 2233.52
# Player 4 - Points: 0, Elo: 1731.03
# Player 5 - Points: 1, Elo: 2250.97
# Player 6 - Points: 0, Elo: 1494.69
# Player 7 - Points: 1, Elo: 2219.31
# Player 8 - Points: 0.5, Elo: 1734.58
# Player 9 - Points: 0.5, Elo: 1942.42
#
# After Round 2:
# Player 0 - Points: 1.0, Elo: 2014.33
# Player 1 - Points: 1.5, Elo: 2146.80
# Player 2 - Points: 1, Elo: 2100.36
# Player 3 - Points: 2, Elo: 2244.03
# Player 4 - Points: 1, Elo: 1735.12
# Player 5 - Points: 1, Elo: 2240.46
# Player 6 - Points: 0, Elo: 1490.61
# Player 7 - Points: 1.5, Elo: 2213.90
# Player 8 - Points: 0.5, Elo: 1732.86
# Player 9 - Points: 0.5, Elo: 1936.53
#
# After Round 3:
# Player 0 - Points: 2.0, Elo: 2017.67
# Player 1 - Points: 1.5, Elo: 2139.53
# Player 2 - Points: 1, Elo: 2093.51
# Player 3 - Points: 3, Elo: 2251.30
# Player 4 - Points: 1, Elo: 1731.78
# Player 5 - Points: 2, Elo: 2241.49
# Player 6 - Points: 0, Elo: 1489.19
# Player 7 - Points: 2.5, Elo: 2220.74
# Player 8 - Points: 0.5, Elo: 1731.84
# Player 9 - Points: 1.5, Elo: 1937.96
#
# After Round 4:
# Player 0 - Points: 2.5, Elo: 2023.35
# Player 1 - Points: 2.5, Elo: 2144.30
# Player 2 - Points: 2, Elo: 2095.73
# Player 3 - Points: 3.5, Elo: 2250.42
# Player 4 - Points: 1, Elo: 1729.56
# Player 5 - Points: 2.5, Elo: 2235.81
# Player 6 - Points: 0, Elo: 1485.22
# Player 7 - Points: 3.0, Elo: 2221.62
# Player 8 - Points: 1.5, Elo: 1735.81
# Player 9 - Points: 1.5, Elo: 1933.19
#
# After Round 5:
# Player 0 - Points: 2.5, Elo: 2019.09
# Player 1 - Points: 2.5, Elo: 2136.49
# Player 2 - Points: 2, Elo: 2089.56
# Player 3 - Points: 4.5, Elo: 2254.68
# Player 4 - Points: 2, Elo: 1739.74
# Player 5 - Points: 3.5, Elo: 2241.98
# Player 6 - Points: 0, Elo: 1485.22
# Player 7 - Points: 4.0, Elo: 2229.43
# Player 8 - Points: 1.5, Elo: 1725.63
# Player 9 - Points: 1.5, Elo: 1933.19

# %%
import random

# Number of Players, Rounds, and Simulations
num_players = 10
num_rounds = 5
num_simulations = 400
k_factor = 20  # K-factor for Elo rating updates

# Initialize Players with Elo ratings
players = [{'name': f'Player {i}', 'elo': random.randint(1400, 2600), 'points': 0} for i in range(num_players)]

def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2 """
    return 1 / (1 + 10 ** ((player2['elo'] - player1['elo']) / 400))

def update_elo_ratings(winner, loser, draw=False):
    """ Update Elo ratings after a game """
    expected_win_winner = calculate_win_probability(winner, loser)
    expected_win_loser = calculate_win_probability(loser, winner)

    score_winner = 0.5 if draw else 1
    score_loser = 0.5 if draw else 0

    winner['elo'] += k_factor * (score_winner - expected_win_winner)
    loser['elo'] += k_factor * (score_loser - expected_win_loser)

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
        update_elo_ratings(player1, player2)
    elif result < win_prob + (1 - win_prob) / 2:
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
        update_elo_ratings(player1, player2, draw=True)
    else:
        player2['points'] += 1  # Player 2 wins
        update_elo_ratings(player2, player1)

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

def print_final_round_statistics(players, simulation_number):
    """ Print statistics for the final round """
    if 390 <= simulation_number <= 400:
        print(f"\nSimulation {simulation_number} - Final Round Results:")
        for player in players:
            # Print probabilities of winning the tournament

            probability = tournament_wins[player['name']] / num_simulations
#           print(f"{player['name']} winning probability: {probability:.2f}")
            print(f"{player['name']} - Points: {player['points']}, Elo: {player['elo']:.2f} winning probability: {probability:.2f}")

def simulate_tournament(simulation_number):
    """ Simulate a single Swiss-system tournament """
    # Reset points and opponents for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []
        player['elo'] = random.randint(1400, 2600)  # Reset Elo for each simulation

    # Simulate rounds
    for round_number in range(1, num_rounds + 1):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)
        # update elo ratings after actual outcome         

    # Print final round statistics for specified simulations
    if round_number == num_rounds:
        print_final_round_statistics(players, simulation_number)

# Simulate and Print Results
for simulation_number in range(1, num_simulations + 1):
    simulate_tournament(simulation_number)
# Out:
# Simulation 390 - Final Round Results:
# Player 0 - Points: 3, Elo: 2014.10 winning probability: 1.29
# Player 1 - Points: 1, Elo: 1570.92 winning probability: 0.01
# Player 2 - Points: 3.5, Elo: 2099.65 winning probability: 0.23
# Player 3 - Points: 1, Elo: 1993.76 winning probability: 0.00
# Player 4 - Points: 2.5, Elo: 1956.72 winning probability: 0.09
# Player 5 - Points: 0, Elo: 1913.84 winning probability: 0.01
# Player 6 - Points: 2.0, Elo: 1972.64 winning probability: 0.04
# Player 7 - Points: 4.5, Elo: 2535.00 winning probability: 0.00
# Player 8 - Points: 2.5, Elo: 2197.72 winning probability: 0.08
# Player 9 - Points: 4, Elo: 2195.66 winning probability: 0.76
#
# Simulation 391 - Final Round Results:
# Player 0 - Points: 2.5, Elo: 1599.74 winning probability: 1.29
# Player 1 - Points: 1.5, Elo: 1498.82 winning probability: 0.01
# Player 2 - Points: 3.5, Elo: 2550.03 winning probability: 0.23
# Player 3 - Points: 0.5, Elo: 1432.34 winning probability: 0.00
# Player 4 - Points: 2.5, Elo: 1851.79 winning probability: 0.09
# Player 5 - Points: 4.0, Elo: 2364.05 winning probability: 0.01
# Player 6 - Points: 3, Elo: 2232.30 winning probability: 0.04
# Player 7 - Points: 3.0, Elo: 2219.85 winning probability: 0.00
# Player 8 - Points: 1.0, Elo: 1449.54 winning probability: 0.08
# Player 9 - Points: 3.5, Elo: 2192.55 winning probability: 0.76
#
# Simulation 392 - Final Round Results:
# Player 0 - Points: 3.0, Elo: 1800.36 winning probability: 1.29
# Player 1 - Points: 5, Elo: 2567.10 winning probability: 0.01
# Player 2 - Points: 2.5, Elo: 2342.35 winning probability: 0.23
# Player 3 - Points: 3.0, Elo: 2459.45 winning probability: 0.00
# Player 4 - Points: 2.5, Elo: 2267.54 winning probability: 0.09
# Player 5 - Points: 1, Elo: 1490.27 winning probability: 0.01
# Player 6 - Points: 2.5, Elo: 2130.13 winning probability: 0.04
# Player 7 - Points: 1.5, Elo: 1634.21 winning probability: 0.00
# Player 8 - Points: 2.0, Elo: 2176.44 winning probability: 0.08
# Player 9 - Points: 0, Elo: 1557.15 winning probability: 0.76
#
# Simulation 393 - Final Round Results:
# Player 0 - Points: 2, Elo: 1827.82 winning probability: 1.29
# Player 1 - Points: 4.0, Elo: 2375.50 winning probability: 0.01
# Player 2 - Points: 3.5, Elo: 2459.58 winning probability: 0.23
# Player 3 - Points: 2.5, Elo: 2496.06 winning probability: 0.00
# Player 4 - Points: 4.0, Elo: 2280.36 winning probability: 0.09
# Player 5 - Points: 0, Elo: 1903.73 winning probability: 0.01
# Player 6 - Points: 1, Elo: 1894.83 winning probability: 0.04
# Player 7 - Points: 1.5, Elo: 1870.44 winning probability: 0.00
# Player 8 - Points: 2.5, Elo: 2096.52 winning probability: 0.08
# Player 9 - Points: 3.0, Elo: 2259.16 winning probability: 0.76
#
# Simulation 394 - Final Round Results:
# Player 0 - Points: 5, Elo: 2516.11 winning probability: 1.29
# Player 1 - Points: 0, Elo: 1463.57 winning probability: 0.01
# Player 2 - Points: 1, Elo: 1943.16 winning probability: 0.23
# Player 3 - Points: 1.5, Elo: 1742.15 winning probability: 0.00
# Player 4 - Points: 3.5, Elo: 2318.89 winning probability: 0.09
# Player 5 - Points: 1, Elo: 1819.61 winning probability: 0.01
# Player 6 - Points: 2.5, Elo: 2087.45 winning probability: 0.04
# Player 7 - Points: 3.5, Elo: 2154.24 winning probability: 0.00
# Player 8 - Points: 3, Elo: 2335.66 winning probability: 0.08
# Player 9 - Points: 3, Elo: 2403.14 winning probability: 0.76
#
# Simulation 395 - Final Round Results:
# Player 0 - Points: 3.5, Elo: 2053.72 winning probability: 1.29
# Player 1 - Points: 1.5, Elo: 2039.81 winning probability: 0.01
# Player 2 - Points: 3.5, Elo: 2282.73 winning probability: 0.23
# Player 3 - Points: 1.5, Elo: 1885.65 winning probability: 0.00
# Player 4 - Points: 3, Elo: 2253.11 winning probability: 0.09
# Player 5 - Points: 0.5, Elo: 1662.13 winning probability: 0.01
# Player 6 - Points: 1.5, Elo: 1863.93 winning probability: 0.04
# Player 7 - Points: 2.5, Elo: 2030.22 winning probability: 0.00
# Player 8 - Points: 4.5, Elo: 2285.53 winning probability: 0.08
# Player 9 - Points: 2.0, Elo: 1902.17 winning probability: 0.76
#
# Simulation 396 - Final Round Results:
# Player 0 - Points: 2.0, Elo: 1690.70 winning probability: 1.29
# Player 1 - Points: 2.5, Elo: 2048.13 winning probability: 0.01
# Player 2 - Points: 0, Elo: 1810.30 winning probability: 0.23
# Player 3 - Points: 2.0, Elo: 2119.70 winning probability: 0.00
# Player 4 - Points: 2.0, Elo: 1831.95 winning probability: 0.09
# Player 5 - Points: 3.5, Elo: 2209.45 winning probability: 0.01
# Player 6 - Points: 5, Elo: 2534.66 winning probability: 0.04
# Player 7 - Points: 1, Elo: 1642.20 winning probability: 0.00
# Player 8 - Points: 2.0, Elo: 2085.30 winning probability: 0.08
# Player 9 - Points: 3.0, Elo: 2390.62 winning probability: 0.76
#
# Simulation 397 - Final Round Results:
# Player 0 - Points: 2.5, Elo: 2301.75 winning probability: 1.29
# Player 1 - Points: 1, Elo: 1728.81 winning probability: 0.01
# Player 2 - Points: 3.0, Elo: 1847.14 winning probability: 0.23
# Player 3 - Points: 2.0, Elo: 2042.38 winning probability: 0.00
# Player 4 - Points: 1.0, Elo: 1621.11 winning probability: 0.09
# Player 5 - Points: 3.0, Elo: 2115.20 winning probability: 0.01
# Player 6 - Points: 2.5, Elo: 2082.06 winning probability: 0.04
# Player 7 - Points: 4.5, Elo: 2495.35 winning probability: 0.00
# Player 8 - Points: 4, Elo: 2486.06 winning probability: 0.08
# Player 9 - Points: 0.5, Elo: 1930.14 winning probability: 0.76
#
# Simulation 398 - Final Round Results:
# Player 0 - Points: 2.5, Elo: 2155.08 winning probability: 1.29
# Player 1 - Points: 4.0, Elo: 2544.81 winning probability: 0.01
# Player 2 - Points: 3.0, Elo: 2306.53 winning probability: 0.23
# Player 3 - Points: 1, Elo: 1578.00 winning probability: 0.00
# Player 4 - Points: 3.0, Elo: 2346.57 winning probability: 0.09
# Player 5 - Points: 0, Elo: 1430.76 winning probability: 0.01
# Player 6 - Points: 4.5, Elo: 2523.80 winning probability: 0.04
# Player 7 - Points: 2.5, Elo: 2361.11 winning probability: 0.00
# Player 8 - Points: 2.5, Elo: 2407.41 winning probability: 0.08
# Player 9 - Points: 1, Elo: 1756.93 winning probability: 0.76
#
# Simulation 399 - Final Round Results:
# Player 0 - Points: 1.5, Elo: 1715.55 winning probability: 1.29
# Player 1 - Points: 2, Elo: 1735.77 winning probability: 0.01
# Player 2 - Points: 4.5, Elo: 2360.57 winning probability: 0.23
# Player 3 - Points: 4, Elo: 2095.58 winning probability: 0.00
# Player 4 - Points: 3, Elo: 1798.14 winning probability: 0.09
# Player 5 - Points: 0.5, Elo: 1692.55 winning probability: 0.01
# Player 6 - Points: 2, Elo: 2301.10 winning probability: 0.04
# Player 7 - Points: 0.5, Elo: 1686.79 winning probability: 0.00
# Player 8 - Points: 3, Elo: 1606.34 winning probability: 0.08
# Player 9 - Points: 3, Elo: 1931.62 winning probability: 0.76
#
# Simulation 400 - Final Round Results:
# Player 0 - Points: 3.5, Elo: 2493.09 winning probability: 1.29
# Player 1 - Points: 1.5, Elo: 1529.65 winning probability: 0.01
# Player 2 - Points: 1, Elo: 1816.70 winning probability: 0.23
# Player 3 - Points: 0.5, Elo: 2023.60 winning probability: 0.00
# Player 4 - Points: 4.5, Elo: 2341.15 winning probability: 0.09
# Player 5 - Points: 4.0, Elo: 2370.89 winning probability: 0.01
# Player 6 - Points: 2.5, Elo: 1573.98 winning probability: 0.04
# Player 7 - Points: 1.0, Elo: 1599.71 winning probability: 0.00
# Player 8 - Points: 3, Elo: 1740.73 winning probability: 0.08
# Player 9 - Points: 2.5, Elo: 1777.50 winning probability: 0.76

# %%
import random

# Number of Players, Rounds, and Simulations
num_players = 10
num_rounds = 5
num_simulations = 1000
k_factor = 20  # K-factor for Elo rating updates

# Initialize Players with Elo ratings
players = [{'name': f'Player {i}', 'elo': random.randint(1400, 2600), 'points': 0, 'wins': 0} for i in range(num_players)]

def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2 """
    return 1 / (1 + 10 ** ((player2['elo'] - player1['elo']) / 400))

def update_elo_ratings(winner, loser, draw=False):
    """ Update Elo ratings after a game """
    expected_win_winner = calculate_win_probability(winner, loser)
    expected_win_loser = calculate_win_probability(loser, winner)

    score_winner = 0.5 if draw else 1
    score_loser = 0.5 if draw else 0

    winner['elo'] += k_factor * (score_winner - expected_win_winner)
    loser['elo'] += k_factor * (score_loser - expected_win_loser)

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
        update_elo_ratings(player1, player2)
    elif result < win_prob + (1 - win_prob) / 2:
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
        update_elo_ratings(player1, player2, draw=True)
    else:
        player2['points'] += 1  # Player 2 wins
        update_elo_ratings(player2, player1)

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

def print_final_round_statistics(players, simulation_number):
    """ Print statistics for the final round """
    if 990 <= simulation_number <= 1000:
        print(f"\nSimulation {simulation_number} - Final Round Results:")
        for player in players:
            winning_probability = player['wins'] / num_simulations
            print(f"{player['name']} - Points: {player['points']}, Elo: {player['elo']:.2f}, Winning Probability: {winning_probability:.2f}")

def simulate_tournament(simulation_number):
    """ Simulate a single Swiss-system tournament """
    # Reset points and opponents for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []

    # Simulate rounds
    for round_number in range(1, num_rounds + 1):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)

    # Determine winner and update wins
    winner = max(players, key=lambda x: x['points'])
    winner['wins'] += 1

    # Print final round statistics for specified simulations
    if round_number == num_rounds:
        print_final_round_statistics(players, simulation_number)

# Simulate and Print Results
for simulation_number in range(1, num_simulations + 1):
    simulate_tournament(simulation_number)

# Reset wins count for next simulation
for player in players:
    player['wins'] = 0
# Out:
# Simulation 990 - Final Round Results:
# Player 0 - Points: 5, Elo: 2901.79, Winning Probability: 0.79
# Player 1 - Points: 1, Elo: 1457.79, Winning Probability: 0.00
# Player 2 - Points: 2.5, Elo: 1970.77, Winning Probability: 0.06
# Player 3 - Points: 3.0, Elo: 2028.35, Winning Probability: 0.00
# Player 4 - Points: 4, Elo: 2078.52, Winning Probability: 0.11
# Player 5 - Points: 2, Elo: 1836.34, Winning Probability: 0.00
# Player 6 - Points: 3.0, Elo: 1986.12, Winning Probability: 0.02
# Player 7 - Points: 2, Elo: 1851.67, Winning Probability: 0.00
# Player 8 - Points: 1.5, Elo: 2019.37, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1053.26, Winning Probability: 0.00
#
# Simulation 991 - Final Round Results:
# Player 0 - Points: 5, Elo: 2902.30, Winning Probability: 0.79
# Player 1 - Points: 1, Elo: 1457.89, Winning Probability: 0.00
# Player 2 - Points: 3, Elo: 1992.08, Winning Probability: 0.06
# Player 3 - Points: 3.0, Elo: 2028.91, Winning Probability: 0.00
# Player 4 - Points: 3, Elo: 2084.80, Winning Probability: 0.11
# Player 5 - Points: 2.0, Elo: 1831.71, Winning Probability: 0.00
# Player 6 - Points: 2.5, Elo: 1986.56, Winning Probability: 0.02
# Player 7 - Points: 2.5, Elo: 1854.28, Winning Probability: 0.00
# Player 8 - Points: 2, Elo: 1994.49, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1050.99, Winning Probability: 0.00
#
# Simulation 992 - Final Round Results:
# Player 0 - Points: 5, Elo: 2902.77, Winning Probability: 0.79
# Player 1 - Points: 2.0, Elo: 1492.19, Winning Probability: 0.00
# Player 2 - Points: 2, Elo: 1988.05, Winning Probability: 0.06
# Player 3 - Points: 1.5, Elo: 1993.91, Winning Probability: 0.00
# Player 4 - Points: 2.5, Elo: 2077.00, Winning Probability: 0.11
# Player 5 - Points: 2.0, Elo: 1838.56, Winning Probability: 0.00
# Player 6 - Points: 3.0, Elo: 1983.60, Winning Probability: 0.02
# Player 7 - Points: 2, Elo: 1839.51, Winning Probability: 0.00
# Player 8 - Points: 4, Elo: 2017.92, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1050.51, Winning Probability: 0.00
#
# Simulation 993 - Final Round Results:
# Player 0 - Points: 5, Elo: 2903.17, Winning Probability: 0.79
# Player 1 - Points: 1, Elo: 1490.63, Winning Probability: 0.00
# Player 2 - Points: 3.5, Elo: 2007.45, Winning Probability: 0.06
# Player 3 - Points: 2.5, Elo: 2005.73, Winning Probability: 0.00
# Player 4 - Points: 2.5, Elo: 2052.19, Winning Probability: 0.11
# Player 5 - Points: 1.5, Elo: 1846.20, Winning Probability: 0.00
# Player 6 - Points: 2.5, Elo: 1968.75, Winning Probability: 0.02
# Player 7 - Points: 1, Elo: 1829.36, Winning Probability: 0.00
# Player 8 - Points: 3.5, Elo: 2031.77, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1048.75, Winning Probability: 0.00
#
# Simulation 994 - Final Round Results:
# Player 0 - Points: 5, Elo: 2903.64, Winning Probability: 0.79
# Player 1 - Points: 0, Elo: 1484.00, Winning Probability: 0.00
# Player 2 - Points: 2.5, Elo: 2012.00, Winning Probability: 0.06
# Player 3 - Points: 3, Elo: 1991.42, Winning Probability: 0.00
# Player 4 - Points: 4, Elo: 2077.81, Winning Probability: 0.11
# Player 5 - Points: 2, Elo: 1838.26, Winning Probability: 0.00
# Player 6 - Points: 2, Elo: 1950.31, Winning Probability: 0.02
# Player 7 - Points: 2.5, Elo: 1845.43, Winning Probability: 0.00
# Player 8 - Points: 3, Elo: 2032.87, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1048.27, Winning Probability: 0.00
#
# Simulation 995 - Final Round Results:
# Player 0 - Points: 5, Elo: 2904.04, Winning Probability: 0.79
# Player 1 - Points: 2, Elo: 1499.92, Winning Probability: 0.00
# Player 2 - Points: 1.5, Elo: 2001.44, Winning Probability: 0.06
# Player 3 - Points: 2, Elo: 1980.88, Winning Probability: 0.00
# Player 4 - Points: 1.5, Elo: 2041.41, Winning Probability: 0.11
# Player 5 - Points: 3, Elo: 1847.90, Winning Probability: 0.00
# Player 6 - Points: 3.5, Elo: 1973.25, Winning Probability: 0.02
# Player 7 - Points: 2.5, Elo: 1848.21, Winning Probability: 0.00
# Player 8 - Points: 3, Elo: 2040.59, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1046.35, Winning Probability: 0.00
#
# Simulation 996 - Final Round Results:
# Player 0 - Points: 5, Elo: 2904.48, Winning Probability: 0.80
# Player 1 - Points: 1, Elo: 1496.76, Winning Probability: 0.00
# Player 2 - Points: 1.5, Elo: 1975.91, Winning Probability: 0.06
# Player 3 - Points: 2.5, Elo: 1993.42, Winning Probability: 0.00
# Player 4 - Points: 3.5, Elo: 2060.83, Winning Probability: 0.11
# Player 5 - Points: 1, Elo: 1830.64, Winning Probability: 0.00
# Player 6 - Points: 3, Elo: 1970.05, Winning Probability: 0.02
# Player 7 - Points: 3, Elo: 1858.41, Winning Probability: 0.00
# Player 8 - Points: 3.5, Elo: 2049.01, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1044.49, Winning Probability: 0.00
#
# Simulation 997 - Final Round Results:
# Player 0 - Points: 5, Elo: 2904.95, Winning Probability: 0.80
# Player 1 - Points: 1, Elo: 1493.88, Winning Probability: 0.00
# Player 2 - Points: 3, Elo: 1993.86, Winning Probability: 0.06
# Player 3 - Points: 2.5, Elo: 1975.93, Winning Probability: 0.00
# Player 4 - Points: 3.5, Elo: 2079.87, Winning Probability: 0.11
# Player 5 - Points: 1, Elo: 1815.14, Winning Probability: 0.00
# Player 6 - Points: 2.0, Elo: 1962.04, Winning Probability: 0.02
# Player 7 - Points: 3, Elo: 1867.63, Winning Probability: 0.00
# Player 8 - Points: 3, Elo: 2048.10, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1042.61, Winning Probability: 0.00
#
# Simulation 998 - Final Round Results:
# Player 0 - Points: 5, Elo: 2905.48, Winning Probability: 0.80
# Player 1 - Points: 1, Elo: 1492.39, Winning Probability: 0.00
# Player 2 - Points: 3, Elo: 2004.64, Winning Probability: 0.06
# Player 3 - Points: 3.0, Elo: 1992.76, Winning Probability: 0.00
# Player 4 - Points: 1.5, Elo: 2050.30, Winning Probability: 0.11
# Player 5 - Points: 2.0, Elo: 1811.94, Winning Probability: 0.00
# Player 6 - Points: 3.0, Elo: 1975.67, Winning Probability: 0.02
# Player 7 - Points: 2.5, Elo: 1855.12, Winning Probability: 0.00
# Player 8 - Points: 3.0, Elo: 2054.93, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1040.76, Winning Probability: 0.00
#
# Simulation 999 - Final Round Results:
# Player 0 - Points: 5, Elo: 2905.91, Winning Probability: 0.80
# Player 1 - Points: 1, Elo: 1489.83, Winning Probability: 0.00
# Player 2 - Points: 3.5, Elo: 2028.60, Winning Probability: 0.06
# Player 3 - Points: 3.5, Elo: 2015.62, Winning Probability: 0.00
# Player 4 - Points: 2.5, Elo: 2048.70, Winning Probability: 0.11
# Player 5 - Points: 2.5, Elo: 1826.41, Winning Probability: 0.00
# Player 6 - Points: 2, Elo: 1947.86, Winning Probability: 0.02
# Player 7 - Points: 2, Elo: 1856.98, Winning Probability: 0.00
# Player 8 - Points: 2, Elo: 2025.08, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1039.02, Winning Probability: 0.00
#
# Simulation 1000 - Final Round Results:
# Player 0 - Points: 5, Elo: 2906.38, Winning Probability: 0.80
# Player 1 - Points: 1, Elo: 1487.29, Winning Probability: 0.00
# Player 2 - Points: 1.5, Elo: 2013.38, Winning Probability: 0.06
# Player 3 - Points: 3, Elo: 2000.28, Winning Probability: 0.00
# Player 4 - Points: 4, Elo: 2076.30, Winning Probability: 0.11
# Player 5 - Points: 3, Elo: 1855.09, Winning Probability: 0.00
# Player 6 - Points: 1, Elo: 1914.60, Winning Probability: 0.02
# Player 7 - Points: 3, Elo: 1875.90, Winning Probability: 0.00
# Player 8 - Points: 2.5, Elo: 2017.43, Winning Probability: 0.01
# Player 9 - Points: 0, Elo: 1037.35, Winning Probability: 0.00

# %%
import random

# Number of Players, Rounds, and Simulations
num_players = 10
num_rounds = 5
num_simulations = 10000
k_factor = 30  # Higher K-factor for more responsive Elo rating updates

# Initialize Players with Elo ratings
players = [{'name': f'Player {i}', 'elo': random.randint(1400, 2000), 'points': 0, 'wins': 0, 'current_form': 0} for i in range(num_players)]

def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2, considering current form """
    # Adjusting Elo ratings based on current form
    adjusted_elo1 = player1['elo'] + player1['current_form']
    adjusted_elo2 = player2['elo'] + player2['current_form']
    return 1 / (1 + 10 ** ((adjusted_elo2 - adjusted_elo1) / 400))

def update_elo_ratings(winner, loser, draw=False):
    """ Update Elo ratings and current form after a game """
    expected_win_winner = calculate_win_probability(winner, loser)
    expected_win_loser = calculate_win_probability(loser, winner)

    score_winner = 0.5 if draw else 1
    score_loser = 0.5 if draw else 0

    winner['elo'] += k_factor * (score_winner - expected_win_winner)
    loser['elo'] += k_factor * (score_loser - expected_win_loser)

    # Update current form based on recent game outcome
    winner['current_form'] += k_factor * 0.5 if not draw else -k_factor * 0.2
    loser['current_form'] += -k_factor * 0.5 if not draw else k_factor * 0.2

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
        update_elo_ratings(player1, player2)
    elif result < win_prob + (1 - win_prob) / 2:
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
        update_elo_ratings(player1, player2, draw=True)
    else:
        player2['points'] += 1  # Player 2 wins
        update_elo_ratings(player2, player1)

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

def print_final_round_statistics(players, simulation_number):
    """ Print statistics for the final round """
    if 9990 <= simulation_number <= 10000:
        print(f"\nSimulation {simulation_number} - Final Round Results:")
        for player in players:
            winning_probability = player['wins'] / num_simulations
            print(f"{player['name']} - Points: {player['points']}, Elo: {player['elo']:.2f}, Winning Probability: {winning_probability:.2f}")

def simulate_tournament(simulation_number):
    """ Simulate a single Swiss-system tournament """
    # Reset points, opponents, and current form for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []
        player['current_form'] = 0
        player['elo'] = random.randint(1400, 2000)  # Reset Elo for each simulation

    # Simulate rounds
    for round_number in range(1, num_rounds + 1):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)

    # Determine winner and update wins
    winner = max(players, key=lambda x: x['points'])
    winner['wins'] += 1

    # Print final round statistics for specified simulations
    if round_number == num_rounds:
        print_final_round_statistics(players, simulation_number)

# Simulate and Print Results
for simulation_number in range(1, num_simulations + 1):
    simulate_tournament(simulation_number)
# Out:
# Simulation 9990 - Final Round Results:
# Player 0 - Points: 2, Elo: 1865.93, Winning Probability: 0.19
# Player 1 - Points: 3, Elo: 1960.75, Winning Probability: 0.13
# Player 2 - Points: 0.5, Elo: 1529.58, Winning Probability: 0.12
# Player 3 - Points: 4.5, Elo: 1936.63, Winning Probability: 0.08
# Player 4 - Points: 1.0, Elo: 1666.22, Winning Probability: 0.11
# Player 5 - Points: 2, Elo: 1954.33, Winning Probability: 0.07
# Player 6 - Points: 3, Elo: 1918.40, Winning Probability: 0.09
# Player 7 - Points: 2.5, Elo: 1797.20, Winning Probability: 0.06
# Player 8 - Points: 1.5, Elo: 1636.23, Winning Probability: 0.08
# Player 9 - Points: 4.0, Elo: 1809.74, Winning Probability: 0.05
#
# Simulation 9991 - Final Round Results:
# Player 0 - Points: 3, Elo: 1874.72, Winning Probability: 0.19
# Player 1 - Points: 2.5, Elo: 1948.65, Winning Probability: 0.13
# Player 2 - Points: 0.5, Elo: 1395.86, Winning Probability: 0.12
# Player 3 - Points: 3.5, Elo: 1477.66, Winning Probability: 0.08
# Player 4 - Points: 5, Elo: 1915.94, Winning Probability: 0.11
# Player 5 - Points: 1, Elo: 1439.50, Winning Probability: 0.07
# Player 6 - Points: 2.5, Elo: 1597.65, Winning Probability: 0.09
# Player 7 - Points: 2.5, Elo: 1640.00, Winning Probability: 0.06
# Player 8 - Points: 2, Elo: 1903.75, Winning Probability: 0.08
# Player 9 - Points: 0.5, Elo: 1497.27, Winning Probability: 0.05
#
# Simulation 9992 - Final Round Results:
# Player 0 - Points: 2.0, Elo: 1690.02, Winning Probability: 0.19
# Player 1 - Points: 3.5, Elo: 1750.30, Winning Probability: 0.13
# Player 2 - Points: 1.5, Elo: 1491.63, Winning Probability: 0.12
# Player 3 - Points: 2.5, Elo: 1795.99, Winning Probability: 0.08
# Player 4 - Points: 2.5, Elo: 1854.03, Winning Probability: 0.11
# Player 5 - Points: 4.5, Elo: 1946.31, Winning Probability: 0.07
# Player 6 - Points: 1.5, Elo: 1430.49, Winning Probability: 0.09
# Player 7 - Points: 2.0, Elo: 1772.85, Winning Probability: 0.06
# Player 8 - Points: 0.5, Elo: 1404.37, Winning Probability: 0.08
# Player 9 - Points: 3.5, Elo: 1937.00, Winning Probability: 0.05
#
# Simulation 9993 - Final Round Results:
# Player 0 - Points: 1.5, Elo: 1522.98, Winning Probability: 0.19
# Player 1 - Points: 3.5, Elo: 1870.86, Winning Probability: 0.13
# Player 2 - Points: 4.0, Elo: 1790.64, Winning Probability: 0.12
# Player 3 - Points: 0.5, Elo: 1481.42, Winning Probability: 0.08
# Player 4 - Points: 3.5, Elo: 1953.98, Winning Probability: 0.11
# Player 5 - Points: 2.5, Elo: 1724.62, Winning Probability: 0.07
# Player 6 - Points: 1.0, Elo: 1423.71, Winning Probability: 0.09
# Player 7 - Points: 2, Elo: 1679.44, Winning Probability: 0.06
# Player 8 - Points: 1.5, Elo: 1604.30, Winning Probability: 0.08
# Player 9 - Points: 4, Elo: 1885.05, Winning Probability: 0.05
#
# Simulation 9994 - Final Round Results:
# Player 0 - Points: 3.0, Elo: 1902.98, Winning Probability: 0.19
# Player 1 - Points: 2.5, Elo: 1718.92, Winning Probability: 0.13
# Player 2 - Points: 5, Elo: 1975.76, Winning Probability: 0.12
# Player 3 - Points: 1.5, Elo: 1655.74, Winning Probability: 0.08
# Player 4 - Points: 2.5, Elo: 1737.21, Winning Probability: 0.11
# Player 5 - Points: 2.0, Elo: 1692.58, Winning Probability: 0.07
# Player 6 - Points: 1.5, Elo: 1832.08, Winning Probability: 0.09
# Player 7 - Points: 0, Elo: 1705.51, Winning Probability: 0.06
# Player 8 - Points: 3.0, Elo: 1958.52, Winning Probability: 0.08
# Player 9 - Points: 3.0, Elo: 1721.70, Winning Probability: 0.05
#
# Simulation 9995 - Final Round Results:
# Player 0 - Points: 1.5, Elo: 1477.05, Winning Probability: 0.19
# Player 1 - Points: 2.0, Elo: 1454.23, Winning Probability: 0.13
# Player 2 - Points: 1.5, Elo: 1487.42, Winning Probability: 0.12
# Player 3 - Points: 3.5, Elo: 1957.39, Winning Probability: 0.08
# Player 4 - Points: 4.0, Elo: 1877.32, Winning Probability: 0.11
# Player 5 - Points: 2, Elo: 1670.47, Winning Probability: 0.07
# Player 6 - Points: 1, Elo: 1577.80, Winning Probability: 0.09
# Player 7 - Points: 0, Elo: 1393.90, Winning Probability: 0.06
# Player 8 - Points: 3.5, Elo: 1793.02, Winning Probability: 0.08
# Player 9 - Points: 4.0, Elo: 1871.40, Winning Probability: 0.05
#
# Simulation 9996 - Final Round Results:
# Player 0 - Points: 1.5, Elo: 1430.19, Winning Probability: 0.19
# Player 1 - Points: 3.0, Elo: 1898.81, Winning Probability: 0.13
# Player 2 - Points: 5, Elo: 1957.24, Winning Probability: 0.12
# Player 3 - Points: 3, Elo: 1620.73, Winning Probability: 0.08
# Player 4 - Points: 2.0, Elo: 1673.35, Winning Probability: 0.11
# Player 5 - Points: 2.5, Elo: 1545.32, Winning Probability: 0.07
# Player 6 - Points: 1, Elo: 1544.96, Winning Probability: 0.09
# Player 7 - Points: 2.5, Elo: 1525.88, Winning Probability: 0.06
# Player 8 - Points: 3.5, Elo: 1631.50, Winning Probability: 0.08
# Player 9 - Points: 1, Elo: 1521.03, Winning Probability: 0.05
#
# Simulation 9997 - Final Round Results:
# Player 0 - Points: 1, Elo: 1458.16, Winning Probability: 0.19
# Player 1 - Points: 2.0, Elo: 1816.01, Winning Probability: 0.13
# Player 2 - Points: 3.0, Elo: 1830.23, Winning Probability: 0.12
# Player 3 - Points: 2.5, Elo: 1945.66, Winning Probability: 0.08
# Player 4 - Points: 4.0, Elo: 1798.89, Winning Probability: 0.11
# Player 5 - Points: 0.5, Elo: 1481.37, Winning Probability: 0.07
# Player 6 - Points: 3, Elo: 1943.76, Winning Probability: 0.09
# Player 7 - Points: 2.0, Elo: 1600.35, Winning Probability: 0.06
# Player 8 - Points: 2.5, Elo: 1733.66, Winning Probability: 0.08
# Player 9 - Points: 4.5, Elo: 1893.92, Winning Probability: 0.05
#
# Simulation 9998 - Final Round Results:
# Player 0 - Points: 3.0, Elo: 1714.92, Winning Probability: 0.19
# Player 1 - Points: 3.5, Elo: 1704.22, Winning Probability: 0.13
# Player 2 - Points: 3.0, Elo: 1611.46, Winning Probability: 0.12
# Player 3 - Points: 0.5, Elo: 1521.48, Winning Probability: 0.08
# Player 4 - Points: 1.5, Elo: 1615.09, Winning Probability: 0.11
# Player 5 - Points: 0.5, Elo: 1442.52, Winning Probability: 0.07
# Player 6 - Points: 4, Elo: 1939.89, Winning Probability: 0.09
# Player 7 - Points: 2.5, Elo: 1654.69, Winning Probability: 0.06
# Player 8 - Points: 3.5, Elo: 1673.74, Winning Probability: 0.08
# Player 9 - Points: 2.0, Elo: 1751.00, Winning Probability: 0.05
#
# Simulation 9999 - Final Round Results:
# Player 0 - Points: 0, Elo: 1383.68, Winning Probability: 0.19
# Player 1 - Points: 1.5, Elo: 1619.47, Winning Probability: 0.13
# Player 2 - Points: 3.0, Elo: 1732.14, Winning Probability: 0.12
# Player 3 - Points: 2, Elo: 1609.82, Winning Probability: 0.08
# Player 4 - Points: 3.0, Elo: 1813.31, Winning Probability: 0.11
# Player 5 - Points: 2, Elo: 1636.53, Winning Probability: 0.07
# Player 6 - Points: 3.0, Elo: 1786.79, Winning Probability: 0.09
# Player 7 - Points: 3.5, Elo: 1908.24, Winning Probability: 0.06
# Player 8 - Points: 1, Elo: 1764.79, Winning Probability: 0.08
# Player 9 - Points: 5, Elo: 1978.22, Winning Probability: 0.05
#
# Simulation 10000 - Final Round Results:
# Player 0 - Points: 4.0, Elo: 1819.48, Winning Probability: 0.19
# Player 1 - Points: 1, Elo: 1448.00, Winning Probability: 0.13
# Player 2 - Points: 2.5, Elo: 1641.25, Winning Probability: 0.12
# Player 3 - Points: 3, Elo: 1905.08, Winning Probability: 0.08
# Player 4 - Points: 1, Elo: 1514.29, Winning Probability: 0.11
# Player 5 - Points: 3, Elo: 1787.27, Winning Probability: 0.07
# Player 6 - Points: 0, Elo: 1480.08, Winning Probability: 0.09
# Player 7 - Points: 4.5, Elo: 1671.41, Winning Probability: 0.06
# Player 8 - Points: 2.0, Elo: 1426.47, Winning Probability: 0.08
# Player 9 - Points: 3.0, Elo: 1625.66, Winning Probability: 0.05

# %%
import random

# Number of Players, Rounds, and Simulations
num_players = 10
num_rounds = 5
num_simulations = 1000
k_factor = 30  # Higher K-factor for more responsive Elo rating updates

# Initialize Players with Elo ratings
players = [{'name': f'Player {i}', 'initial_elo': random.randint(1400, 2600), 'elo': 0, 'points': 0, 'total_points': 0, 'wins': 0, 'current_form': 0} for i in range(num_players)]

def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2, considering current form """
    adjusted_elo1 = player1['elo'] + player1['current_form']
    adjusted_elo2 = player2['elo'] + player2['current_form']
    return 1 / (1 + 10 ** ((adjusted_elo2 - adjusted_elo1) / 400))

def update_elo_ratings(winner, loser, draw=False):
    """ Update Elo ratings and current form after a game """
    expected_win_winner = calculate_win_probability(winner, loser)
    expected_win_loser = calculate_win_probability(loser, winner)

    score_winner = 0.5 if draw else 1
    score_loser = 0.5 if draw else 0

    winner['elo'] += k_factor * (score_winner - expected_win_winner)
    loser['elo'] += k_factor * (score_loser - expected_win_loser)

    # Update current form based on recent game outcome
    # result of all parameter(win, loser, draw=True/NA) should be actual result
    winner['current_form'] += k_factor * 0.5 if not draw else -k_factor * 0.2
    loser['current_form'] += -k_factor * 0.5 if not draw else k_factor * 0.2

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
        update_elo_ratings(player1, player2)
    elif result < win_prob + (1 - win_prob) / 2:
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
        update_elo_ratings(player1, player2, draw=True)
    else:
        player2['points'] += 1  # Player 2 wins
        update_elo_ratings(player2, player1)

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

def simulate_tournament():
    """ Simulate a single Swiss-system tournament """
    # Reset points and opponents for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []
        player['current_form'] = 0
        player['elo'] = player['initial_elo']  # Reset Elo to initial Elo for each simulation

    # Simulate rounds
    for round_number in range(1, num_rounds + 1):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)

    # Determine winner and update wins
    winner = max(players, key=lambda x: x['points'])
    winner['wins'] += 1

    # Accumulate total points for each player
    for player in players:
        player['total_points'] += player['points']

# Simulate all tournaments
for _ in range(1, num_simulations + 1):
    simulate_tournament()

# Calculate and print final results after all simulations
print("\nFinal Tournament Results after all simulations:")
for player in players:
    winning_probability = player['wins'] / num_simulations
    average_points = player['total_points'] / num_simulations
    print(f"{player['name']} - Initial Elo: {player['initial_elo']}, Final Elo: {player['elo']:.2f}, Average Points: {average_points:.2f}, Winning Probability: {winning_probability:.2f}")
# Out:
# Final Tournament Results after all simulations:
# Player 0 - Initial Elo: 1837, Final Elo: 1842.54, Average Points: 2.12, Winning Probability: 0.01
# Player 1 - Initial Elo: 1722, Final Elo: 1694.50, Average Points: 1.55, Winning Probability: 0.00
# Player 2 - Initial Elo: 2261, Final Elo: 2239.87, Average Points: 3.60, Winning Probability: 0.35
# Player 3 - Initial Elo: 1563, Final Elo: 1534.74, Average Points: 1.05, Winning Probability: 0.00
# Player 4 - Initial Elo: 2314, Final Elo: 2335.21, Average Points: 3.69, Winning Probability: 0.30
# Player 5 - Initial Elo: 2365, Final Elo: 2347.04, Average Points: 3.66, Winning Probability: 0.26
# Player 6 - Initial Elo: 1752, Final Elo: 1761.65, Average Points: 1.94, Winning Probability: 0.00
# Player 7 - Initial Elo: 1471, Final Elo: 1518.49, Average Points: 0.87, Winning Probability: 0.00
# Player 8 - Initial Elo: 2050, Final Elo: 2044.62, Average Points: 2.81, Winning Probability: 0.04
# Player 9 - Initial Elo: 2124, Final Elo: 2140.33, Average Points: 2.90, Winning Probability: 0.04

# %% [markdown]
# # Final code- 04 Dec

# %%
import random

# Number of Players, Rounds, and Simulations
num_players = 10
num_rounds = 5
num_simulations = 1000
k_factor = 10  # Higher K-factor for more responsive Elo rating updates

# Initialize Players with Elo ratings
players = [{'name': f'Player {i}', 'elo': random.randint(1200, 2000), 'points': 0, 'wins': 0, 'current_form': 0} for i in range(num_players)]

for player in players:
    print(f"{player ['name']} - Init Elo: {player['elo']:.2f}")
    
def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2, considering current form """
    # Adjusting Elo ratings based on current form
    adjusted_elo1 = player1['elo'] + player1['current_form']
    adjusted_elo2 = player2['elo'] + player2['current_form']
    return 1 / (1 + 10 ** ((adjusted_elo2 - adjusted_elo1) / 400))

def update_elo_ratings(winner, loser, draw=False):
    """ Update Elo ratings and current form after a game """
    expected_win_winner = calculate_win_probability(winner, loser)
    expected_win_loser = calculate_win_probability(loser, winner)

    score_winner = 0.5 if draw else 1
    score_loser = 0.5 if draw else 0

    winner['elo'] += k_factor * (score_winner - expected_win_winner)
    loser['elo'] += k_factor * (score_loser - expected_win_loser)

    # Update current form based on recent game outcome
    winner['current_form'] += k_factor * 1.2 if not draw else -k_factor * 0.3
    loser['current_form'] += -k_factor * 1.2 if not draw else k_factor * 0.5

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()
    if result < win_prob:
        player1['points'] += 1  # Player 1 wins
        update_elo_ratings(player1, player2)
    elif result < win_prob + (1 - win_prob) / 2:
#         print(player1['name'], player2['name'], " draw")
        player1['points'] += 0.5
        player2['points'] += 0.5  # Draw
        update_elo_ratings(player1, player2, draw=True)
    else:
        player2['points'] += 1  # Player 2 wins
        update_elo_ratings(player2, player1)

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

def print_final_round_statistics(players, simulation_number):
    """ Print statistics for the final round """
    if 9990 <= simulation_number <= 10000:
        print(f"\nSimulation {simulation_number} - Final Round Results:")
        for player in players:
            winning_probability = player['wins'] / num_simulations
            print(f"{player['name']} - Points: {player['points']}, Elo: {player['elo']:.2f}, Winning Probability: {winning_probability:.2f}")

def simulate_tournament():
    """ Simulate a single Swiss-system tournament """
    # Reset points and opponents for each player
    for player in players:
        player['points'] = 0
        player['opponents'] = []
        player['current_form'] = 0

    # Simulate rounds
    for round_number in range(1, num_rounds + 1):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)

    # Determine winner and update wins
    winner = max(players, key=lambda x: x['points'])
    winner['wins'] += 1
    
    
# Reset wins count before all simulations
for player in players:
    player['wins'] = 0

# Simulate all tournaments
for _ in range(1, num_simulations + 1):
    simulate_tournament()

    
# Calculate and print final probabilities after all simulations
print("\nFinal Tournament Results after all simulations:")
for player in players:
    winning_probability = player['wins'] / num_simulations
    print(f"{player['name']} - - Points: {player['points']} - - Final Elo: {player['elo']:.2f} - - Winning Probability: {winning_probability:.2f}")
# Out:
# Player 0 - Init Elo: 1556.00
# Player 1 - Init Elo: 1548.00
# Player 2 - Init Elo: 1991.00
# Player 3 - Init Elo: 1214.00
# Player 4 - Init Elo: 1232.00
# Player 5 - Init Elo: 1698.00
# Player 6 - Init Elo: 1396.00
# Player 7 - Init Elo: 1531.00
# Player 8 - Init Elo: 1751.00
# Player 9 - Init Elo: 1707.00
#
# Final Tournament Results after all simulations:
# Player 0 - - Points: 4.5 - - Final Elo: 2165.36 - - Winning Probability: 0.76
# Player 1 - - Points: 1 - - Final Elo: 1236.82 - - Winning Probability: 0.01
# Player 2 - - Points: 2.5 - - Final Elo: 1606.58 - - Winning Probability: 0.12
# Player 3 - - Points: 3 - - Final Elo: 1609.79 - - Winning Probability: 0.00
# Player 4 - - Points: 4.5 - - Final Elo: 1989.47 - - Winning Probability: 0.05
# Player 5 - - Points: 1 - - Final Elo: 1345.61 - - Winning Probability: 0.01
# Player 6 - - Points: 2 - - Final Elo: 1662.80 - - Winning Probability: 0.01
# Player 7 - - Points: 2.5 - - Final Elo: 1485.15 - - Winning Probability: 0.00
# Player 8 - - Points: 3 - - Final Elo: 1722.38 - - Winning Probability: 0.04
# Player 9 - - Points: 0 - - Final Elo: 800.05 - - Winning Probability: 0.00

# %%
import random

# Number of Players, Rounds, and Simulations
num_players = 10
num_rounds = 5
num_simulations = 1000
k_factor = 10  # Higher K-factor for more responsive Elo rating updates

# Initialize Players with Elo ratings
players = [{'name': f'Player {i}', 'elo': random.randint(1200, 2000), 'points': 0, 'wins': 0, 'current_form': 0, 'winning_probabilities': []} for i in range(num_players)]

def calculate_win_probability(player1, player2):
    """ Calculate the probability of player1 winning against player2, considering current form """
    adjusted_elo1 = player1['elo'] + player1['current_form']
    adjusted_elo2 = player2['elo'] + player2['current_form']
    return 1 / (1 + 10 ** ((adjusted_elo2 - adjusted_elo1) / 400))

def update_elo_ratings(winner, loser, draw=False):
    """ Update Elo ratings and current form after a game """
    expected_win_winner = calculate_win_probability(winner, loser)
    expected_win_loser = calculate_win_probability(loser, winner)

    score_winner = 0.5 if draw else 1
    score_loser = 0.5 if draw else 0

    winner['elo'] += k_factor * (score_winner - expected_win_winner)
    loser['elo'] += k_factor * (score_loser - expected_win_loser)

    winner['current_form'] += k_factor * 1.2 if not draw else -k_factor * 0.3
    loser['current_form'] += -k_factor * 1.2 if not draw else k_factor * 0.5

def simulate_game(player1, player2):
    """ Simulate a game between two players """
    win_prob = calculate_win_probability(player1, player2)
    result = random.random()

    if result < win_prob:
        player1['points'] += 1
        update_elo_ratings(player1, player2)
    elif result < win_prob + (1 - win_prob) / 2:
        player1['points'] += 0.5
        player2['points'] += 0.5
        update_elo_ratings(player1, player2, draw=True)
    else:
        player2['points'] += 1
        update_elo_ratings(player2, player1)

def swiss_pairing(players):
    """ Pair players using a simple Swiss system approach """
    sorted_players = sorted(players, key=lambda x: x['points'], reverse=True)
    pairings = []
    while sorted_players:
        player1 = sorted_players.pop(0)
        for i, player2 in enumerate(sorted_players):
            if not 'opponents' in player1 or player2['name'] not in player1['opponents']:
                player1.setdefault('opponents', []).append(player2['name'])
                player2.setdefault('opponents', []).append(player1['name'])
                pairings.append((player1, player2))
                sorted_players.pop(i)
                break
    return pairings

def simulate_tournament():
    """ Simulate a single Swiss-system tournament """
    for player in players:
        player['points'] = 0
        player['opponents'] = []
        player['current_form'] = 0
        player['winning_probabilities'] = []  # Clear winning probabilities

    for round_number in range(1, num_rounds + 1):
        pairings = swiss_pairing(players)
        for player1, player2 in pairings:
            simulate_game(player1, player2)
        
        # Calculate and store winning probabilities for each player after the round
        for player in players:
            total_wins_so_far = player['wins']
            total_simulations_so_far = round_number * num_simulations
            winning_probability = total_wins_so_far / total_simulations_so_far
            player
